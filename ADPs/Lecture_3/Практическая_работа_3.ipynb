# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/ADPs/Lecture_3/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа № 3: Обработка естественного языка в психологии**
#
# ## Введение
#
# В лекции №3 мы познакомились с ключевыми этапами обработки естественного языка (NLP) применительно к текстам пациентов. Мы разобрали, как «живой», неструктурированный и зашумленный язык превращается в структурированные числовые признаки, пригодные для машинного обучения и статистического анализа. Теперь вам предстоит применить эти знания на практике.
#
# Цель данной работы — закрепить навыки:
#
# - очистки текста (токенизация, удаление стоп-слов, нормализация, лемматизация),
# - векторизации текста методами Bag of Words и TF‑IDF,
# - осознанного выбора подхода в зависимости от клинической задачи,
# - критической оценки этических аспектов автоматического анализа текстов пациентов.
#
# Работа выполняется в среде Python с использованием библиотек `nltk`, `pymorphy3`, `scikit-learn` (и, по желанию, `gensim` для эмбеддингов). Все задания сопровождаются пояснениями и примерами.
#
# ---
#
# ## Подготовка рабочей среды
#
# Перед началом работы установите необходимые библиотеки (в терминале или командной строке):

# %%
# !pip install nltk pymorphy3 scikit-learn pandas matplotlib
# Для работы с эмбеддингами (дополнительно):
# !pip install gensim

# %% [markdown]
# Затем в Python-скрипте или Jupyter Notebook импортируйте модули и скачайте данные для NLTK:

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')   # если требуется

# %% [markdown]
# ## Часть 1. Теоретические вопросы (для самопроверки)
#
# Перед выполнением практических заданий ответьте письменно на следующие вопросы (кратко, но содержательно). Это поможет убедиться, что вы понимаете ключевые концепции.
#
# 1. Почему тексты пациентов считаются «шумными»? Приведите три примера такого шума.
# 2. Что такое токенизация и для чего она нужна?
# 3. Почему при удалении стоп‑слов в клинических текстах важно **не** удалять частицу «не»? Приведите пример, где это критично.
# 4. В чём разница между стеммингом и лемматизацией? Какой метод больше подходит для русского языка и почему?
# 5. Для каких задач в психологии подходит **One‑Hot Encoding**, а для каких — нет?
# 6. Что такое «мешок слов» (Bag of Words)? Опишите его сильные и слабые стороны.
# 7. В чём преимущество метода TF‑IDF перед простым подсчётом частот? Приведите пример слова, которое получит высокий вес у пациента с суицидальными мыслями.
# 8. Что такое векторные эмбеддинги слов и как они помогают компьютеру «понимать» смысл?
# 9. Назовите три особенности русского языка, усложняющих его обработку методами NLP.
# 10. Почему при анализе текстов на русском языке не рекомендуется переводить их на английский и использовать англоязычные модели?
#
# ---

# %% [markdown]
# ## Часть 2. Практические задания на Python
#
# Все задания выполняйте в одной Jupyter Notebook или в отдельном Python‑скрипте. Код должен быть прокомментирован. В конце каждого задания приводите краткий вывод.
#
# ---
#
# ### Задание 1. Очистка текста пациента
#
# **Описание.** Возьмите следующий текст — реальную дневниковую запись пациента с опечатками, сленгом и эмоциональной лексикой:
#
# ```
# «чё то я севодня вабще без сил, не магу встать с кровати. фсё бессмыслено. наверно я никуда не гажусь. хочеться просто заснуть и не прасыпаца»
# ```
#
# Выполните последовательно все этапы препроцессинга и выведите результаты на каждом шаге.
#
# **Требуется:**
#
# 1. **Токенизация** — разбить текст на отдельные токены (слова и знаки препинания). Используйте `nltk.word_tokenize(text, language='russian')`.
# 2. **Удаление стоп‑слов** — удалить стандартные стоп‑слова русского языка (из `nltk.corpus.stopwords.words('russian')`), но **обязательно сохранить** частицу «не». Выведите список оставшихся слов.
# 3. **Нормализация** — вручную или с помощью регулярных выражений исправить очевидные опечатки и сленг (например, «севодня» → «сегодня», «вабще» → «вообще», «магу» → «могу», «фсё» → «всё», «бессмыслено» → «бессмысленно», «гажусь» → «гожусь», «прасыпаца» → «просыпаться»). Можно также привести все слова к нижнему регистру.
# 4. **Лемматизация** — привести все слова к нормальной (словарной) форме с помощью `pymorphy3.MorphAnalyzer()`. Выведите итоговый список лемм.
#
# **Результат:** вы должны получить чистый список смысловых единиц, например: `['что', 'сегодня', 'вообще', 'сила', 'не', 'мочь', 'встать', 'кровать', 'всё', 'бессмысленный', 'наверно', 'никуда', 'годиться', 'хотеться', 'заснуть', 'просыпаться']`.
#
# **Вопрос для размышления:** Какие ключевые маркеры состояния пациента вы видите в очищенном тексте? Опишите их (апатия, ангедония, снижение самооценки и т.п.).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 2. Векторизация методом Bag of Words и TF‑IDF
#
# **Описание.** Даны три короткие фразы пациентов:
#
# 1. *«я чувствую тревогу и страх»*
# 2. *«тревога проходит, но остаётся страх»*
# 3. *«чувствую усталость, страх и безнадёжность»*
#
# **2.1. Постройте матрицу «мешок слов» (Bag of Words).**
#
# - Используйте `sklearn.feature_extraction.text.CountVectorizer`.
# - Выведите общий словарь (названия признаков) и саму матрицу частот (в виде массива).
# - Объясните, какие слова встречаются чаще всего и почему.
#
# **2.2. Вычислите TF‑IDF‑веса для этих же текстов.**
#
# - Используйте `sklearn.feature_extraction.text.TfidfVectorizer`.
# - Выведите матрицу TF‑IDF.
# - Сравните значения для частотных слов (например, «я», «чувствую») и для редких («усталость», «безнадёжность»). Какой метод лучше выделяет клинически значимые слова?
#
# **2.3. Визуализация (по желанию).**
#
# - Постройте тепловую карту (heatmap) матрицы частот или TF‑IDF с помощью `seaborn` или `matplotlib`. Подпишите строки (тексты) и столбцы (слова).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 3. Работа с векторными эмбеддингами (введение)
#
# **Описание.** В этом задании мы попробуем использовать предобученные векторные представления слов (Word2Vec) для измерения семантической близости между словами, важными в клиническом контексте.
#
# **Инструкция:**
#
# 1. Загрузите предобученную модель `word2vec‑google‑news‑300` (если позволяет интернет и память) или используйте более лёгкую русскоязычную модель от `DeepPavlov` или `RusVectōrēs`. Если загрузка больших моделей затруднена, можно использовать встроенные векторы из `gensim.downloader` или обучить свою модель на небольшом корпусе (например, на нескольких сотнях предложений). **Для упрощения мы предложим использовать `FastText` из библиотеки `gensim` с загрузкой русской модели** (например, `fasttext-wiki-news-subwords-300`).
#
#    **Альтернатива (легче):** можно пропустить этот шаг и перейти к анализу без эмбеддингов, но тогда задание будет неполным. Для студентов с низкой скоростью интернета предлагается использовать встроенную модель `gensim.models.KeyedVectors.load_word2vec_format` с небольшим файлом, но это сложно. Поэтому мы упростим: **не требуется загружать реальную модель, а только написать код для загрузки и выполнить простые операции с уже загруженными векторами** (можно скачать маленькую модель, например, `ruwikiruscorpora`). В целях практической работы можно выполнить задание, используя готовые эмбеддинги из библиотеки `spacy` с русской моделью (`ru_core_news_sm`). Однако установка `spacy` и модели может быть громоздкой.
#
#    **Решение:** Сделаем задание на понимание — студенты напишут код для загрузки модели и получения векторов для нескольких слов, а также вычисления косинусного расстояния между ними. В качестве модели используем `gensim.models.KeyedVectors` с моделью `fasttext-wiki-news-subwords-300`, которую можно скачать автоматически через `gensim.downloader`.

# %%
import gensim.downloader as api
model = api.load("fasttext-wiki-news-subwords-300")  # около 500 МБ, может занять время

# %% [markdown]
#    Если нет возможности скачать, можно использовать модель из `spacy` (установка: `pip install spacy` и `python -m spacy download ru_core_news_sm`). Но для единообразия предложим первый вариант.
#
# 2. Получите векторы для следующих слов (список чувств и состояний):
#    - `тревога`
#    - `страх`
#    - `паника`
#    - `депрессия`
#    - `тоска`
#    - `безнадёжность`
#    - `надежда`
#    - `радость`
#
# 3. Вычислите косинусное расстояние между каждой парой слов из этого списка (можно построить матрицу расстояний). С помощью комментариев объясните, какие пары оказались семантически близкими, а какие — далёкими. Соответствует ли это психологическим представлениям?
#
# 4. *Дополнительное задание (для углублённого понимания).* Выберите слово «будущее» и найдите 5 самых похожих по смыслу слов в модели. Сравните результат с тем, что вы ожидали как психолог.
#
# **Результат:** вы должны представить код и краткий текстовый анализ полученных семантических отношений.

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 4. Этический анализ системы NLP в психологии
#
# **Описание.** Представьте, что вы — руководитель центра психологической помощи. Вам предлагают внедрить систему, которая автоматически анализирует дневниковые записи пациентов с помощью описанных методов NLP (от очистки до эмбеддингов) и выдаёт рекомендации по тактике терапии, а также предупреждения о возможном суицидальном риске.
#
# Напишите эссе (объёмом 1–2 страницы) на тему **«Этические вызовы при автоматическом анализе текстов пациентов»**. В эссе обязательно осветите следующие аспекты:
#
# 1. **Информированное согласие** — что должно быть разъяснено пациенту перед началом использования системы? Какие пункты обязательно включить в форму согласия?
# 2. **Конфиденциальность и безопасность данных** — как должны храниться и обрабатываться тексты пациентов? Кто имеет доступ к результатам анализа? Как обеспечивается анонимизация?
# 3. **Ответственность за ошибки** — кто несёт ответственность, если алгоритм пропустит суицидальные тенденции или, наоборот, ложно сработает и вызовет ненужную тревогу?
# 4. **Прозрачность и интерпретируемость** — должен ли пациент знать, как именно работает алгоритм? Как психолог может объяснить пациенту, что анализ проводится автоматически?
#
# Постарайтесь привести аргументированные предложения по минимизации каждого из рисков. Ссылайтесь на материалы лекции (раздел 9, 10 и этические замечания).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Часть 3. Комплексное задание (повышенной сложности)
#
# **Классификация депрессивных текстов с использованием методов NLP (по желанию).**
#
# Если вы уже знакомы с основами машинного обучения, попробуйте реализовать простой классификатор, который по тексту определяет, относится ли он к депрессивному высказыванию или нет.
#
# **Инструкция:**
#
# - Используйте небольшой размеченный датасет (например, из открытых источников, либо создайте синтетическую выборку из 20–30 фраз с метками: 1 — депрессивная, 0 — нет).
# - Примените TF‑IDF для извлечения признаков.
# - Обучите классификатор (логистическая регрессия, наивный Байес или метод опорных векторов) с помощью `sklearn`.
# - Оцените точность (accuracy) на тестовой выборке (или используйте кросс‑валидацию).
# - Опишите, какие слова (признаки) оказались наиболее информативными для классификации.
#
# Это задание не является обязательным, но даст вам более глубокое понимание всего пайплайна NLP в клинической задаче.
#
# ---
#
# ## Критерии оценки
#
# - **Теоретические вопросы** — 20% (полнота и правильность ответов).
# - **Задание 1 (очистка)** — 25% (правильность выполнения всех этапов, комментарии, вывод).
# - **Задание 2 (BoW и TF‑IDF)** — 25% (корректность кода, интерпретация результатов).
# - **Задание 3 (эмбеддинги)** — 15% (код работает, анализ расстояний обоснован).
# - **Задание 4 (этика)** — 15% (глубина анализа, аргументированность, соответствие теме).
# - Дополнительное задание (классификация) — оценивается отдельно как бонус.
#
# ---
#
# ## Требования к сдаче
#
# - Пришлите **один файл** (Jupyter Notebook `.ipynb` или Python `.py`) со всеми заданиями.
# - Код должен быть чистым, снабжённым комментариями на русском языке.
# - Ответы на теоретические вопросы и эссе по этике приложите в виде текстовых ячеек (в Notebook) или отдельного документа (если сдаёте скрипт, то отдельный файл `.txt` или `.pdf`).
# - Убедитесь, что все библиотеки импортированы и код выполняется без ошибок (при необходимости укажите версии).
#
# ---
#
# ## Срок выполнения
#
# Работа рассчитана на **2 недели**. Рекомендуется выполнять задания последовательно, после каждой лекции по NLP.

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Заключение
#
# Данная практическая работа охватывает полный цикл обработки текста — от «сырого» пациентского языка до числовых векторов и этических размышлений. Вы не только освоите инструменты, но и научитесь критически оценивать их применение в психологии. Успехов!
