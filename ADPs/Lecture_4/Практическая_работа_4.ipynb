# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/ADPs/Lecture_4/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа № 4: Визуализация данных в психологических исследованиях**
#
# ## Введение
#
# В лекции №4 мы изучили, как визуализация помогает психологу увидеть закономерности, проверить допущения статистических тестов, сравнить группы и донести результаты до аудитории. График — это не просто «картинка», а инструмент мышления, позволяющий мгновенно оценить распределение, выбросы, связи и динамику.
#
# Цель данной работы — закрепить практические навыки:
#
# - выбора правильного типа графика в зависимости от исследовательской задачи и типа данных,
# - построения и оформления графиков в соответствии с правилами APA,
# - критической оценки графиков на предмет манипуляций и искажений,
# - работы с библиотеками `matplotlib`, `seaborn` и `pandas` в Python.
#
# Вы будете выполнять задания как с генерацией случайных данных, так и с анализом реальных (или приближенных к реальным) психологических данных. Все графики необходимо оформлять так, как принято в научных публикациях.
#
# ---
#
# ## Подготовка рабочей среды
#
# Перед началом работы установите необходимые библиотеки (в терминале или командной строке):

# %%
# !pip install pandas numpy matplotlib seaborn scipy

# %% [markdown]
# Если вы используете Jupyter Notebook или Google Colab, достаточно выполнить ячейку с импортами:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# Для корректного отображения русских шрифтов в графиках (если необходимо) можно добавить:

# %%
plt.rcParams['font.family'] = 'DejaVu Sans'  # или другой шрифт с поддержкой кириллицы

# %% [markdown]
# ## Часть 1. Теоретические вопросы (для самопроверки)
#
# Перед выполнением практических заданий письменно ответьте на следующие вопросы (кратко, но содержательно). Это поможет убедиться, что вы понимаете ключевые концепции визуализации.
#
# 1. Назовите четыре основные функции визуализации в психологических исследованиях. Приведите пример для каждой.
#
# 2. Какой тип графика вы выберете для отображения распределения одной количественной переменной? Почему?
#
# 3. В чём отличие гистограммы от столбчатой диаграммы? Приведите примеры использования каждого в психологии.
#
# 4. Что показывает ящик с усами (boxplot)? Какие пять статистик на нём отображены?
#
# 5. Для какой задачи используется точечный график (scatter plot)? Какую информацию он даёт о связи двух переменных?
#
# 6. Что такое тепловая карта (heatmap) и когда она применяется в психологических исследованиях? Приведите два примера.
#
# 7. Назовите обязательные элементы оформления графика для научной публикации (по стандартам APA).
#
# 8. Какие ошибки при построении графиков могут ввести читателя в заблуждение? Приведите хотя бы три примера.
#
# 9. Почему важно проверять распределение данных перед выбором статистического теста? Какой график для этого подходит лучше всего?
#
# 10. **Этический вопрос:** Представьте, что вы видите в статье график, где ось Y начинается не с нуля, а с 20. Что вы заподозрите и как проверите честность такого графика?

# %% [markdown]
# ## Часть 2. Практические задания на Python
#
# Все задания выполняйте в одной Jupyter Notebook (или .py-скрипте). Код должен быть прокомментирован на русском языке, а каждый график сопровождаться текстовым анализом (что вы видите и какой вывод можно сделать). В конце каждого задания приводите краткий вывод.
#
# ---
#
# ### Задание 1. Гистограмма: анализ распределения баллов по опроснику
#
# **Описание.** Предположим, вы исследовали уровень депрессии у 200 пациентов с помощью шкалы Бека (BDI). Баллы могут варьироваться от 0 до 63. Вы получили следующие данные (сгенерируем их для примера).
#
# **Требуется:**
#
# 1. Сгенерируйте массив из 200 случайных значений, имеющих нормальное распределение со средним 25 и стандартным отклонением 8, но обрежьте значения до диапазона 0–63 (используйте `np.clip`). Это будет имитация реальных данных.
#
# 2. Постройте гистограмму с 12 интервалами. Добавьте вертикальные линии для среднего и медианы, подпишите их на графике.
#
# 3. Оформите график по правилам APA:
#    - заголовок с номером (например, *Рисунок 1. Распределение баллов по шкале депрессии Бека (N=200)*),
#    - подписи осей (с единицами измерения),
#    - легенду.
#
# 4. Напишите краткий анализ: симметрично ли распределение? Есть ли выбросы? Какое значение (среднее или медиана) лучше описывает центральную тенденцию?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 2. Ящик с усами: сравнение трёх групп по уровню тревоги
#
# **Описание.** Вы проводите исследование эффективности трёх видов терапии при тревожных расстройствах. У вас есть три группы по 40 человек каждая: КПТ, медикаментозная терапия и контрольная группа. Уровень тревоги измеряется по шкале Спилбергера (баллы от 20 до 80).
#
# Сгенерируйте данные так, чтобы:
# - в группе КПТ средний балл был около 45, разброс 8;
# - в медикаментозной — около 50, разброс 10;
# - в контрольной — около 58, разброс 12.
#
# **Требуется:**
#
# 1. Создайте DataFrame с колонками `['Тревога', 'Группа']`.
#
# 2. Постройте ящик с усами (boxplot) с помощью `seaborn.boxplot`. Сравните медианы, разброс и выбросы в группах.
#
# 3. Оформите график по APA: номер, название, подписи осей, легенда (если нужна). Добавьте под графиком примечание со средними и стандартными отклонениями для каждой группы (используйте `plt.figtext` или текстовую ячейку).
#
# 4. Напишите интерпретацию: какие группы статистически различаются (визуально)? Есть ли группы с большим разбросом? Что это может означать для практики?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 3. Точечный график: связь между качеством сна и уровнем депрессии
#
# **Описание.** Вы хотите проверить гипотезу о том, что у пациентов с депрессией качество сна отрицательно связано с выраженностью симптомов. Для этого вы собрали данные 100 пациентов: уровень депрессии (BDI) и субъективную оценку качества сна (по шкале от 0 до 10, где 10 — отличный сон).
#
# Сгенерируйте данные так, чтобы корреляция была примерно –0.6 (т.е. чем выше депрессия, тем хуже сон).
#
# **Требуется:**
#
# 1. Постройте scatter plot: по оси X — качество сна, по оси Y — балл BDI.
#
# 2. Добавьте линию регрессии (используйте `scipy.stats.linregress`). Нанесите на график коэффициент корреляции (r).
#
# 3. Оформите график по APA. Добавьте примечание с уравнением регрессии (опционально).
#
# 4. Напишите анализ: что вы видите? Есть ли нелинейность? Есть ли явные выбросы, которые могут искажать связь?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 4. Тепловая карта корреляционной матрицы
#
# **Описание.** Вы измерили у 120 испытуемых пять психологических характеристик:
# - депрессия (BDI),
# - тревога (шкала Спилбергера),
# - качество сна (PSQI),
# - уровень стресса (PSS),
# - субъективное благополучие (SWLS).
#
# Вы хотите увидеть, какие шкалы сильно коррелируют между собой, а какие — независимы.
#
# Сгенерируйте коррелированные данные (можно использовать многомерное нормальное распределение или создать переменные с известными корреляциями).
#
# **Требуется:**
#
# 1. Рассчитайте матрицу корреляций Пирсона для всех пяти переменных.
#
# 2. Постройте тепловую карту (heatmap) с аннотациями (коэффициенты корреляции). Используйте цветовую палитру `coolwarm` или `RdBu`.
#
# 3. Оформите график по APA: номер, название, подписи осей (названия шкал), цветовая шкала с подписью.
#
# 4. Проанализируйте: какие кластеры сильно коррелирующих шкал вы видите? Есть ли шкалы, которые почти не коррелируют с другими? Что это говорит о конструктах?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 5. Линейный график: динамика симптомов в ходе терапии
#
# **Описание.** Вы отслеживаете изменения уровня депрессии у одного пациента (или усреднённые данные по группе) на протяжении 12 сессий КПТ. Данные по баллам BDI на каждой сессии:
#
# `[34, 31, 28, 24, 21, 19, 17, 16, 15, 14, 13, 12]`
#
# **Требуется:**
#
# 1. Постройте линейный график, соединяющий точки. Используйте маркеры (например, кружки).
#
# 2. Подпишите оси: «Номер сессии» и «Балл BDI».
#
# 3. Оформите по APA: заголовок, подписи, легенда (если несколько линий).
#
# 4. Добавьте горизонтальную пунктирную линию, обозначающую клинически значимое улучшение (например, снижение на 50% от исходного уровня — проведите расчёт и отобразите).
#
# 5. Напишите анализ: какова динамика? Есть ли периоды застоя или ухудшения? Какой темп снижения?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 6. Сравнение нескольких групп с помощью столбчатой диаграммы (бонус)
#
# **Описание.** У вас есть данные о частоте встречаемости различных диагнозов в вашей клинической выборке (например, 150 пациентов). Распределение: депрессия — 45, тревога — 38, ПТСР — 28, шизофрения — 15, ОКР — 24.
#
# **Требуется:**
#
# 1. Постройте столбчатую диаграмму (bar chart) с частотами для каждого диагноза.
#
# 2. Оформите по APA.
#
# 3. Сделайте вывод о наиболее распространённом диагнозе в выборке.

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Часть 3. Анализ готовых графиков и этика визуализации
#
# **Задание 7. Критический анализ графиков (эссе).**
#
# Найдите в интернете или научных публикациях **два графика** (можно скриншоты):
# - один, по вашему мнению, **хороший и честный**;
# - другой, который **вводит в заблуждение** (манипуляции с масштабом, обрезанные оси, неподходящий тип графика и т.п.).
#
# Вставьте их в свой отчёт (или опишите словами, если нет возможности вставить) и напишите **эссе** (объёмом 1–2 страницы), в котором:
#
# 1. Опишите, что показывает каждый график и какова его цель.
#
# 2. Для хорошего графика: почему он удачен? Какие элементы оформления делают его понятным и честным? Соответствует ли он правилам APA?
#
# 3. Для плохого графика: какая именно манипуляция использована? Как она искажает восприятие данных? Что бы вы изменили, чтобы график стал честным?
#
# 4. Сделайте вывод о важности критического взгляда на визуализацию в психологических исследованиях. Почему психолог должен уметь распознавать недобросовестные графики?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Часть 4. Комплексное задание (повышенной сложности) — по желанию
#
# **Задание 8. Построение инфографики «Как выбрать правильный график».**
#
# Создайте одностраничную памятку для коллег-психологов. Можно использовать любой инструмент (Word, PowerPoint, Canva, даже код с `matplotlib` для создания схемы). Памятка должна содержать:
#
# - алгоритм выбора графика в виде блок-схемы (можно взять за основу схему из лекции);
# - краткое описание не менее 5 типов графиков (гистограмма, boxplot, scatter plot, heatmap, line plot) с указанием, когда какой использовать;
# - примеры психологических задач для каждого;
# - чек-лист оформления графика по APA (заголовок, оси, легенда, примечание).
#
# Файл приложите к работе (в формате .png, .pdf или .pptx).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Часть 5. Домашнее задание (на 2 недели)
#
# **Задание 9. Работа с реальными (или приближенными) данными.**
#
# Возьмите любой набор данных, который у вас есть (можно использовать данные из лекции №2 — опросник 30 респондентов, либо найти открытый датасет по психологии, например, из репозиториев Kaggle). Если данных нет, создайте свои, имитируя опрос 50 человек по 3–4 шкалам (например, тревога, депрессия, стресс, возраст).
#
# Выполните следующие пункты:
#
# 1. **Очистите данные** (если есть пропуски, удалите или заполните) и опишите их (средние, медианы, стандартные отклонения).
#
# 2. **Постройте гистограмму** для одной количественной переменной (например, суммарный балл опросника). Оформите по APA.
#
# 3. **Постройте boxplot** для сравнения двух групп (например, мужчины и женщины, или группа с высоким и низким уровнем стресса, если есть данные). Сделайте выводы.
#
# 4. **Постройте scatter plot** для двух переменных, которые, по вашему предположению, могут быть связаны (например, возраст и уровень депрессии). Добавьте линию регрессии и коэффициент корреляции.
#
# 5. **Постройте тепловую карту** корреляционной матрицы для всех количественных переменных. Проанализируйте сильные связи.
#
# Все графики должны быть оформлены по APA: номера, названия, подписи осей, легенды, примечания со статистиками.
#
# В конце напишите **общее резюме** (1 страница): какие закономерности вы обнаружили в своих данных? Подтвердились ли ваши гипотезы? Какой график оказался наиболее информативным?

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Критерии оценки
#
# | Компонент | Процент | Описание |
# |-----------|---------|----------|
# | Теоретические вопросы (Часть 1) | 15% | Полнота и правильность ответов |
# | Задания 1–5 (построение графиков) | 40% | Корректность кода, соответствие APA, качество интерпретации |
# | Задания 6–7 (анализ и этика) | 20% | Глубина анализа, аргументированность, умение выявить манипуляции |
# | Задание 8 (инфографика) | 10% | Наглядность, полнота, практическая полезность |
# | Домашнее задание (Часть 5) | 15% | Полнота выполнения всех пунктов, качество оформления, выводы |
#
# ---
#
# ## Требования к сдаче
#
# - Пришлите **один файл** (Jupyter Notebook `.ipynb` или Python `.py`) со всеми заданиями, кодом и текстовыми комментариями.
# - Эссе по этике (Задание 7) и инфографика (Задание 8) могут быть приложены отдельными файлами (`.pdf`, `.png`, `.pptx`) или вставлены в Notebook как Markdown-ячейки.
# - Убедитесь, что код выполняется без ошибок. Укажите версии библиотек, если требуется.
# - Все графики должны быть сохранены в высоком разрешении (при необходимости используйте `plt.savefig`).
#
# ---
#
# ## Заключение
#
# Данная практическая работа позволит вам не только освоить технические приёмы построения графиков на Python, но и научиться выбирать правильный инструмент для каждой психологической задачи, а главное — критически оценивать визуализацию с точки зрения честности и информативности. Грамотная визуализация — это путь к более глубокому пониманию данных и прозрачной коммуникации результатов. Успехов!
#
# ---
#
# **Срок выполнения: 2 недели.**
