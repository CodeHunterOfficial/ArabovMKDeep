# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/ADPs/Lecture_7/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа № 7: Развёртывание моделей — создание веб-интерфейсов для психологических инструментов
#
# ## Введение
#
# В лекции №7 мы научились превращать обученные NLP-модели в полноценные веб-приложения, доступные для использования психологами, исследователями и даже пациентами. Мы разобрали:
#
# - почему веб-интерфейс превращает модель из «игрушки для программистов» в реальный инструмент,
# - как установить и настроить **VS Code** для работы с Python,
# - как создавать веб-приложения с **Streamlit** и **Gradio**,
# - как организовать структуру проекта и подключить обученную модель,
# - как выложить приложение в интернет через **Streamlit Cloud** и **Hugging Face Spaces**,
# - какие этические правила нужно соблюдать при создании психологических ИИ-инструментов.
#
# Теперь вам предстоит применить эти знания на практике.
#
# **Цель работы** — закрепить навыки:
# - настройки среды разработки (VS Code, Python, виртуальное окружение),
# - создания веб-приложений на Streamlit для психологических задач,
# - подключения обученной модели к веб-интерфейсу,
# - организации проекта (структура папок, requirements.txt, кеширование),
# - подготовки приложения к облачному деплою,
# - разработки этического дисклеймера и протокола конфиденциальности.
#
# ---
#
# ## Подготовка рабочей среды
#
# Для выполнения работы вам понадобится:
#
# | Инструмент | Где взять | Зачем |
# |------------|-----------|-------|
# | **VS Code** | https://code.visualstudio.com/ | Редактор кода |
# | **Python 3.10+** | https://python.org/downloads/ | Язык программирования |
# | **Git** | https://git-scm.com/downloads | Для деплоя на GitHub |
# | **Аккаунт GitHub** | https://github.com/join | Для деплоя на Streamlit Cloud |
# | **Аккаунт Hugging Face** | https://huggingface.co/join | Для токена API (опционально) |
#
# **Если вы ещё не установили VS Code и Python** — вернитесь к разделу 2.3 лекции, там есть подробная пошаговая инструкция.
#
# **Рекомендуемый подход:** все задания выполняйте в **VS Code** — это самый удобный и мощный редактор для Python-разработки. В лекции даны подробные инструкции по его установке и настройке.
#
# ---
#
# ## Часть 1. Теоретические вопросы (для самопроверки)
#
# Перед выполнением практических заданий письменно ответьте на следующие вопросы. Это поможет убедиться, что вы понимаете ключевые концепции.
#
# 1. Зачем психологу создавать веб-приложение для своей модели? Приведите три причины.
#
# 2. В чём основное различие между Streamlit и Gradio? В каком случае выбрать каждый инструмент?
#
# 3. Что делает `@st.cache_resource` и почему это важно для работы приложения?
#
# 4. Зачем нужен файл `requirements.txt` в проекте? Что произойдёт, если его не будет при деплое?
#
# 5. Назовите 3 компонента Streamlit для ввода данных и 3 для вывода результатов.
#
# 6. Что такое Hugging Face Inference API и как он упрощает создание приложений?
#
# 7. Опишите пошагово процесс деплоя на Streamlit Cloud.
#
# 8. Какие ограничения есть у бесплатного тарифа Streamlit Cloud? Как они влияют на выбор модели?
#
# 9. Почему нельзя загружать реальные данные пациентов в облачные сервисы без анонимизации?
#
# 10. Что должен содержать дисклеймер в психологическом ИИ-приложении?
#
# 11. **Этический вопрос:** представьте, что вы создали приложение для анализа эмоций. Ваш коллега хочет использовать его в клинике. Что вы ему посоветуете?

# %% [markdown]
# ## Часть 2. Практические задания
#
# Все задания выполняйте в **VS Code** (рекомендуется) или другом редакторе кода. Код должен быть снабжён комментариями на русском языке. В конце каждого задания приводите краткий анализ результатов.
#
# ---
#
# ### Задание 1. Установка и настройка среды разработки
#
# **Описание.** В этом задании вы установите все необходимые инструменты и создадите структуру проекта.
#
# **Требуется:**
#
# 1. Установите **VS Code** (если ещё не установлен) с официального сайта.
#
# 2. Установите расширение **Python** от Microsoft в VS Code.
#
# 3. Установите **Python 3.10+** с официального сайта (отметьте "Add to PATH").
#
# 4. Проверьте установку в терминале:
#    ```bash
#    python --version
#    pip --version
#    ```
#
# 5. Создайте папку проекта `psychology_app` на диске D: (или на рабочем столе).
#
# 6. Откройте папку в VS Code (File → Open Folder).
#
# 7. Создайте файл `requirements.txt` и добавьте в него:
#    ```txt
#    streamlit
#    transformers
#    torch
#    matplotlib
#    numpy
#    scikit-learn
#    python-dotenv
#    langdetect
#    huggingface-hub
#    ```
#
# 8. Установите библиотеки:
#    ```bash
#    pip install -r requirements.txt
#    ```
#
# 9. Проверьте установку Streamlit:
#    ```bash
#    streamlit --version
#    ```
#
# **Что сдать:** скриншоты выполнения всех шагов (терминал, VS Code с открытой папкой) и краткое описание (1 страница).

# %%
# Ваш код решения задачи (команды в терминале):

# %% [markdown]
# ### Задание 2. Создание первого Streamlit-приложения
#
# **Описание.** В этом задании вы создадите простое приложение "Hello, World!" на Streamlit, чтобы убедиться, что всё работает.
#
# **Требуется:**
#
# 1. Создайте файл `app.py` в корне проекта.
#
# 2. Напишите код для простого приложения:
#    - Заголовок "🧠 Мой первый Streamlit-анализатор".
#    - Текст-описание.
#    - Поле для ввода имени (`st.text_input`).
#    - Кнопка "Поприветствовать" (`st.button`).
#    - При нажатии кнопки выводится приветствие с именем пользователя.
#
# 3. Запустите приложение:
#    ```bash
#    streamlit run app.py
#    ```
#
# 4. Убедитесь, что в браузере открылась страница `http://localhost:8501`.
#
# **Что сдать:** код `app.py`, скриншот работающего приложения.

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 3. Приложение для анализа эмоций (с локальной моделью)
#
# **Описание.** В этом задании вы создадите полноценное приложение для классификации эмоций, используя модель из Практики 6 (или готовую модель с Hugging Face).
#
# **Требуется:**
#
# 1. Если у вас есть обученная модель из Практики 6, скопируйте её в папку `models/best_model`.
#
# 2. Если модели нет, используйте готовую модель:
#    ```python
#    from transformers import pipeline
#    model = pipeline("sentiment-analysis", model="blanchefort/rubert-base-cased-sentiment")
#    ```
#
# 3. Создайте приложение со следующими компонентами:
#    - **Заголовок** и **описание**.
#    - **Боковая панель** с ползунком для порога уверенности (`st.slider`).
#    - **Поле для ввода текста** (`st.text_area`).
#    - **Кнопка "Анализировать"** (`st.button`).
#    - **Кеширование модели** с `@st.cache_resource`.
#    - **Вывод результата**: эмоция, уверенность (прогресс-бар).
#    - **График** распределения вероятностей (`st.pyplot`).
#    - **Дисклеймер** о недиагностическом назначении.
#
# 4. Запустите приложение и протестируйте его на 3–4 текстах.
#
# **Что сдать:** код `app.py`, скриншоты работы приложения на разных текстах, краткий анализ (1 страница).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 4. Создание Gradio-приложения (быстрая демонстрация)
#
# **Описание.** Создайте альтернативную версию приложения на Gradio для быстрой демонстрации модели коллегам.
#
# **Требуется:**
#
# 1. Установите Gradio:
#    ```bash
#    pip install gradio
#    ```
#
# 2. Создайте файл `app_gradio.py`.
#
# 3. Напишите код, аналогичный Заданию 3, но с использованием Gradio:
#    - `gr.Interface` с функцией анализа.
#    - Поле ввода (`gr.Textbox`).
#    - Вывод результата.
#    - Примеры (`examples`) для быстрого тестирования.
#
# 4. Запустите приложение:
#    ```bash
#    python app_gradio.py
#    ```
#
# 5. Откройте `http://127.0.0.1:7860` в браузере.
#
# 6. Сравните: чем отличается интерфейс Gradio от Streamlit? Что проще/сложнее?
#
# **Что сдать:** код `app_gradio.py`, скриншот работы, сравнительный анализ (1 страница).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 5. Полноценное приложение для психолога (6 функций)
#
# **Описание.** Создайте расширенное приложение по образцу из лекции (раздел 4.6), которое решает 6 практических NLP-задач через Hugging Face Inference API.
#
# **Требуется:**
#
# 1. Получите бесплатный токен на Hugging Face (инструкция в лекции).
#
# 2. Создайте файл `.env` с токеном:
#    ```
#    HF_TOKEN=ваш_токен_сюда
#    ```
#
# 3. Реализуйте функции:
#    - Анализ тональности (позитив/нейтраль/негатив).
#    - Суммаризация текста (4–6 предложений).
#    - Перефразирование (сохранение смысла).
#    - Исправление текста (орфография, пунктуация).
#    - Определение стиля (научный, официальный, разговорный и т.д.).
#    - Генерация заголовка (3–8 слов).
#
# 4. Создайте интерфейс с боковой панелью для выбора функции.
#
# 5. Добавьте автоматическое определение языка (русский/английский).
#
# 6. Добавьте дисклеймер и предупреждение о конфиденциальности.
#
# **Что сдать:** полный код `app_psychology.py`, скриншоты работы каждой функции, анализ (1–2 страницы).

# %%
# Ваш код решения задачи:

# %% [markdown]
# ### Задание 6. Подготовка к деплою (GitHub + Streamlit Cloud)
#
# **Описание.** Подготовьте ваше приложение к публикации в интернете.
#
# **Требуется:**
#
# 1. Создайте репозиторий на GitHub (публичный).
#
# 2. Инициализируйте Git в вашем проекте:
#    ```bash
#    git init
#    git add .
#    git commit -m "Initial commit"
#    git remote add origin https://github.com/ваш_username/psychology_app.git
#    git push -u origin main
#    ```
#
# 3. Создайте файл `.gitignore` и добавьте:
#    ```
#    .env
#    __pycache__/
#    *.pyc
#    .DS_Store
#    *.log
#    ```
#
# 4. Убедитесь, что `requirements.txt` содержит все необходимые библиотеки.
#
# 5. Зайдите на [share.streamlit.io](https://share.streamlit.io).
#
# 6. Нажмите "New app" и выберите ваш репозиторий.
#
# 7. Укажите файл `app.py` как точку входа.
#
# 8. Нажмите "Deploy" и подождите 3–5 минут.
#
# 9. Получите публичную ссылку на приложение.
#
# 10. Если приложение использует токен HF, добавьте его в Streamlit Secrets.
#
# **Что сдать:** ссылку на GitHub-репозиторий, ссылку на развёрнутое приложение, скриншот процесса деплоя.

# %%
# Ваш код решения задачи (команды в терминале):

# %% [markdown]
# ### Задание 7. Этический анализ (обязательное)
#
# **Описание.** Представьте, что вы — руководитель психологического центра. Вы хотите внедрить созданное вами приложение для анализа дневниковых записей пациентов.
#
# **Напишите этический протокол** (2–3 страницы), в котором осветите:
#
# 1. **Информированное согласие** — что пациент должен знать об использовании ИИ-приложения? Какие пункты обязательно включить?
#
# 2. **Конфиденциальность и безопасность** — где хранятся данные? Кто имеет доступ? Как обеспечивается анонимизация?
#
# 3. **Человеческий контроль** — как организовать проверку результатов модели психологом? Кто отвечает за финальные решения?
#
# 4. **Обработка ошибок** — что делать при ложных срабатываниях? Как минимизировать риски?
#
# 5. **Прозрачность** — как объяснить пациенту, что анализ проводит ИИ? Как показать источники (если используется RAG)?
#
# **Что сдать:** этический протокол в формате PDF или текстовой ячейкой в Notebook.

# %% [markdown]
# ```
# Ваш отчет
# ```

# %% [markdown]
# ### Задание 8. Дополнительное задание (повышенной сложности — по желанию)
#
# **Создание приложения с загрузкой файлов и историей**
#
# **Описание.** Расширьте приложение из Задания 5, добавив:
# - Загрузку файлов `.txt` для анализа.
# - Историю анализов (сохранение результатов в сессии).
# - Экспорт результатов в CSV.
#
# **Требуется:**
#
# 1. Добавьте компонент `st.file_uploader` для загрузки текстовых файлов.
#
# 2. Добавьте `st.session_state` для хранения истории анализов.
#
# 3. Добавьте кнопку "Экспортировать историю" для выгрузки CSV.
#
# **Что сдать:** код расширенного приложения, скриншоты работы.

# %%
# Ваш код решения задачи:

# %% [markdown]
# ## Критерии оценки
#
# | Компонент | Процент | Описание |
# |-----------|---------|----------|
# | Теоретические вопросы (Часть 1) | 15% | Полнота и правильность ответов |
# | Задание 1 (установка среды) | 5% | Корректность установки, скриншоты |
# | Задание 2 (Hello, World!) | 5% | Работающее приложение, скриншот |
# | Задание 3 (анализ эмоций) | 15% | Корректность кода, кеширование, интерфейс |
# | Задание 4 (Gradio) | 10% | Работающее приложение, сравнительный анализ |
# | Задание 5 (6 функций) | 20% | Полнота функций, мультиязычность, качество кода |
# | Задание 6 (деплой) | 10% | GitHub-репозиторий, публичная ссылка |
# | Задание 7 (этический протокол) | 20% | Полнота, аргументированность, практичность |
# | Задание 8 (бонус) | +5% | Расширенный функционал, качество кода |
#
# ---
#
# ## Требования к сдаче
#
# - Пришлите **один ZIP-архив** или **ссылку на GitHub-репозиторий** со всеми файлами проекта.
# - Файлы должны включать:
#   - `app.py` (или `app_psychology.py`) — основной код.
#   - `app_gradio.py` (если выполнено Задание 4).
#   - `requirements.txt`.
#   - `.gitignore`.
#   - `README.md` с описанием проекта.
# - Скриншоты вставьте в отдельный файл (Word/PDF) или в `README.md`.
# - Этический протокол (Задание 7) приложите отдельным файлом (PDF/DOCX).
# - Убедитесь, что код выполняется без ошибок.
#
# ---
#
# ## Заключение
#
# Данная практическая работа проведёт вас через весь цикл создания веб-приложения для психологических задач — от установки VS Code до деплоя в интернет. Вы создадите не один, а несколько приложений (Streamlit, Gradio, полнофункциональный инструмент с 6 задачами) и освоите все ключевые навыки, необходимые современному психологу-разработчику.
#
# **Главный вывод:** модель — это ещё не инструмент. Инструмент появляется, когда у модели есть интерфейс. Streamlit и Gradio позволяют сделать этот шаг за несколько часов, даже если вы никогда не занимались веб-разработкой. Но с возможностью публикации приходит и ответственность — за конфиденциальность данных, точность результатов и этичность использования.
#
# ---
#
# **Срок выполнения: 2 недели.**
