# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/BioChem/BioCase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case для биохимиков 1 курса
#
#
# ## Часть 1. Базовые выборы (BioCase1–BioCase5)
#
# **BioCase1.** Дано целое число 1–7 — **день недели** для планирования эксперимента. Вывести название дня: 1 — «понедельник», 2 — «вторник», …, 7 — «воскресенье».
#
# ```
# Вход:  3
# Выход: среда
# ```
#
# **BioCase2.** Дано целое число $K$ — **оценка качества образца** (1–5). Вывести строку-описание:
# - 1 — «брак»
# - 2 — «неудовлетворительно»
# - 3 — «удовлетворительно»
# - 4 — «хорошо»
# - 5 — «отлично»
#
# Если $K$ не в диапазоне 1–5 — вывести «ошибка».
#
# ```
# Вход:  4
# Выход: хорошо
# ```
#
# **BioCase3.** Дан номер месяца (1–12) — **месяц сбора образцов**. Вывести сезон:
# - 12, 1, 2 — «зима»
# - 3, 4, 5 — «весна»
# - 6, 7, 8 — «лето»
# - 9, 10, 11 — «осень»
#
# ```
# Вход:  4
# Выход: весна
# ```
#
# **BioCase4.** Дан номер месяца (1–12). Определить **количество дней** в этом месяце для невисокосного года (для планирования длительности эксперимента).
#
# ```
# Вход:  2
# Выход: 28
# ```
#
# **BioCase5.** Даны номер действия $N$ (1–4) и два числа $A$ и $B$. Выполнить операцию:
# - 1 — сложение ($A + B$)
# - 2 — вычитание ($A - B$)
# - 3 — умножение ($A \cdot B$)
# - 4 — деление ($A / B$, $B \ne 0$)
#
# Вывести результат (калькулятор для обработки данных).
#
# ```
# Вход:  N = 3, A = 2.5, B = 4.0
# Выход: 10.0
# ```
#
# ---
#
# ## Часть 2. Единицы измерения (BioCase6–BioCase7)
#
# **BioCase6.** Даны номер единицы **концентрации** (1–5) и значение $C$:
# - 1 — моль/л (М)
# - 2 — ммоль/л (мМ)
# - 3 — мкмоль/л (мкМ)
# - 4 — нмоль/л (нМ)
# - 5 — пикомоль/л (пМ)
#
# Перевести концентрацию в **моль/л**.
#
# $$1 \text{ М} = 1, \quad 1 \text{ мМ} = 10^{-3}, \quad 1 \text{ мкМ} = 10^{-6}, \quad 1 \text{ нМ} = 10^{-9}, \quad 1 \text{ пМ} = 10^{-12}$$
#
# ```
# Вход:  N = 3, C = 500
# Выход: 5e-4
# ```
#
# **BioCase7.** Даны номер единицы **массы** (1–5) и масса $m$:
# - 1 — килограмм (кг)
# - 2 — миллиграмм (мг)
# - 3 — грамм (г)
# - 4 — микрограмм (мкг)
# - 5 — нанограмм (нг)
#
# Перевести массу в **граммы**.
#
# $$1 \text{ кг} = 1000, \quad 1 \text{ мг} = 10^{-3}, \quad 1 \text{ г} = 1, \quad 1 \text{ мкг} = 10^{-6}, \quad 1 \text{ нг} = 10^{-9}$$
#
# ```
# Вход:  N = 2, m = 250
# Выход: 0.25
# ```
#
# ---
#
# ## Часть 3. Даты эксперимента (BioCase8–BioCase9)
#
# **BioCase8.** Даны два целых числа: $D$ (день) и $M$ (месяц) — **дата начала эксперимента**. Вывести дату **предыдущего дня** (для планирования забора образцов).
#
# ```
# Вход:  D = 1, M = 3
# Выход: D = 28, M = 2
# ```
#
# **BioCase9.** Даны два целых числа: $D$ (день) и $M$ (месяц) — **дата начала эксперимента**. Вывести дату **следующего дня** (для планирования следующего этапа).
#
# ```
# Вход:  D = 28, M = 2
# Выход: D = 1, M = 3
# ```
#
# ---
#
# ## Часть 4. Режимы оборудования (BioCase10–BioCase11)
#
# **BioCase10.** Термостат может работать в четырёх режимах («Н» — нагрев, «О» — охлаждение, «С» — стабилизация, «В» — выключен) и принимать три команды:
# - 0 — продолжить текущий режим
# - 1 — переключить на следующий режим
# - −1 — переключить на предыдущий режим
#
# Даны символ $C$ — текущий режим и целое число $N$ — команда. Вывести режим после выполнения команды.
#
# ```
# Вход:  C = 'Н', N = 1
# Выход: О
# ```
#
# **BioCase11.** Спектрофотометр ориентирован на одну из длин волн («У» — УФ 260 нм, «В» — видимая 595 нм, «И» — ИК 900 нм, «Ф» — флуоресценция 485 нм) и может принимать команды поворота:
# - 1 — следующая длина волны
# - −1 — предыдущая длина волны
# - 2 — поворот на 180° (противоположная)
#
# Даны символ $C$ — текущий режим и целые числа $N_1, N_2$ — две команды. Вывести режим после выполнения команд.
#
# ```
# Вход:  C = 'У', N1 = 1, N2 = 1
# Выход: И
# ```
#
# ---
#
# ## Часть 5. Параметры кинетики (BioCase12–BioCase14)
#
# **BioCase12.** Элементы ферментативной кинетики пронумерованы:
# - 1 — $V_{max}$ (мкмоль/мин)
# - 2 — $K_m$ (мМ)
# - 3 — $k_{cat}$ (с⁻¹)
# - 4 — $k_{cat}/K_m$ (М⁻¹·с⁻¹)
#
# Даны номер одного из этих элементов и его значение, а также известные $[E] = 1$ мкМ, $V_{max} = 100$, $K_m = 1$. Вывести значения остальных элементов.
#
# ```
# Вход:  N = 1, значение = 100
# Выход: Vmax = 100, Km = 1, kcat = 100, kcat/Km = 100000
# ```
#
# **BioCase13.** Элементы **серии разведений** пронумерованы:
# - 1 — фактор разведения $DF$
# - 2 — исходная концентрация $C_0$
# - 3 — конечная концентрация $C_1$
# - 4 — объём аликвоты $V_{al}$
# - 5 — общий объём $V_{tot}$
#
# Даны номер одного из элементов и его значение, а также недостающие параметры. Вывести значения остальных.
#
# $$DF = \frac{V_{tot}}{V_{al}}, \quad C_1 = \frac{C_0}{DF}$$
#
# ```
# Вход:  N = 1, DF = 10, C0 = 1.0, Val = 10, Vtot = 100
# Выход: DF = 10, C0 = 1.0, C1 = 0.1, Val = 10, Vtot = 100
# ```
#
# **BioCase14.** Элементы **серийного разведения** (2-кратного) пронумерованы:
# - 1 — начальная концентрация $C_0$
# - 2 — концентрация после 1-го разведения
# - 3 — после 2-го
# - 4 — после 3-го
# - 5 — после $N$-го
#
# Дано $N$ и $C_0$. Вывести концентрацию после $N$-го разведения.
#
# $$C_N = \frac{C_0}{2^N}$$
#
# ```
# Вход:  N = 3, C0 = 8
# Выход: 1.0
# ```
#
# ---
#
# ## Часть 6. Аминокислоты и кодоны (BioCase15–BioCase17)
#
# **BioCase15.** Дана **таблица соответствия**:
# ```
# 1=A, 2=R, 3=N, 4=D, 5=C, 6=Q, 7=E, 8=G, 9=H, 10=I,
# 11=L, 12=K, 13=M, 14=F, 15=P, 16=S, 17=T, 18=W, 19=Y, 20=V
# ```
# Даны $N$ (1–20) — номер аминокислоты и $M$ (1–4) — тип модификации:
# - 1 — немодифицированная
# - 2 — фосфорилированная
# - 3 — метилированная
# - 4 — ацетилированная
#
# Вывести название модифицированной аминокислоты (например, «фосфосерин», «метиллизин»).
#
# ```
# Вход:  N = 16 (S), M = 2
# Выход: фосфосерин
# ```
#
# **BioCase16.** Дан номер типа клеток (1–4). Вывести **метод лизиса**:
# - 1 — бактерии: «лизоцим + EDTA»
# - 2 — дрожжи: «гомогенизация + ферменты»
# - 3 — клетки млекопитающих: «детергент»
# - 4 — растительные: «жидкий азот + гомогенизация»
#
# ```
# Вход:  1
# Выход: лизоцим + EDTA
# ```
#
# **BioCase17.** Дано целое число в диапазоне 1–64 — **номер кодона** в генетическом коде. Вывести соответствующую аминокислоту (однобуквенный код).
#
# ```
# Вход:  1 (UUU)
# Выход: F (фенилаланин)
# ```
#
# ---
#
# ## Часть 7. Методы анализа (BioCase18–BioCase20)
#
# **BioCase18.** Дан номер аналита (1–5). Вывести **метод анализа**:
# - 1 — глюкоза: «глюкозооксидазный»
# - 2 — белок: «Брэдфорд»
# - 3 — ДНК: «A260»
# - 4 — РНК: «A260»
# - 5 — липиды: «сульфофосфованилиновый»
#
# ```
# Вход:  2
# Выход: Брэдфорд
# ```
#
# **BioCase19.** Дан номер типа бактерий (1–4). Вывести **рекомендуемый антибиотик**:
# - 1 — грамположительные: «ампициллин»
# - 2 — грамотрицательные: «канамицин»
# - 3 — микоплазмы: «тетрациклин»
# - 4 — анаэробы: «хлорамфеникол»
#
# ```
# Вход:  1
# Выход: ампициллин
# ```
#
# **BioCase20.** Дан номер сайта узнавания (1–4). Вывести **рестриктазу**:
# - 1 — GAATTC: «EcoRI»
# - 2 — GGATCC: «BamHI»
# - 3 — AAGCTT: «HindIII»
# - 4 — GCGGCCGC: «NotI»
#
# ```
# Вход:  1
# Выход: EcoRI
# ```
#
# ---
#
# ## Часть 8. Дополнительные биохимические задачи (BioCase21–BioCase40)
#
# **BioCase21.** Дан номер диапазона pH (1–5). Вывести **буферную систему**:
# - 1 — ацетатный (pH 3.6–5.6)
# - 2 — фосфатный (pH 5.8–8.0)
# - 3 — Tris-HCl (pH 7.0–9.0)
# - 4 — глициновый (pH 8.6–10.6)
# - 5 — карбонатный (pH 9.2–10.8)
#
# ```
# Вход:  3
# Выход: Tris-HCl
# ```
#
# **BioCase22.** Дан номер типа ротора (1–4). Вывести **максимальную скорость** (об/мин):
# - 1 — фиксированный угол: 15 000
# - 2 — качающийся: 10 000
# - 3 — вертикальный: 20 000
# - 4 — зональный: 40 000
#
# ```
# Вход:  2
# Выход: 10000
# ```
#
# **BioCase23.** Дан номер типа детергента (1–4). Вывести его **назначение**:
# - 1 — SDS: денатурирующий
# - 2 — Triton X-100: мягкий неионный
# - 3 — Tween-20: мягкий неионный
# - 4 — CHAPS: цвиттер-ионный
#
# ```
# Вход:  1
# Выход: денатурирующий
# ```
#
# **BioCase24.** Дан номер типа хроматографии (1–5). Вывести **принцип разделения**:
# - 1 — ионообменная: по заряду
# - 2 — гель-фильтрация: по размеру
# - 3 — аффинная: по сродству
# - 4 — обращённо-фазовая: по гидрофобности
# - 5 — гидрофобная: по гидрофобности
#
# ```
# Вход:  2
# Выход: по размеру
# ```
#
# **BioCase25.** Дан номер антибиотика (1–5). Вывести **механизм действия**:
# - 1 — ампициллин: ингибирует синтез клеточной стенки
# - 2 — канамицин: ингибирует синтез белка
# - 3 — тетрациклин: ингибирует синтез белка
# - 4 — хлорамфеникол: ингибирует синтез белка
# - 5 — ципрофлоксацин: ингибирует ДНК-гиразу
#
# ```
# Вход:  1
# Выход: ингибирует синтез клеточной стенки
# ```
#
# **BioCase26.** Дан номер рестриктазы (1–4). Вывести её **сайт узнавания**:
# - 1 — EcoRI: GAATTC
# - 2 — BamHI: GGATCC
# - 3 — HindIII: AAGCTT
# - 4 — NotI: GCGGCCGC
#
# ```
# Вход:  1
# Выход: GAATTC
# ```
#
# **BioCase27.** Дан номер ДНК-полимеразы (1–4). Вывести её **применение**:
# - 1 — Taq: ПЦР
# - 2 — Pfu: ПЦР с высокой точностью
# - 3 — Klenow: достройка концов
# - 4 — T4: заполнение липких концов
#
# ```
# Вход:  1
# Выход: ПЦР
# ```
#
# **BioCase28.** Дан номер протеазы (1–4). Вывести **сайт расщепления**:
# - 1 — трипсин: после Lys/Arg
# - 2 — химотрипсин: после Phe/Tyr/Trp
# - 3 — пепсин: после Leu/Phe
# - 4 — V8: после Glu
#
# ```
# Вход:  1
# Выход: после Lys/Arg
# ```
#
# **BioCase29.** Дан номер метода окрашивания (1–4). Вывести **что окрашивает**:
# - 1 — Кумасси: белки
# - 2 — SYBR Green: ДНК
# - 3 — Ponceau: белки
# - 4 — DAPI: ДНК
#
# ```
# Вход:  2
# Выход: ДНК
# ```
#
# **BioCase30.** Дан номер буфера для электрофореза (1–4). Вывести **pH**:
# - 1 — TAE: 8.0
# - 2 — TBE: 8.3
# - 3 — MOPS: 7.0
# - 4 — Tris-глицин: 8.3
#
# ```
# Вход:  1
# Выход: 8.0
# ```
#
# **BioCase31.** Дан номер метода детекции в Western blot (1–4). Вывести **тип детекции**:
# - 1 — ECL: хемилюминесценция
# - 2 — DAB: колориметрия
# - 3 — BCIP/NBT: колориметрия
# - 4 — флуоресценция: флуоресценция
#
# ```
# Вход:  1
# Выход: хемилюминесценция
# ```
#
# **BioCase32.** Дан номер типа матрицы для ПЦР (1–4). Вывести **программу амплификации**:
# - 1 — плазмида: 30 циклов
# - 2 — геномная ДНК: 35 циклов
# - 3 — кДНК: 40 циклов
# - 4 — олигонуклеотид: 25 циклов
#
# ```
# Вход:  2
# Выход: 35 циклов
# ```
#
# **BioCase33.** Дан номер типа клеток (1–4). Вывести **метод лизиса**:
# - 1 — бактерии: лизоцим + EDTA
# - 2 — дрожжи: гомогенизация + ферменты
# - 3 — клетки млекопитающих: детергент
# - 4 — растительные: жидкий азот + гомогенизация
#
# ```
# Вход:  1
# Выход: лизоцим + EDTA
# ```
#
# **BioCase34.** Дан номер аффинной метки (1–4). Вывести **метод очистки**:
# - 1 — His-tag: Ni-NTA
# - 2 — GST-tag: глутатион-сефароза
# - 3 — MBP-tag: амилоза
# - 4 — FLAG-tag: анти-FLAG
#
# ```
# Вход:  1
# Выход: Ni-NTA
# ```
#
# **BioCase35.** Дан номер аналита (1–4). Вывести **метод анализа**:
# - 1 — глюкоза: глюкозооксидаза
# - 2 — белок: Брэдфорд
# - 3 — ДНК: A260
# - 4 — РНК: A260
#
# ```
# Вход:  2
# Выход: Брэдфорд
# ```
#
# **BioCase36.** Дан номер хозяина для антител (1–4). Вывести **вид животного**:
# - 1 — кролик
# - 2 — мышь
# - 3 — коза
# - 4 — овца
#
# ```
# Вход:  1
# Выход: кролик
# ```
#
# **BioCase37.** Дан номер организма (1–4). Вывести **питательную среду**:
# - 1 — E. coli: LB
# - 2 — дрожжи: YPD
# - 3 — клетки млекопитающих: DMEM
# - 4 — грибы: PDA
#
# ```
# Вход:  1
# Выход: LB
# ```
#
# **BioCase38.** Дан номер материала (1–4). Вывести **метод стерилизации**:
# - 1 — стекло: автоклавирование
# - 2 — пластик: УФ
# - 3 — растворы: фильтрация 0.22 мкм
# - 4 — металл: сухой жар
#
# ```
# Вход:  3
# Выход: фильтрация 0.22 мкм
# ```
#
# **BioCase39.** Дан номер типа метки (1–4). Вывести **метод детекции**:
# - 1 — флуоресцентная: «флуориметр»
# - 2 — радиоактивная: «авторадиография»
# - 3 — колориметрическая: «спектрофотометр»
# - 4 — хемилюминесцентная: «ECL»
#
# ```
# Вход:  4
# Выход: ECL
# ```
#
# **BioCase40.** Дан номер типа образца (1–5). Вывести **температуру хранения**:
# - 1 — ДНК: −20 °C
# - 2 — РНК: −80 °C
# - 3 — белок: −80 °C
# - 4 — клетки: −196 °C (жидкий азот)
# - 5 — сыворотка: −20 °C
#
# ```
# Вход:  1
# Выход: -20 °C
# ```
