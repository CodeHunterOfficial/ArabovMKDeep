# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/BioChem/BioInt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  «Целые числа» для биохимиков 1 курса
#
#
# ## Блок 1. Простые задачи (BioInt1–BioInt20)
#
# ### Работа с кодами образцов
#
# **BioInt1.** В криохранилище каждая пробирка имеет **трёхзначный код**: первая цифра — номер стеллажа, вторая — номер полки, третья — номер позиции. При сканировании штрих-кода сканер иногда ошибается и **сдвигает цифры вправо**: последняя цифра переходит в начало. Дано считанное трёхзначное число `code`. Восстановите **правильный код пробирки**.
#
# ```
# Вход:  312
# Выход: 231
# ```
#
# **BioInt2.** В лаборатории принята система кодирования: **трёхзначный номер образца**, где первая цифра — тип ткани, вторая — номер пациента, третья — номер аликвоты. При ручном вводе лаборант перепутал **первую и вторую** цифры. Дано ошибочно введённое число. Выведите **правильный номер образца** (перестановка сотен и десятков).
#
# ```
# Вход:  213
# Выход: 123
# ```
#
# **BioInt3.** В той же системе лаборант перепутал **вторую и третью** цифры (десятки и единицы). Дано ошибочно введённое число. Выведите **правильный номер**.
#
# ```
# Вход:  132
# Выход: 123
# ```
#
# **BioInt4.** В криохранилище **пятизначный код** пробирки: первые две цифры — номер стеллажа, следующие две — номер ящика, последняя — номер позиции. Дано число `N > 9999` — код пробирки. Используя **не более двух операций div/mod**, найдите **номер ящика** (две цифры).
#
# ```
# Вход:  12345
# Выход: 34
# ```
#
# **BioInt5.** В той же системе кодирования дано число `N > 9999`. Используя **не более двух операций div/mod**, найдите **номер стеллажа** (две цифры).
#
# ```
# Вход:  12345
# Выход: 12
# ```
#
# **BioInt6.** В лабораторном журнале регистрируется **общее время инкубации в секундах** (`N`). Лаборанту нужно записать **количество полных минут** инкубации для отчёта.
#
# ```
# Вход:  185
# Выход: 3
# ```
#
# **BioInt7.** Дано общее время **ферментативной реакции** в секундах (`N`). Найдите **количество полных часов** реакции.
#
# ```
# Вход:  7325
# Выход: 2
# ```
#
# **BioInt8.** Дано время **культивирования клеток** в секундах (`N`). Найдите **количество секунд, прошедших с начала последней минуты** (остаток от деления на 60).
#
# ```
# Вход:  185
# Выход: 5
# ```
#
# **BioInt9.** Дано время **хроматографии** в секундах (`N`). Найдите **количество секунд, прошедших с начала последнего часа** (остаток от деления на 3600).
#
# ```
# Вход:  7325
# Выход: 125
# ```
#
# **BioInt10.** Дано время **ПЦР-программы** в секундах (`N`). Найдите **количество полных минут, прошедших с начала последнего часа**.
#
# ```
# Вход:  7325
# Выход: 2
# ```
#
# ### Планирование эксперимента
#
# **BioInt11.** Эксперимент длится 365 дней. Известно, что **1 января — понедельник**. Дано `K` — номер дня, когда был поставлен опыт. Определите **день недели** (0 — воскресенье, 1 — понедельник, …, 6 — суббота). Выведите также **1, если это рабочий день** (пн–пт), и **0, если выходной**.
#
# ```
# Вход:  K = 1
# Выход: день = 1, рабочий = 1
# ```
#
# **BioInt12.** То же, но **1 января — четверг**.
#
# ```
# Вход:  K = 1
# Выход: день = 4, рабочий = 1
# ```
#
# **BioInt13.** Дни недели: 1 — понедельник, …, 7 — воскресенье. **1 января — вторник**. Дано `K` — номер дня года. Определите день недели.
#
# ```
# Вход:  K = 1
# Выход: 2
# ```
#
# **BioInt14.** То же, но **1 января — суббота**.
#
# ```
# Вход:  K = 1
# Выход: 6
# ```
#
# **BioInt15.** Дни недели: 1 — понедельник, …, 7 — воскресенье. Дано `K` — номер дня года и `N` — номер дня недели 1 января (1–7). Определите номер дня недели для K-го дня.
#
# ```
# Вход:  K = 100, N = 3
# Выход: 4
# ```
#
# ### Раскладка и оборудование
#
# **BioInt16.** В штативе размером **A × B лунок** нужно разместить **квадратные подложки** размером **C × C лунок** (без наложений). Найдите **максимальное количество подложек** и **количество свободных лунок**.
#
# ```
# Вход:  A = 10, B = 8, C = 3
# Выход: подложек = 6, свободных = 26
# ```
#
# **BioInt17.** В лаборатории есть **центрифуга**, год выпуска которой известен. Для метрологического отчёта нужно указать **век выпуска** (1901 — XX век). Дан год выпуска (целое положительное). Выведите номер века.
#
# ```
# Вход:  1995
# Выход: 20
# ```
#
# ### Работа с номерами
#
# **BioInt18.** Дано трёхзначное число — **номер аминокислоты** в белке. Выведите число, полученное при перестановке **первой и последней** цифр (например, 123 → 321).
#
# ```
# Вход:  123
# Выход: 321
# ```
#
# **BioInt19.** Дано четырёхзначное число — **номер нуклеотида** в гене. Найдите **сумму его цифр**.
#
# ```
# Вход:  1234
# Выход: 10
# ```
#
# **BioInt20.** Дано трёхзначное число — **код штамма**. Найдите **произведение его цифр**.
#
# ```
# Вход:  234
# Выход: 24
# ```
#
# ---
#
# ## Блок 2. Посложнее (BioInt21–BioInt40)
#
# ### Время и форматы
#
# **BioInt21.** Ферментативная реакция инкубируется при 37 °C. В журнале регистрируется **общее время инкубации в секундах** (`N`). Лаборанту нужно записать время в формате **ЧЧ:ММ:СС** для отчёта. Выведите время в этом формате.
#
# ```
# Вход:  7325
# Выход: 02:02:05
# ```
#
# **BioInt22.** Дано время **культивирования клеток** в секундах (`N`). Найдите **количество полных суток**, прошедших с начала культивирования.
#
# ```
# Вход:  200000
# Выход: 2
# ```
#
# **BioInt23.** Дано время **эксперимента** в секундах (`N`). Найдите **количество секунд, прошедших с начала последних суток**.
#
# ```
# Вход:  200000
# Выход: 27200
# ```
#
# **BioInt24.** Дано время **ПЦР-программы** в секундах (`N`). Найдите **количество полных минут, прошедших с начала последних суток**.
#
# ```
# Вход:  200000
# Выход: 453
# ```
#
# ### Циклические сдвиги и разряды
#
# **BioInt25.** Дано трёхзначное число — **номер пробирки**. При сканировании произошёл **циклический сдвиг вправо**: 123 → 312. Дано считанное число. Восстановите **исходный номер** (сдвиг влево).
#
# ```
# Вход:  312
# Выход: 123
# ```
#
# **BioInt26.** Дано трёхзначное число — **код образца**. При сканировании произошёл **циклический сдвиг влево**: 123 → 231. Дано считанное число. Восстановите **исходный код** (сдвиг вправо).
#
# ```
# Вход:  231
# Выход: 123
# ```
#
# **BioInt27.** Дано четырёхзначное число — **номер фракции** в хроматографии. Найдите цифру, соответствующую разряду **десятков**, используя не более двух операций div/mod.
#
# ```
# Вход:  1234
# Выход: 3
# ```
#
# **BioInt28.** Дано четырёхзначное число — **номер колонки** в HPLC. Найдите цифру, соответствующую разряду **сотен**.
#
# ```
# Вход:  1234
# Выход: 2
# ```
#
# **BioInt29.** Дано целое число `N > 999` — **общее число клеток** в камере. Найдите **сумму цифр** в разрядах сотен и тысяч.
#
# ```
# Вход:  1234
# Выход: 3
# ```
#
# **BioInt30.** Дано целое число `N > 999` — **число молекул**. Найдите **произведение цифр** в разрядах сотен и тысяч.
#
# ```
# Вход:  1234
# Выход: 2
# ```
#
# ### Недели и дни недели
#
# **BioInt31.** Дано время **реакции** в секундах (`N`). Определите, сколько **полных недель** прошло с начала реакции.
#
# ```
# Вход:  1209600
# Выход: 2
# ```
#
# **BioInt32.** Дано время **культивирования** в секундах (`N`). Эксперимент начался **в понедельник**. Найдите номер **дня недели** (0 — воскресенье, …, 6 — суббота).
#
# ```
# Вход:  172800
# Выход: 2
# ```
#
# **BioInt33.** Дано время **эксперимента** в секундах (`N`), который начался **в среду** (день недели = 3). Найдите текущий день недели (0 — воскресенье, …, 6 — суббота).
#
# ```
# Вход:  172800
# Выход: 5
# ```
#
# ### Проверки и остатки
#
# **BioInt34.** Дано трёхзначное число — **номер аминокислоты**. Проверьте, является ли **сумма его цифр** чётной. Выведите `True` или `False`.
#
# ```
# Вход:  123
# Выход: True
# ```
#
# **BioInt35.** Дано трёхзначное число — **код штамма**. Проверьте, является ли **произведение его цифр** кратным 3. Выведите `True` или `False`.
#
# ```
# Вход:  234
# Выход: True
# ```
#
# **BioInt36.** Дано целое число `N > 999` — **число клеток**. Найдите **разность** между цифрой тысяч и цифрой сотен.
#
# ```
# Вход:  1234
# Выход: -1
# ```
#
# **BioInt37.** Дано целое число `N > 999` — **число молекул**. Найдите **остаток** от деления числа, образованного цифрами тысяч и сотен, на 7.
#
# ```
# Вход:  1234
# Выход: 5
# ```
#
# ### Циклы
#
# **BioInt38.** Дано время **ферментативной реакции** в секундах (`N`). Один цикл реакции длится **45 секунд**. Найдите **количество полных циклов**.
#
# ```
# Вход:  200
# Выход: 4
# ```
#
# **BioInt39.** Дано время **ПЦР-программы** в секундах (`N`). Один цикл длится **120 секунд**. Найдите **номер текущего цикла** (нумерация с 1).
#
# ```
# Вход:  200
# Выход: 2
# ```
#
# **BioInt40.** Дано целое число `N > 9999` — **общее число нуклеотидов** в гене. Найдите **цифру в разряде десяти тысяч**, используя не более двух операций div/mod.
#
# ```
# Вход:  12345
# Выход: 1
# ```
