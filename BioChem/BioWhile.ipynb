# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/BioChem/BioWhile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #While для биохимиков 1 курса
#
# ## Часть 1. Деление без операций (BioWhile1–BioWhile3)
#
# **BioWhile1.** Даны положительные числа $A$ и $B$ ($A > B$) — общий объём реакционной смеси (мкл) и объём одной аликвоты (мкл). Не используя операции умножения и деления, найти **объём остатка** после отбора максимального числа полных аликвот.
#
# ```
# Вход:  A = 17, B = 5
# Выход: 2
# ```
#
# **BioWhile2.** Даны положительные числа $A$ и $B$ ($A > B$) — общий объём смеси и объём одной аликвоты. Не используя операции умножения и деления, найти **количество полных аликвот**, которые можно отобрать.
#
# ```
# Вход:  A = 17, B = 5
# Выход: 3
# ```
#
# **BioWhile3.** Даны целые положительные числа $N$ и $K$ — общее число молекул и размер одной порции. Используя только операции сложения и вычитания, найти **частное** и **остаток** от деления $N$ на $K$ (модель распределения молекул по пробиркам).
#
# ```
# Вход:  N = 17, K = 5
# Выход: частное = 3, остаток = 2
# ```
#
# ---
#
# ## Часть 2. Степени и факториалы (BioWhile4–BioWhile6)
#
# **BioWhile4.** Дано целое число $N > 0$ — число клеток. Если оно является **степенью числа 3** (равновесное деление), вывести TRUE, иначе — FALSE.
#
# ```
# Вход:  N = 27
# Выход: TRUE
# ```
#
# **BioWhile5.** Дано целое число $N > 0$, являющееся некоторой **степенью числа 2** (модель бинарного деления): $N = 2^K$. Найти целое число $K$ — **число делений**.
#
# ```
# Вход:  N = 32
# Выход: 5
# ```
#
# **BioWhile6.** Дано целое число $N > 0$ — число мономеров. Найти **двойной факториал** $N!! = N \cdot (N-2) \cdot (N-4) \cdot \ldots$ (последний сомножитель равен 2, если $N$ чётное, и 1, если $N$ нечётное) — модель сборки димеров. Использовать вещественную переменную.
#
# ```
# Вход:  N = 6
# Выход: 48.0
# ```
#
# ---
#
# ## Часть 3. Квадратные корни и степени (BioWhile7–BioWhile10)
#
# **BioWhile7.** Дано целое число $N > 0$ — число клеток. Найти **наименьшее** целое $K$, квадрат которого превосходит $N$: $K^2 > N$ (модель оценки размера колонии). Функцию извлечения квадратного корня не использовать.
#
# ```
# Вход:  N = 20
# Выход: 5
# ```
#
# **BioWhile8.** Дано целое число $N > 0$. Найти **наибольшее** целое $K$, квадрат которого не превосходит $N$: $K^2 \le N$.
#
# ```
# Вход:  N = 20
# Выход: 4
# ```
#
# **BioWhile9.** Дано целое число $N > 1$ — число клеток. Найти **наименьшее** целое $K$, при котором $3^K > N$ (модель оценки числа делений при тройном делении).
#
# ```
# Вход:  N = 50
# Выход: 4
# ```
#
# **BioWhile10.** Дано целое число $N > 1$. Найти **наибольшее** целое $K$, при котором $3^K < N$.
#
# ```
# Вход:  N = 50
# Выход: 3
# ```
#
# ---
#
# ## Часть 4. Суммы и накопления (BioWhile11–BioWhile14)
#
# **BioWhile11.** Дано целое число $N > 1$ — целевой объём (мкл). Найти **наименьшее** целое $K$, для которого сумма $1 + 2 + \ldots + K \ge N$ (модель накопления объёма при последовательном добавлении), и саму эту сумму.
#
# ```
# Вход:  N = 10
# Выход: K = 4, сумма = 10
# ```
#
# **BioWhile12.** Дано целое число $N > 1$. Найти **наибольшее** целое $K$, для которого сумма $1 + 2 + \ldots + K \le N$, и саму эту сумму.
#
# ```
# Вход:  N = 10
# Выход: K = 4, сумма = 10
# ```
#
# **BioWhile13.** Дано число $A > 1$ — целевой уровень накопления. Найти **наименьшее** целое $K$, для которого сумма $1 + 1/2 + \ldots + 1/K > A$ (модель накопления относительной ошибки), и саму эту сумму.
#
# ```
# Вход:  A = 2
# Выход: K = 4, сумма = 2.0833
# ```
#
# **BioWhile14.** Дано число $A > 1$. Найти **наибольшее** целое $K$, для которого сумма $1 + 1/2 + \ldots + 1/K < A$, и саму эту сумму.
#
# ```
# Вход:  A = 2
# Выход: K = 3, сумма = 1.8333
# ```
#
# ---
#
# ## Часть 5. Рост и накопление (BioWhile15–BioWhile16)
#
# **BioWhile15.** Начальная концентрация фермента в реакторе равна 1000 Ед. Каждый час активность увеличивается на $P$ процентов от текущей ($0 < P < 25$). По данному $P$ определить, через сколько часов активность превысит 1100 Ед., и вывести найденное количество часов $K$ и итоговую активность $S$.
#
# ```
# Вход:  P = 5
# Выход: K = 2, S = 1102.5
# ```
#
# **BioWhile16.** Культура клеток начинает рост с 10 единиц. Каждый следующий день прирост составляет $P$ процентов от предыдущего дня ($0 < P < 50$). По данному $P$ определить, после какого дня **суммарное** количество клеток превысит 200, и вывести количество дней $K$ и суммарное количество $S$.
#
# ```
# Вход:  P = 20
# Выход: K = 8, S = 205.8
# ```
#
# ---
#
# ## Часть 6. Цифры чисел (BioWhile17–BioWhile19)
#
# **BioWhile17.** Дано целое число $N > 0$ — код образца. Используя операции деления нацело и взятия остатка, вывести все его цифры, начиная с самой правой (разряда единиц) — модель декодирования штрих-кода.
#
# ```
# Вход:  N = 1234
# Выход: 4, 3, 2, 1
# ```
#
# **BioWhile18.** Дано целое число $N > 0$ — код образца. Найти **количество** и **сумму** его цифр (контрольная сумма для проверки целостности кода).
#
# ```
# Вход:  N = 1234
# Выход: количество = 4, сумма = 10
# ```
#
# **BioWhile19.** Дано целое число $N > 0$ — код образца. Найти число, полученное при прочтении числа $N$ **справа налево** (модель обратного кодирования).
#
# ```
# Вход:  N = 1234
# Выход: 4321
# ```
#
# ---
#
# ## Часть 7. Проверки цифр (BioWhile20–BioWhile21)
#
# **BioWhile20.** Дано целое число $N > 0$ — код образца. С помощью операций деления нацело и взятия остатка определить, **имеется ли** в записи числа цифра «2» (признак контрольной группы). Если имеется — вывести TRUE, если нет — FALSE.
#
# ```
# Вход:  N = 1234
# Выход: TRUE
# ```
#
# **BioWhile21.** Дано целое число $N > 0$ — код образца. Определить, имеются ли в записи числа **нечётные цифры** (признак опытной группы). Если имеются — TRUE, иначе — FALSE.
#
# ```
# Вход:  N = 2468
# Выход: FALSE
# ```
#
# ---
#
# ## Часть 8. Простые числа и НОД (BioWhile22–BioWhile23)
#
# **BioWhile22.** Дано целое число $N > 1$ — число клеток в микроколонии. Если оно является **простым** (то есть не имеет положительных делителей, кроме 1 и самого себя), вывести TRUE, иначе — FALSE.
#
# ```
# Вход:  N = 17
# Выход: TRUE
# ```
#
# **BioWhile23.** Даны целые положительные числа $A$ и $B$ — объёмы двух растворов. Найти их **наибольший общий делитель** (НОД), используя алгоритм Евклида (модель поиска общего фактора разведения):
#
# $$\text{НОД}(A, B) = \text{НОД}(B, A \bmod B), \text{ если } B \ne 0; \quad \text{НОД}(A, 0) = A$$
#
# ```
# Вход:  A = 48, B = 36
# Выход: 12
# ```
#
# ---
#
# ## Часть 9. Последовательность Фибоначчи (BioWhile24–BioWhile27)
#
# **BioWhile24.** Дано целое число $N > 1$. Последовательность чисел Фибоначчи моделирует **рост популяции клеток**:
#
# $$F_1 = 1, \quad F_2 = 1, \quad F_K = F_{K-2} + F_{K-1}, \quad K = 3, 4, \ldots$$
#
# Проверить, является ли число $N$ числом Фибоначчи. Если является — TRUE, иначе — FALSE.
#
# ```
# Вход:  N = 13
# Выход: TRUE
# ```
#
# **BioWhile25.** Дано целое число $N > 1$. Найти **первое** число Фибоначчи, большее $N$ (модель прогноза роста).
#
# ```
# Вход:  N = 10
# Выход: 13
# ```
#
# **BioWhile26.** Дано целое число $N > 1$, являющееся числом Фибоначчи: $N = F_K$. Найти целые числа $F_{K-1}$ и $F_{K+1}$ — **предыдущее** и **последующее** числа Фибоначчи (модель прогноза соседних поколений).
#
# ```
# Вход:  N = 13
# Выход: F(K-1) = 8, F(K+1) = 21
# ```
#
# **BioWhile27.** Дано целое число $N > 1$, являющееся числом Фибоначчи: $N = F_K$. Найти целое число $K$ — **порядковый номер** числа Фибоначчи (номер поколения).
#
# ```
# Вход:  N = 13
# Выход: 7
# ```
#
# ---
#
# ## Часть 10. Сходимость последовательностей (BioWhile28–BioWhile29)
#
# **BioWhile28.** Дано вещественное число $\varepsilon > 0$ — точность. Последовательность концентраций субстрата:
#
# $$A_1 = 2, \quad A_K = 2 + \frac{1}{A_{K-1}}, \quad K = 2, 3, \ldots$$
#
# Найти **первый** номер $K$, для которого $|A_K - A_{K-1}| < \varepsilon$, и вывести этот номер, а также $A_{K-1}$ и $A_K$ (модель установления стационарного состояния).
#
# ```
# Вход:  ε = 0.01
# Выход: K = 5, A(K-1) = 2.414, A(K) = 2.414
# ```
#
# **BioWhile29.** Дано вещественное число $\varepsilon > 0$. Последовательность:
#
# $$A_1 = 1, \quad A_2 = 2, \quad A_K = \frac{A_{K-2} + 2A_{K-1}}{3}, \quad K = 3, 4, \ldots$$
#
# Найти **первый** номер $K$, для которого $|A_K - A_{K-1}| < \varepsilon$, и вывести этот номер, а также $A_{K-1}$ и $A_K$ (модель сглаживания данных).
#
# ```
# Вход:  ε = 0.01
# Выход: K = 8, A(K-1) = 1.75, A(K) = 1.75
# ```
#
# ---
#
# ## Часть 11. Раскладка без умножения (BioWhile30)
#
# **BioWhile30.** Даны положительные числа $A, B, C$ — размеры планшета $A \times B$ и сторона квадратной зоны $C$. На прямоугольнике размещено максимально возможное количество квадратов $C \times C$ (без наложений). Найти **количество квадратов**. Операции умножения и деления не использовать.
#
# ```
# Вход:  A = 10, B = 8, C = 3
# Выход: 6
# ```
#
# ---
#
# ## Часть 12. Дополнительные биохимические задачи (BioWhile31–BioWhile40)
#
# **BioWhile31.** Дана начальная активность фермента $A_0$ (Ед) и период полуинактивации $t_{1/2}$ (ч). Найти **время** $t$, за которое активность упадёт ниже заданного порога $A_{min}$. Использовать цикл while.
#
# $$A_k = A_0 \cdot \left(\frac{1}{2}\right)^{k \cdot \Delta t / t_{1/2}}$$
#
# ```
# Вход:  A0 = 1000, Amin = 100, t1/2 = 2, Δt = 0.5
# Выход: t = 6.5
# ```
#
# **BioWhile32.** Дано начальное число клеток $N_0$ и время удвоения $t_d$ (мин). Найти **число поколений** $K$, необходимых для достижения $N_{target}$ клеток.
#
# $$N_K = N_0 \cdot 2^K \ge N_{target}$$
#
# ```
# Вход:  N0 = 100, Ntarget = 10000
# Выход: K = 7
# ```
#
# **BioWhile33.** Дана начальная концентрация субстрата $[S]_0$ (мМ). Каждую минуту фермент превращает 5% субстрата. Найти **время**, за которое концентрация упадёт ниже 50% от начальной.
#
# ```
# Вход:  [S]0 = 100
# Выход: t = 14 мин
# ```
#
# **BioWhile34.** Дано число $N > 0$ — общее количество нуклеотидов в гене. Используя только операции деления нацело на 2, найти **количество шагов**, за которое число станет равным 1 (модель бинарного деления).
#
# ```
# Вход:  N = 16
# Выход: 4
# ```
#
# **BioWhile35.** Даны начальный объём раствора $V_0$ (мкл) и объём испарения за час $v$ (мкл/ч). Найти **время**, за которое объём уменьшится вдвое.
#
# ```
# Вход:  V0 = 100, v = 5
# Выход: 10 ч
# ```
#
# **BioWhile36.** Дано число $N > 1$ — число клеток. Найти **сумму** $1 + 2 + \ldots + K$, где $K$ — наибольшее число, при котором сумма **не превышает** $N$ (модель распределения питательных веществ).
#
# ```
# Вход:  N = 15
# Выход: сумма = 15, K = 5
# ```
#
# **BioWhile37.** Дано число $A > 1$ — начальная активность. Каждый час активность умножается на 0.9 (инактивация 10%). Найти **наименьшее** $K$, при котором активность станет меньше $A/2$.
#
# ```
# Вход:  A = 1000
# Выход: K = 7
# ```
#
# **BioWhile38.** Дано целое число $N > 0$ — код образца. Определить, является ли он **палиндромом** (читается одинаково слева направо и справа налево). Если да — TRUE, иначе — FALSE.
#
# ```
# Вход:  N = 12321
# Выход: TRUE
# ```
#
# **BioWhile39.** Дано целое число $N > 0$ — число нуклеотидов. Найти **наибольшую** степень числа 4, не превосходящую $N$ (модель кодирования 4 нуклеотидами).
#
# ```
# Вход:  N = 50
# Выход: 16
# ```
#
# **BioWhile40.** Дано целое число $N > 1$ — число штаммов. Найти **количество простых чисел**, не превосходящих $N$ (модель отбора штаммов с простыми номерами).
#
# ```
# Вход:  N = 20
# Выход: 8 (2, 3, 5, 7, 11, 13, 17, 19)
# ```
