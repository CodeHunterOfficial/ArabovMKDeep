# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/Low_resource_language.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Низкоресурсные LLM, инструкции и бенчмарки
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | Bilingual Adaptation of Monolingual Foundation Models | Двуязычная адаптация одноязычных фундаментальных моделей | + | + | + | + |
# | Sherkala-Chat: Building a State-of-the-Art LLM for Kazakh in a Moderately Resourced Setting | Sherkala-Chat: создание современной LLM для казахского в условиях средней ресурсности | ± | + | ± | ± |
# | Instruction Tuning on Public Government and Cultural Data for Low-Resource Language: a Case Study in Kazakh | Инструкционная настройка на государственных и культурных данных для низкоресурсного языка: кейс казахского | + | + | + | + |
# | KazMMLU: Evaluating Language Models on Kazakh, Russian, and Regional Knowledge of Kazakhstan | KazMMLU: оценка языковых моделей на казахском, русском и региональных знаниях Казахстана | + | + | + | + |
# | Qorgau: Evaluating LLM Safety in Kazakh-Russian Bilingual Contexts | Qorgau: оценка безопасности LLM в казахско-русском двуязычном контексте | + | + | + | + |
# | ArabicMMLU: Assessing Massive Multitask Language Understanding in Arabic | ArabicMMLU: оценка массового многоэтапного понимания языка в арабском | + | + | + | + |
# | UrduMMLU: A Massive Multitask Benchmark for Urdu Language Understanding | UrduMMLU: массовый многоэтапный бенчмарк для понимания урду | + | + | + | + |
# | DialectalArabicMMLU: Benchmarking Dialectal Capabilities in Arabic and Multilingual Language Models | DialectalArabicMMLU: бенчмарк диалектных возможностей арабских и многоязычных моделей | + | + | + | + |
# | EXAMS: A Multi-Subject High School Examinations Dataset for Cross-Lingual and Multilingual Question Answering | EXAMS: многопредметный датасет школьных экзаменов для кросс-языкового и многоязычного QA | + | + | + | + |
# | EXAMS-V: A Multi-Discipline Multilingual Multimodal Exam Benchmark for Evaluating Vision Language Models | EXAMS-V: многодисциплинарный многоязычный мультимодальный экзаменационный бенчмарк для VLM | + | + | + | + |
# | BALSAM: A Platform for Benchmarking Arabic Large Language Models | BALSAM: платформа для бенчмаркинга арабских больших языковых моделей | + | + | + | + |
# | Jais and Jais-chat: Arabic-Centric Foundation and Instruction-Tuned Open Generative Large Language Models | Jais и Jais-chat: арабоцентричные открытые генеративные LLM | + | + | + | + |
# | Jais 2: A Family of Arabic-Centric Open Large Language Models | Jais 2: семейство арабоцентричных открытых LLM | + | + | + | + |
# | Atlas-Chat: Adapting Large Language Models for Low-Resource Moroccan Arabic Dialect | Atlas-Chat: адаптация LLM для низкоресурсного марокканского арабского диалекта | + | + | + | + |
# | Nile-Chat: Egyptian Language Models for Arabic and Latin Scripts | Nile-Chat: египетские языковые модели для арабской и латинской письменности | + | + | + | + |
# | Llama-3-Nanda-10B-Chat: An Open Generative Large Language Model for Hindi | Llama-3-Nanda-10B-Chat: открытая генеративная LLM для хинди | + | + | + | + |
#
# ## 2. Морфология, OCR, NER, машинный перевод
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | Feature-Rich Part-of-speech Tagging for Morphologically Complex Languages: Application to Bulgarian | Частеречная разметка с богатыми признаками для морфологически сложных языков: применение к болгарскому | + | + | + | + |
# | Feature-Rich Named Entity Recognition for Bulgarian Using Conditional Random Fields | Извлечение именованных сущностей для болгарского с богатыми признаками и CRF | + | + | + | + |
# | A Morpho-Syntactically Informed LSTM-CRF Model for Named Entity Recognition | Морфосинтаксически информированная LSTM-CRF модель для NER | + | + | + | + |
# | Post-OCR Text Correction for Bulgarian Historical Documents | Пост-OCR коррекция текста для болгарских исторических документов | + | + | + | + |
# | Translating from Morphologically Complex Languages: A Paraphrase-Based Approach | Перевод с морфологически сложных языков: подход на основе перефразирования | + | + | + | + |
# | A Hybrid Morpheme-Word Representation for Machine Translation of Morphologically Rich Languages | Гибридное морфемно-словное представление для машинного перевода морфологически богатых языков | + | + | + | + |
# | Analyzing the Use of Character-Level Translation with Sparse and Noisy Datasets | Анализ символьного перевода на разреженных и шумных данных | + | + | + | + |
# | Improving Statistical Machine Translation for a Resource-Poor Language Using Related Resource-Rich Languages | Улучшение статистического машинного перевода для низкоресурсного языка с использованием родственных богатых языков | + | + | + | + |
# | Enabling Medical Translation for Low-Resource Languages | Обеспечение медицинского перевода для низкоресурсных языков | + | + | + | + |
#
# ## 3. Фактчекинг, пропаганда, hate speech, misinformation
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | CheckThat! (серия CLEF) | CheckThat!: автоматическая идентификация и верификация утверждений | + | + | + | + |
# | ClaimRank: Detecting Check-Worthy Claims in Arabic and English | ClaimRank: обнаружение утверждений, достойных проверки, в арабском и английском | + | + | + | + |
# | UrduFactCheck: An Agentic Fact-Checking Framework for Urdu with Evidence Boosting and Benchmarking | UrduFactCheck: агентная система фактчекинга для урду с усилением доказательств и бенчмаркингом | + | + | + | + |
# | Factcheck-Bench: Fine-Grained Evaluation Benchmark for Automatic Fact-checkers | Factcheck-Bench: тонкий оценочный бенчмарк для автоматических фактчекеров | + | + | + | + |
# | OpenFactCheck: A Unified Framework for Factuality Evaluation of LLMs | OpenFactCheck: единая структура оценки фактичности LLM | + | + | + | + |
# | Loki: An Open-Source Tool for Fact Verification | Loki: открытый инструмент для верификации фактов | + | + | + | + |
# | FIRE: Fact-checking with Iterative Retrieval and Verification | FIRE: фактчекинг с итеративным поиском и верификацией | + | + | + | + |
# | Few-Shot Cross-Lingual Stance Detection with Sentiment-Based Pre-Training | Малошотное кросс-языковое определение позиции с предобучением на сентименте | + | + | + | + |
# | AraStance: A Multi-Country and Multi-Domain Dataset of Arabic Stance Detection for Fact Checking | AraStance: многострановой и многодоменный датасет арабского определения позиции для фактчекинга | + | + | + | + |
# | SemEval-2020 Task 11: Detection of Propaganda Techniques in News Articles | SemEval-2020 Task 11: обнаружение пропагандистских приёмов в новостях | + | + | + | + |
# | Fine-Grained Analysis of Propaganda in News Articles | Тонкий анализ пропаганды в новостных статьях | + | + | + | + |
# | Detecting Propaganda Techniques in Memes | Обнаружение пропагандистских приёмов в мемах | + | + | + | + |
# | ArAIEval Shared Task: Persuasion Techniques and Disinformation Detection in Arabic Text | ArAIEval: обнаружение приёмов убеждения и дезинформации в арабском тексте | + | + | + | + |
# | OffensEval / SemEval-2019 Task 6 / SemEval-2020 Task 12 | OffensEval: идентификация оскорбительного языка в соцсетях | + | + | + | + |
# | SOLID: A Large-Scale Semi-Supervised Dataset for Offensive Language Identification | SOLID: крупномасштабный полууправляемый датасет для идентификации оскорбительного языка | + | + | + | + |
# | MemeLens: Multilingual Multitask VLMs for Memes | MemeLens: многоязычные многоцелевые VLM для мемов | + | + | + | + |
# | MOMENTA: A Multimodal Framework for Detecting Harmful Memes and Their Targets | MOMENTA: мультимодальная структура для обнаружения вредных мемов и их целей | + | + | + | + |
#
# ## 4. QA, таблицы, финансы, медицина, образование
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | TART: An Open-Source Tool-Augmented Framework for Explainable Table-based Reasoning | TART: открытая инструментально-дополненная структура для объяснимого табличного рассуждения | + | + | + | + |
# | SCITAB: A Challenging Benchmark for Compositional Reasoning and Claim Verification on Scientific Tables | SCITAB: сложный бенчмарк для композиционного рассуждения и проверки утверждений по научным таблицам | + | + | + | + |
# | TABVERSE: Benchmarking Cross-Format Table Understanding in LLMs and VLMs | TABVERSE: бенчмарк кросс-форматного понимания таблиц в LLM и VLM | + | + | + | + |
# | FinChain: A Symbolic Benchmark for Verifiable Chain-of-Thought Financial Reasoning | FinChain: символьный бенчмарк для проверяемых цепочек финансовых рассуждений | + | + | + | + |
# | FinCARDS: Card-Based Analyst Reranking for Financial Document Question Answering | FinCARDS: карточный реранкинг аналитика для QA по финансовым документам | + | + | + | + |
# | FinMMEval 2026 Task 1/2: Multilingual Financial QA | FinMMEval 2026: многоязычный финансовый QA | + | + | + | + |
# | SAHM: A Benchmark for Arabic Financial and Shari'ah-Compliant Reasoning | SAHM: бенчмарк для арабских финансовых и шариатских рассуждений | + | + | + | + |
# | FinReporting: An Agentic Workflow for Localized Reporting of Cross-Jurisdiction Financial Disclosures | FinReporting: агентный workflow для локализованной отчётности по межюрисдикционным финансовым раскрытиям | + | + | + | + |
# | Leaf: Multiple-Choice Question Generation | Leaf: генерация вопросов с множественным выбором | + | + | + | + |
# | Generating Answer Candidates for Quizzes and Answer-Aware Question Generators | Генерация вариантов ответов для викторин и генераторы вопросов с учётом ответа | + | + | + | + |
# | SurgiQ: A Large-Scale Multi-Domain Benchmark for Evaluating Surgical Understanding in Large Language Models | SurgiQ: крупномасштабный многодоменный бенчмарк для оценки хирургического понимания в LLM | + | + | + | + |
# | CLExEval: A Human-in-the-Loop Framework for Qualitative Evaluation of LLM Clinical Reasoning | CLExEval: human-in-the-loop структура для качественной оценки клинического рассуждения LLM | + | + | + | + |
# | TOP-Training: Target-Oriented Pretraining for Medical Extractive Question Answering | TOP-Training: целевое предобучение для медицинского экстрактивного QA | + | + | + | + |
# | Health-ORSC-Bench: A Benchmark for Measuring Over-Refusal and Safety Completion in Health Context | Health-ORSC-Bench: бенчмарк для измерения сверхотказов и безопасного завершения в медицинском контексте | + | + | + | + |
#
# ## 5. Неопределённость, RAG, агенты, безопасность
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | Benchmarking Uncertainty Quantification Methods for Large Language Models with LM-Polygraph | Бенчмаркинг методов квантификации неопределённости для LLM с LM-Polygraph | + | + | + | + |
# | Adaptive Conformal Prediction for Improving Factuality of Generations by Large Language Models | Адаптивное конформное предсказание для повышения фактичности генераций LLM | + | + | + | + |
# | Unconditional Truthfulness: Learning Unconditional Uncertainty of Large Language Models | Безусловная правдивость: обучение безусловной неопределённости LLM | + | + | + | + |
# | Uncertainty Quantification for LLMs through Minimum Bayes Risk: Bridging Confidence and Consistency | Квантификация неопределённости LLM через минимальный байесовский риск | + | + | + | + |
# | Efficient Hallucination Detection for LLMs Using Uncertainty-Aware Attention Heads | Эффективное обнаружение галлюцинаций LLM с использованием attention-голов, учитывающих неопределённость | + | + | + | + |
# | MIRAGE: Defending Long-Form RAG Against Misinformation Pollution | MIRAGE: защита длинного RAG от загрязнения дезинформацией | + | + | + | + |
# | QIMG-7 and Source-Aware Resolution for Polluted Multimodal RAG | QIMG-7 и разрешение с учётом источника для загрязнённого мультимодального RAG | + | + | + | + |
# | Faithfulness-Aware Uncertainty Quantification for Fact-Checking the Output of Retrieval Augmented Generation | Квантификация неопределённости с учётом верности для фактчекинга вывода RAG | + | + | + | + |
# | ReDAct: Uncertainty-Aware Deferral for LLM Agents | ReDAct: отложенное решение с учётом неопределённости для LLM-агентов | + | + | + | + |
# | Bayesian control for coding agents | Байесовское управление для кодирующих агентов | + | + | + | + |
# | RegretBench: A Regret-Based Multi-Turn Benchmark for LLMs' Clarification Policies | RegretBench: многоходовой бенчмарк на основе сожаления для политик уточнения LLM | + | + | + | + |
# | Schützen: Evaluating LLM Safety in Bulgarian and German Contexts | Schützen: оценка безопасности LLM в болгарском и немецком контекстах | + | + | + | + |
# | SurakshaEval: An Indic Safety Benchmark for Multilingual LLMs | SurakshaEval: индийский бенчмарк безопасности для многоязычных LLM | + | + | + | + |
# | Do-Not-Answer: A Dataset for Evaluating Safeguards in LLMs | Do-Not-Answer: датасет для оценки защитных механизмов LLM | + | + | + | + |
# | UnsafeChain: Enhancing Reasoning Model Safety via Hard Cases | UnsafeChain: повышение безопасности reasoning-моделей через сложные случаи | + | + | + | + |
#
# ## 6. Речь и мультимодальность
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | WERd: Using Social Text Spelling Variants for Evaluating Dialectal Speech Recognition | WERd: использование вариантов написания из соцтекстов для оценки диалектного распознавания речи | + | + | + | + |
# | Detecting Check-Worthy Claims in Political Debates, Speeches, and Interviews Using Audio Data | Обнаружение утверждений, достойных проверки, в политических дебатах, речах и интервью с использованием аудиоданных | + | + | + | + |
# | Detecting Deception in Political Debates Using Acoustic and Textual Features | Обнаружение обмана в политических дебатах с использованием акустических и текстовых признаков | + | + | + | + |
# | MuSLR: Multimodal Symbolic Logical Reasoning | MuSLR: мультимодальное символьное логическое рассуждение | + | + | + | + |
# | DUAL-Bench: Measuring Over-Refusal and Robustness in Vision-Language Models | DUAL-Bench: измерение сверхотказов и устойчивости в vision-language моделях | + | + | + | + |
# | VSCBench: Bridging the Gap in Vision-Language Model Safety Calibration | VSCBench: преодоление разрыва в калибровке безопасности vision-language моделей | + | + | + | + |
# | MemeMQA: Multimodal Question Answering for Memes via Rationale-Based Inferencing | MemeMQA: мультимодальный QA для мемов через вывод на основе обоснований | + | + | + | + |
# | Detecting Harmful Memes and Their Targets | Обнаружение вредных мемов и их целей | + | + | + | + |
# | DISARM: Detecting the Victims Targeted by Harmful Memes | DISARM: обнаружение жертв, на которых нацелены вредные мемы | + | + | + | + |
# | Characterizing the Entities in Harmful Memes: Who is the Hero, the Villain, the Victim? | Характеристика сущностей во вредных мемах: кто герой, злодей, жертва? | + | + | + | + |
# | What do you MEME? Generating Explanations for Visual Semantic Role Labelling in Memes | What do you MEME? Генерация объяснений для визуальной семантической ролевой разметки в мемах | + | + | + | + |
#
# ## 7. Остальные работы (сводная таблица)
#
# | Оригинальное название | Адаптированное название | Тадж. | Тат./Баш. | Осет. | Кавк. |
# |---|---|---|---|---|---|
# | FinCUABuild: Can Agents Build Reliable Benchmarks for Dynamic Financial Computer Use? | FinCUABuild: могут ли агенты строить надёжные бенчмарки для динамического финансового computer use? | + | + | + | + |
# | How Correct Is Your Answer? A Semantic Correctness Framework for Open QA Evaluation | Насколько правилен ваш ответ? Семантическая корректность для оценки открытого QA | + | + | + | + |
# | EDRAC: Benchmarking Arabic Dialect Reading Comprehension | EDRAC: бенчмарк чтения с пониманием для диалектов | + | + | + | + |
# | Right Frame, Wrong Rule: Cultural Cues Expose the Financial Knowledge Gap | Верная рамка, неверное правило: культурные сигналы и финансовые знания | + | + | + | + |
# | Think with Structured Grounding: Perceptual Reinforcement Learning for Chart and Visual-Tabular Understanding | Мышление со структурной привязкой: перцептивное RL для графиков и визуальных таблиц | + | + | + | + |
# | Seeing Is Not Deciding: Can Multimodal LLMs Act as Effective CEOs? | Видеть — не значит решать: могут ли мультимодальные LLM быть эффективными CEO? | + | + | + | + |
# | Can Agentic Trading Systems Pay for Their Own Intelligence? | Могут ли агентные торговые системы окупать свой интеллект? | + | + | + | + |
# | Can Dialects Be Steered Like Languages? Sparse Neurons and Distributed Directions in Arabic LLMs | Можно ли управлять диалектами как языками? Разреженные нейроны и распределённые направления | + | + | + | + |
# | FinPersona-Bench: A Benchmark for Longitudinal Psychometric Stability of Autonomous Financial Agents | FinPersona-Bench: бенчмарк продольной психометрической стабильности финансовых агентов | + | + | + | + |
# | LabGuard: Grounding Natural-Language Laboratory Rules into Runtime Guards | LabGuard: преобразование лабораторных правил в runtime-защиту | + | + | + | + |
# | The FIL Hypothesis: Inductive Biases Help with Kernel Engineering | Гипотеза FIL: индуктивные смещения помогают в kernel engineering | + | + | + | + |
# | ThinkBooster: A Unified Framework for Seamless Test-Time Scaling of LLM Reasoning | ThinkBooster: единая структура для test-time scaling рассуждений LLM | + | + | + | + |
# | Better with Experience: Self-Evolving LLM Agents for Evidence-Grounded Health Community Notes | Лучше с опытом: самоэволюционирующие LLM-агенты для медицинских Community Notes | + | + | + | + |
# | Uncovering Temporal Framing in the News | Выявление временного фрейминга в новостях | + | + | + | + |
# | The Geometry of Forgetting: Temporal Knowledge Drift as an Independent Axis in LLM Representations | Геометрия забывания: темпоральный дрейф знаний как независимая ось представлений LLM | + | + | + | + |
# | FMI_SU_Yotkova_Kastreva at SemEval-2026 Task 13: Lightweight Detection of LLM-Generated Code via Stylometric Signals | Лёгкая детекция LLM-кода через стилометрические сигналы | + | + | + | + |
# | The Cylindrical Representation Hypothesis for Language Model Steering | Цилиндрическая гипотеза представлений для управления языковыми моделями | + | + | + | + |
# | A Multi-View Media Profiling Suite: Resources, Evaluation, and Analysis | Многовидовой набор для профилирования СМИ: ресурсы, оценка, анализ | + | + | + | + |
# | Cultural Benchmarking of LLMs in Standard and Dialectal Arabic Dialogues | Культурный бенчмарк LLM в стандартных и диалектных арабских диалогах | + | + | + | + |
# | Instruction-Guided Poetry Generation in Arabic and Its Dialects | Генерация поэзии по инструкции в арабском и его диалектах | + | + | + | + |
# | DenoiseRank: Learning to Rank by Diffusion Models | DenoiseRank: обучение ранжированию через диффузионные модели | + | + | + | + |
# | Co-FactChecker: A Framework for Human-AI Collaborative Claim Verification | Co-FactChecker: структура человеко-AI совместной проверки утверждений | + | + | + | + |
# | Why Don't You Know? Evaluating the Impact of Uncertainty Sources on UQ in LLMs | Почему вы не знаете? Влияние источников неопределённости на UQ в LLM | + | + | + | + |
# | SQLStructEval: Structural Evaluation of LLM Text-to-SQL Generation | SQLStructEval: структурная оценка Text-to-SQL генерации LLM | + | + | + | + |
# | SciDER: Scientific Data-centric End-to-end Researcher | SciDER: научный исследователь-агент, ориентированный на данные | + | + | + | + |
# | Multi-Sourced, Multi-Agent Evidence Retrieval for Fact-Checking | Многоисточниковый мультиагентный поиск доказательств для фактчекинга | + | + | + | + |
# | Curriculum Learning and Pseudo-Labeling Improve the Generalization of Multi-Label Arabic Dialect Identification Models | Curriculum learning и псевдоразметка для мультиязычной идентификации диалектов | + | + | + | + |
# | The CLEF-2026 FinMMEval Lab: Multilingual and Multimodal Evaluation of Financial AI Systems | CLEF-2026 FinMMEval: многоязычная и мультимодальная оценка финансовых AI-систем | + | + | + | + |
# | The CLEF-2026 CheckThat! Lab: Advancing Multilingual Fact-Checking | CLEF-2026 CheckThat!: развитие многоязычного фактчекинга | + | + | + | + |
# | Overview of PAN 2026: Voight-Kampff Generative AI Detection, Text Watermarking, Multi-Author Writing Style Analysis, Generative Plagiarism Detection, and Reasoning Trajectory Detection | Обзор PAN 2026: детекция генеративного AI, водяные знаки, анализ стиля, плагиат, траектории рассуждений | + | + | + | + |
# | AICD Bench: A Challenging Benchmark for AI-Generated Code Detection | AICD Bench: сложный бенчмарк для детекции AI-сгенерированного кода | + | + | + | + |
# | VISPA: Pluralistic Alignment via Automatic Value Selection and Activation | VISPA: плюралистическое выравнивание через автоматический выбор и активацию ценностей | + | + | + | + |
# | YaPO: Learnable Sparse Activation Steering Vectors for Domain Adaptation | YaPO: обучаемые разреженные steering-векторы для доменной адаптации | + | + | + | + |
# | How Does Prefix Matter in Reasoning Model Tuning? | Как префикс влияет на настройку reasoning-моделей? | + | + | + | + |
# | Don't Throw Away Your Beams: Improving Consistency-based Uncertainties in LLMs via Beam Search | Не выбрасывайте beams: улучшение consistency-based UQ в LLM через beam search | + | + | + | + |
# | EngTrace: A Symbolic Benchmark for Verifiable Process Supervision of Engineering Reasoning | EngTrace: символьный бенчмарк для проверяемой процессной супервизии инженерных рассуждений | + | + | + | + |
# | COMMUNITYNOTES: A Dataset for Exploring the Helpfulness of Fact-Checking Explanations | COMMUNITYNOTES: датасет для изучения полезности фактчекинг-объяснений | + | + | + | + |
# | PTPP-Aware Adaptation Scaling Laws: Predicting Domain-Adaptation Performance at Unseen Pre-Training Budgets | PTPP-осведомлённые scaling laws для доменной адаптации | + | + | + | + |
# | When Personalization Tricks Detectors: The Feature-Inversion Trap in Machine-Generated Text Detection | Когда персонализация обманывает детекторы: ловушка инверсии признаков | + | + | + | + |
# | HALF: Harm-Aware LLM Fairness Evaluation Aligned with Deployment | HALF: оценка справедливости LLM с учётом вреда и развёртывания | + | + | + | + |
# | Beyond the Crowd: LLM-Augmented Community Notes for Governing Health Misinformation | За пределами толпы: LLM-аугментированные Community Notes для медицинской дезинформации | + | + | + | + |
# | BLAZER: Bootstrapping LLM-based Manipulation Agents with Zero-Shot Data Generation | BLAZER: бутстрап LLM-агентов манипуляции через zero-shot генерацию данных | + | + | + | + |
# | A Fano-Style Accuracy Upper Bound for LLM Single-Pass Reasoning in Multi-Hop QA | Верхняя граница точности в стиле Фано для одношагового рассуждения LLM в multi-hop QA | + | + | + | + |
# | Cross-Cultural Transfer of Commonsense Reasoning in LLMs: Evidence from the Arab World | Кросс-культурный перенос commonsense-рассуждений в LLM: пример арабского мира | + | + | + | + |
# | Toxicity Red-Teaming: Benchmarking LLM Safety in Singapore's Low-Resource Languages | Red-teaming токсичности: безопасность LLM в низкоресурсных языках Сингапура | + | + | + | + |
# | Explicit and Implicit Data Augmentation for Social Event Detection | Явная и неявная аугментация данных для обнаружения социальных событий | + | + | + | + |
# | ConspirED: A Dataset for Cognitive Traits of Conspiracy Theories and LLM Safety | ConspirED: датасет когнитивных черт конспирологии и безопасности LLM | + | + | + | + |
# | Beyond Memorization: Extending Reasoning Depth with Recurrence, Memory and Test-Time Compute Scaling | За пределами запоминания: глубина рассуждений через рекуррентность, память и test-time compute | + | + | + | + |
# | MuDRiC: Multi-Dialect Reasoning for Arabic Commonsense Validation | MuDRiC: мультидиалектное рассуждение для арабской commonsense-валидации | + | + | + | + |
# | Beyond "Not Novel Enough": Enriching Scholarly Critique with LLM-Assisted Feedback | За пределами «недостаточно ново»: обогащение научной критики через LLM-фидбек | + | + | + | + |
# | Droid: A Resource Suite for AI-Generated Code Detection | Droid: набор ресурсов для детекции AI-сгенерированного кода | + | + | + | + |
# | FRaN-X: FRaming and Narratives-eXplorer | FRaN-X: исследователь фрейминга и нарративов | + | + | + | + |
# | DP-Fusion: Token-Level Differentially Private Inference for Large Language Models | DP-Fusion: токен-уровневый дифференциально-приватный инференс для LLM | + | + | + | + |
# | Profiling News Media for Factuality and Bias Using LLMs and the Fact-Checking Methodology of Human Experts | Профилирование СМИ по фактичности и bias с LLM и методологией экспертов | + | + | + | + |
# | Atomic Reasoning for Scientific Table Claim Verification | Атомарное рассуждение для проверки утверждений по научным таблицам | + | + | + | + |
# | Con Instruction: Universal Jailbreaking of Multimodal Large Language Models via Non-Textual Modalities | Con Instruction: универсальный jailbreak мультимодальных LLM через нетекстовые модальности | + | + | + | + |
# | Community Moderation and the New Epistemology of Fact Checking on Social Media | Модерация сообществ и новая эпистемология фактчекинга в соцсетях | + | + | + | + |
# | UNCERTAINTY-LINE: Length-Invariant Estimation of Uncertainty for Large Language Models | UNCERTAINTY-LINE: инвариантная к длине оценка неопределённости LLM | + | + | + | + |
# | From Generation to Detection: A Multimodal Multi-Task Dataset for Benchmarking Health Misinformation | От генерации к детекции: мультимодальный многозадачный датасет для медицинской дезинформации | + | + | + | + |
# | FAID: Fine-Grained AI-Generated Text Detection Using Multi-Task Auxiliary and Multi-Level Contrastive Learning | FAID: тонкая детекция AI-текста через многозадачные вспомогательные и контрастивные методы | + | + | + | + |
# | A Head to Predict and a Head to Question: Pre-trained Uncertainty Quantification Heads for Hallucination Detection | Голова для предсказания и голова для вопроса: предобученные UQ-головы для детекции галлюцинаций | + | + | + | + |
# | Between Underthinking and Overthinking: An Empirical Study of Reasoning Length and Correctness in LLMs | Между недо- и переосмыслением: эмпирическое исследование длины рассуждений и корректности | + | + | + | + |
# | Can LLMs Automate Fact-Checking Article Writing? | Могут ли LLM автоматизировать написание фактчекинг-статей? | + | + | + | + |
# | The CLEF-2025 CheckThat! Lab: Subjectivity, Fact-Checking, Claim Normalization, and Retrieval | CLEF-2025 CheckThat!: субъективность, фактчекинг, нормализация утверждений, поиск | + | + | + | + |
# | CoDet-M4: Detecting Machine-Generated Code in Multi-Lingual, Multi-Generator and Multi-Domain Settings | CoDet-M4: детекция машинно-сгенерированного кода в мультиязычных и многодоменных условиях | + | + | + | + |
# | A Comprehensive Survey of Machine Unlearning Techniques for Large Language Models | Обзор методов machine unlearning для LLM | + | + | + | + |
# | Entity Framing and Role Portrayal in the News | Фрейминг сущностей и ролевое изображение в новостях | + | + | + | + |
# | Fast or Better? Balancing Accuracy and Cost in Retrieval-Augmented Generation with Flexible User Control | Быстрее или лучше? Баланс точности и стоимости в RAG с гибким контролем пользователя | + | + | + | + |
# | Is Human-Like Text Liked by Humans? Multilingual Human Detection and Preference Against AI | Нравится ли людям человекоподобный текст? Многоязычная детекция и предпочтения против AI | + | + | + | + |
# | ExaGPT: Example-Based Machine-Generated Text Detection for Human Interpretability | ExaGPT: детекция машинно-сгенерированного текста на примерах для интерпретируемости | + | + | + | + |
# | GenAI Content Detection Task 1: English and Multilingual Machine-Generated Text Detection | GenAI Content Detection Task 1: англоязычная и многоязычная детекция AI-текста | + | + | + | + |
# | GenAI Content Detection Task 3: Cross-Domain Machine-Generated Text Detection Challenge | GenAI Content Detection Task 3: кросс-доменная детекция AI-текста | + | + | + | + |
# | LLM360 K2: Building a 65B 360-Open-Source Large Language Model from Scratch | LLM360 K2: создание 65B полностью открытой LLM с нуля | + | + | + | + |
# | Libra-Leaderboard: Towards Responsible AI through a Balanced Leaderboard of Safety and Capability | Libra-Leaderboard: ответственный AI через сбалансированный лидерборд безопасности и возможностей | + | + | + | + |
# | Shaping the Safety Boundaries: Understanding and Defending Against Jailbreaks in LLMs | Формирование границ безопасности: понимание и защита от jailbreak в LLM | + | + | + | + |
# | Aristotle: Mastering Logical Reasoning with A Logic-Complete Decompose-Search-Resolve Framework | Aristotle: овладение логическим рассуждением через полную декомпозицию-поиск-решение | + | + | + | + |
# | Towards More Robust Retrieval-Augmented Generation: Evaluating RAG Under Adversarial Poisoning Attacks | К более устойчивому RAG: оценка RAG под состязательными атаками отравления | + | + | + | + |
# | MGM: Global Understanding of Audience Overlap Graphs for Predicting Factuality and Bias of News Media | MGM: глобальное понимание графов пересечения аудитории для предсказания фактичности и bias СМИ | + | + | + | + |
# | MALMM: Multi-Agent Large Language Models for Zero-Shot Robotics Manipulation | MALMM: мультиагентные LLM для zero-shot роботической манипуляции | + | + | + | + |
# | Learning To Sample the Meta-Paths for Social Event Detection | Обучение выборке метапутей для обнаружения социальных событий | + | + | + | + |
# | Arabic Dataset for LLM Safeguard Evaluation | Арабский датасет для оценки защитных механизмов LLM | + | + | + | + |
# | DocEdit-v2: Document Structure Editing Via Multimodal LLM Grounding | DocEdit-v2: редактирование структуры документов через мультимодальную LLM-привязку | + | + | + | + |
# | PropaInsight: Toward Deeper Understanding of Propaganda in Terms of Techniques, Appeals, and Intent | PropaInsight: более глубокое понимание пропаганды через техники, апелляции и интенты | + | + | + | + |
# | Exploring Language Model Generalization in Low-Resource Extractive QA | Исследование обобщения языковых моделей в низкоресурсном экстрактивном QA | + | + | + | + |
# | Grounding Fallacies Misrepresenting Scientific Publications in Evidence | Привязка ошибок, искажающих научные публикации, к доказательствам | + | + | + | + |
# | LLM-DetectAIve: a Tool for Fine-Grained Machine-Generated Text Detection | LLM-DetectAIve: инструмент тонкой детекции машинно-сгенерированного текста | + | + | + | + |
# | Web2Code: A Large-scale Webpage-to-Code Dataset and Evaluation Framework for Multimodal LLMs | Web2Code: крупномасштабный датасет webpage-to-code и оценка для мультимодальных LLM | + | + | + | + |
# | Can Machines Resonate with Humans? Evaluating the Emotional and Empathic Comprehension of LMs | Могут ли машины резонировать с людьми? Оценка эмоционального и эмпатического понимания | + | + | + | + |
# | Exploring the Limitations of Detecting Machine-Generated Text | Исследование ограничений детекции машинно-сгенерированного текста | + | + | + | + |
# | Corpus Poisoning via Approximate Greedy Gradient Descent | Отравление корпуса через приближённый жадный градиентный спуск | + | + | + | + |
# | Missci: Reconstructing Fallacies in Misrepresented Science | Missci: реконструкция ошибок в искажённой науке | + | + | + | + |
# | From Multiple-Choice to Extractive QA: A Case Study for English and Arabic | От множественного выбора к экстрактивному QA: кейс английского и арабского | + | + | + | + |
# | SemEval-2024 Task 8: Multidomain, Multimodel and Multilingual Machine-Generated Text Detection | SemEval-2024 Task 8: многодоменная, многомодельная и многоязычная детекция AI-текста | + | + | + | + |
# | Semantic Ranking for Automated Adversarial Technique Annotation in Security Text | Семантическое ранжирование для автоматической аннотации состязательных техник в security-тексте | + | + | + | + |
# | Fact-Checking the Output of Large Language Models via Token-Level Uncertainty Quantification | Фактчекинг вывода LLM через токен-уровневую квантификацию неопределённости | + | + | + | + |
# | Multimodal Large Language Models to Support Real-World Fact-Checking | Мультимодальные LLM для поддержки реального фактчекинга | + | + | + | + |
# | A Chinese Dataset for Evaluating the Safeguards in Large Language Models | Китайский датасет для оценки защитных механизмов LLM | + | + | + | + |
# | M4GT-Bench: Evaluation Benchmark for Black-Box Machine-Generated Text Detection | M4GT-Bench: бенчмарк для black-box детекции машинно-сгенерированного текста | + | + | + | + |
# | Factuality of Large Language Models: A Survey | Фактичность больших языковых моделей: обзор | + | + | + | + |
# | Recent Advances in Hate Speech Moderation: Multimodality and the Role of Large Models | Последние достижения в модерации hate speech: мультимодальность и роль больших моделей | + | + | + | + |
# | Generating Zero-shot Abstractive Explanations for Rumour Verification | Генерация zero-shot абстрактивных объяснений для проверки слухов | + | + | + | + |
# | LLM360: Towards Fully Transparent Open-Source LLMs | LLM360: к полностью прозрачным открытым LLM | + | + | + | + |
# | Large Language Models are Few-Shot Training Example Generators: A Case Study in Fallacy Recognition | LLM как генераторы few-shot примеров: кейс распознавания ошибок | + | + | + | + |
# | A Survey of Confidence Estimation and Calibration in Large Language Models | Обзор оценки уверенности и калибровки в LLM | + | + | + | + |
# | A Template Is All You Meme | Шаблон — это всё, что нужно для мема | + | + | + | + |
# | Adapting Fake News Detection to the Era of Large Language Models | Адаптация детекции фейк-ньюс к эпохе LLM | + | + | + | + |
# | Lost in Translation, Found in Spans: Identifying Claims in Multilingual Social Media | Потеряно в переводе, найдено в спанах: идентификация утверждений в многоязычных соцсетях | + | + | + | + |
# | From Chaos to Clarity: Claim Normalization to Empower Fact-Checking | От хаоса к ясности: нормализация утверждений для фактчекинга | + | + | + | + |
# | QACHECK: A Demonstration System for Question-Guided Multi-Hop Fact-Checking | QACHECK: демонстрационная система вопросно-управляемого multi-hop фактчекинга | + | + | + | + |
# | Factuality Challenges in the Era of Large Language Models | Вызовы фактичности в эпоху LLM | + | + | + | + |
# | Rethinking STS and NLI in Large Language Models | Переосмысление STS и NLI в LLM | + | + | + | + |
# | Fake News Detectors are Biased against Texts Generated by Large Language Models | Детекторы фейк-ньюс предвзяты к текстам, сгенерированным LLM | + | + | + | + |
# | Gpachov at CheckThat! 2023: A Diverse Multi-Approach Ensemble for Subjectivity Detection in News Articles | Gpachov at CheckThat! 2023: ансамбль для детекции субъективности в новостях | + | + | + | + |
# | DetectLLM: Leveraging Log Rank Information for Zero-Shot Detection of Machine-Generated Text | DetectLLM: использование log-rank информации для zero-shot детекции AI-текста | + | + | + | + |
# | bgGLUE: A Bulgarian General Language Understanding Evaluation Benchmark | bgGLUE: болгарский бенчмарк общего понимания языка | + | + | + | + |
# | M4: Multi-generator, Multi-domain, and Multi-lingual Black-Box Machine-Generated Text Detection | M4: мультигенераторная, многодоменная и многоязычная black-box детекция AI-текста | + | + | + | + |
# | Detecting Propaganda Techniques in Code-Switched Social Media Text | Детекция пропагандистских приёмов в код-свитчинг текстах соцсетей | + | + | + | + |
# | On the Risk of Misinformation Pollution with Large Language Models | О риске загрязнения дезинформацией с помощью LLM | + | + | + | + |
# | Fact-Checking Complex Claims with Program-Guided Reasoning | Фактчекинг сложных утверждений с программно-управляемым рассуждением | + | + | + | + |
# | QCRI at SemEval-2023 Task 3: News Genre, Framing and Persuasion Techniques Detection | QCRI at SemEval-2023 Task 3: жанр, фрейминг и приёмы убеждения в новостях | + | + | + | + |
# | MarsEclipse at SemEval-2023 Task 3: Multi-Lingual and Multi-Label Framing Detection with Contrastive Learning | MarsEclipse at SemEval-2023 Task 3: многоязычная многометочная детекция фрейминга | + | + | + | + |
# | Multimodality Representation Learning: A Survey on Evolution, Pretraining and Its Applications | Мультимодальное представление: обзор эволюции, предобучения и применений | + | + | + | + |
# | Temporal Dynamics of Coordinated Online Behavior: Stability, Archetypes, and Influence | Временная динамика координированного онлайн-поведения | + | + | + | + |
# | Overview of the WANLP 2022 Shared Task on Propaganda Detection in Arabic | Обзор WANLP 2022: детекция пропаганды в арабском | + | + | + | + |
# | GREENER: Graph Neural Networks for News Media Profiling | GREENER: графовые нейросети для профилирования новостных СМИ | + | + | + | + |
# | PASTA: Table-Operations Aware Fact Verification via Sentence-Table Cloze Pre-training | PASTA: проверка фактов с учётом табличных операций | + | + | + | + |
# | IITD at the WANLP 2022 Shared Task: Multilingual Multi-Granularity Network for Propaganda Detection | IITD at WANLP 2022: многоязычная многогранулярная сеть для детекции пропаганды | + | + | + | + |
# | CrowdChecked: Detecting Previously Fact-Checked Claims in Social Media | CrowdChecked: обнаружение ранее проверенных утверждений в соцсетях | + | + | + | + |
# | Ten Years after ImageNet: A 360° Perspective on AI | Десять лет после ImageNet: 360° взгляд на AI | + | + | + | + |
# | Partisan US News Media Representations of Syrian Refugees | Партийные репрезентации сирийских беженцев в американских СМИ | + | + | + | + |
# | US News and Social Media Framing around Vaping | Фрейминг вейпинга в американских новостях и соцсетях | + | + | + | + |
# | TeamX@DravidianLangTech-ACL2022: A Comparative Analysis for Troll-Based Meme Classification | TeamX@DravidianLangTech: сравнительный анализ классификации троллинг-мемов | + | + | + | + |
# | Detecting the Role of an Entity in Harmful Memes: Techniques and Their Limitations | Детекция роли сущности во вредных мемах: техники и ограничения | + | + | + | + |
# | Detecting and Understanding Harmful Memes: A Survey | Обзор детекции и понимания вредных мемов | + | + | + | + |
# | QCRI's COVID-19 Disinformation Detector: A System to Fight the COVID-19 Infodemic | QCRI COVID-19 Disinformation Detector: система борьбы с инфодемией | + | + | + | + |
# | Faking Fake News for Real Fake News Detection: Propaganda-loaded Training Data Generation | Генерация пропагандистских данных для детекции реальных фейков | + | + | + | + |
# | NewsClaims: A New Benchmark for Claim Detection from News with Attribute Knowledge | NewsClaims: бенчмарк для детекции утверждений в новостях с атрибутами | + | + | + | + |
# | Batch-Softmax Contrastive Loss for Pairwise Sentence Scoring Tasks | Batch-softmax контрастивная потеря для парных задач оценки предложений | + | + | + | + |
# | SUper Team at SemEval-2016 Task 3: Building a feature-rich system for community question answering | SUper Team at SemEval-2016 Task 3: система для community QA | + | + | + | + |
# | Improved statistical machine translation using monolingual paraphrases | Улучшенный статистический машинный перевод с помощью одноязычных перефраз | + | + | + | + |
# | Exposing Paid Opinion Manipulation Trolls | Разоблачение платных троллей манипуляции мнением | + | + | + | + |
# | Sentiment Analysis in Twitter for Macedonian | Анализ тональности в Twitter для македонского | + | + | + | + |
# | The Spread of Propaganda by Coordinated Communities on Social Media | Распространение пропаганды координированными сообществами в соцсетях | + | + | + | + |
# | RuleBert: Teaching Soft Rules to Pre-trained Language Models | RuleBert: обучение мягким правилам предобученных языковых моделей | + | + | + | + |
# | Findings of the NLP4IF-2021 Shared Tasks on Fighting the COVID-19 Infodemic and Censorship Detection | Результаты NLP4IF-2021: борьба с COVID-инфодемией и детекция цензуры | + | + | + | + |
# | A Second Pandemic? Analysis of Fake News About COVID-19 Vaccines in Qatar | Вторая пандемия? Анализ фейков о вакцинах COVID-19 в Катаре | + | + | + | + |
# | Assisting the Human Fact-Checkers: Detecting All Previously Fact-Checked Claims in a Document | Помощь фактчекерам: обнаружение всех ранее проверенных утверждений в документе | + | + | + | + |
# | Interpretable Propaganda Detection in News Articles | Интерпретируемая детекция пропаганды в новостях | + | + | + | + |
# | Predicting the Factuality of Reporting of News Media Using Observations About User Attention in Their YouTube Channels | Предсказание фактичности СМИ через внимание пользователей на YouTube | + | + | + | + |
# | SemEval-2021 Task 6: Detection of Persuasion Techniques in Texts and Images | SemEval-2021 Task 6: детекция приёмов убеждения в текстах и изображениях | + | + | + | + |
# | WhatTheWikiFact: Fact-Checking Claims Against Wikipedia | WhatTheWikiFact: фактчекинг утверждений по Википедии | + | + | + | + |
# | Transformers: "The End of History" for NLP? | Трансформеры: «конец истории» для NLP? | + | + | + | + |
# | Cross-Domain Label-Adaptive Stance Detection | Кросс-доменная адаптивная по меткам детекция позиции | + | + | + | + |
# | The Role of Context in Detecting Previously Fact-Checked Claims | Роль контекста в обнаружении ранее проверенных утверждений | + | + | + | + |
# | A Neighbourhood Framework for Resource-Lean Content Flagging | Районная структура для флаггинга контента при малых ресурсах | + | + | + | + |
# | A Survey on Multimodal Disinformation Detection | Обзор мультимодальной детекции дезинформации | + | + | + | + |
# | A Survey on Predicting the Factuality and the Bias of News Media | Обзор предсказания фактичности и bias новостных СМИ | + | + | + | + |
# | Automated Fact-Checking for Assisting Human Fact-Checkers | Автоматический фактчекинг для помощи людям-фактчекерам | + | + | + | + |
# | A Survey on Stance Detection for Mis- and Disinformation Identification | Обзор детекции позиции для выявления мисинформации и дезинформации | + | + | + | + |
# | Detecting Harmful Content On Online Platforms: What Platforms Need Vs. Where Research Efforts Go | Детекция вредного контента на онлайн-платформах: потребности vs. исследования | + | + | + | + |
# | Data-Informed Global Sparseness in Attention Mechanisms for Deep Neural Networks | Глобальная разреженность attention на основе данных для глубоких сетей | + | + | + | + |
# | Vector-Vector-Matrix Architecture: A Novel Hardware-Aware Framework for Low-Latency Inference | Вектор-вектор-матричная архитектура для низколатентного инференса | + | + | + | + |
# | We Can Detect Your Bias: Predicting the Political Ideology of News Articles | Мы можем определить ваш bias: предсказание политической идеологии новостей | + | + | + | + |
# | Team Alex at CLEF CheckThat! 2020: Identifying Check-Worthy Tweets With Transformer Models | Team Alex at CLEF CheckThat! 2020: check-worthy твиты через трансформеры | + | + | + | + |
# | FANG: Leveraging Social Context for Fake News Detection Using Graph Representation | FANG: социальный контекст для детекции фейк-ньюс через графовые представления | + | + | + | + |
# | Can We Spot the "Fake News" Before It Was Even Written? | Можем ли мы обнаружить «фейк-ньюс» до того, как он написан? | + | + | + | + |
# | aschern at SemEval-2020 Task 11: It Takes Three to Tango: RoBERTa, CRF, and Transfer Learning | aschern at SemEval-2020 Task 11: RoBERTa, CRF и transfer learning | + | + | + | + |
# | On a Novel Application of Wasserstein-Procrustes for Unsupervised Cross-Lingual Learning | Новое применение Wasserstein-Procrustes для неконтролируемого кросс-языкового обучения | + | + | + | + |
# | A Survey on Computational Propaganda Detection | Обзор вычислительной детекции пропаганды | + | + | + | + |
# | Fighting the COVID-19 Infodemic in Social Media: A Holistic Perspective and a Call to Arms | Борьба с COVID-инфодемией в соцсетях: целостный взгляд и призыв к действию | + | + | + | + |
# | That is a Known Lie: Detecting Previously Fact-Checked Claims | Это известная ложь: обнаружение ранее проверенных утверждений | + | + | + | + |
# | Prta: A System to Support the Analysis of Propaganda Techniques in the News | Prta: система поддержки анализа пропагандистских приёмов в новостях | + | + | + | + |
# | What Was Written vs. Who Read It: News Media Profiling Using Text Analysis and Social Media Context | Что написано vs. кто прочитал: профилирование СМИ через текст и соцконтекст | + | + | + | + |
# | Fighting the COVID-19 Infodemic: Modeling the Perspective of Journalists, Fact-Checkers, Social Media Platforms, Policy Makers, and the Society | Борьба с COVID-инфодемией: моделирование перспектив журналистов, фактчекеров, платформ, политиков и общества | + | + | + | + |
# | Enriched Pre-trained Transformers for Joint Slot Filling and Intent Detection | Обогащённые предобученные трансформеры для совместного slot filling и intent detection | + | + | + | + |
# | On the Effect of Dropping Layers of Pre-trained Transformer Models | О эффекте удаления слоёв предобученных трансформеров | + | + | + | + |
# | Compressing Large-Scale Transformer-Based Models: A Case Study on BERT | Сжатие крупномасштабных трансформеров: кейс BERT | + | + | + | + |
# | CheckThat! at CLEF 2020: Enabling the Automatic Identification and Verification of Claims | CheckThat! at CLEF 2020: автоматическая идентификация и верификация утверждений | + | + | + | + |
# | A Context-Aware Approach for Detecting Check-Worthy Claims in Political Debates | Контекстно-зависимый подход к обнаружению check-worthy утверждений в дебатах | + | + | + | + |
# | Proppy: A System to Unmask Propaganda in Online News | Proppy: система разоблачения пропаганды в онлайн-новостях | + | + | + | + |
# | SemEval-2013 Task 2: Sentiment Analysis in Twitter | SemEval-2013 Task 2: анализ тональности в Twitter | + | + | + | + |
# | Pairwise Neural Machine Translation Evaluation | Парная нейросетевая оценка машинного перевода | + | + | + | + |
# | Machine Translation Evaluation Meets Community Question Answering | Оценка машинного перевода встречает community QA | + | + | + | + |
# | SemEval-2014 Task 9: Sentiment Analysis in Twitter | SemEval-2014 Task 9: анализ тональности в Twitter | + | + | + | + |
# | SemEval-2015 Task 10: Sentiment Analysis in Twitter | SemEval-2015 Task 10: анализ тональности в Twitter | + | + | + | + |
# | SemEval-2016 Task 4: Sentiment Analysis in Twitter | SemEval-2016 Task 4: анализ тональности в Twitter | + | + | + | + |
# | SemEval-2016 Task 3: Community Question Answering | SemEval-2016 Task 3: community question answering | + | + | + | + |
# | Towards Constructing a Corpus for Studying the Effects of Treatments and Substances Reported in PubMed Abstracts | Построение корпуса для изучения эффектов лечения и веществ в PubMed | + | + | + | + |
# | Using the Web as an Implicit Training Set: Application to Noun Compound Syntax and Semantics | Использование веба как неявного обучающего набора для синтаксиса и семантики noun compounds | + | + | + | + |
# | SemEval-2017 Task 4: Sentiment Analysis in Twitter | SemEval-2017 Task 4: анализ тональности в Twitter | + | + | + | + |
# | SemEval-2017 Task 3: Community Question Answering | SemEval-2017 Task 3: community question answering | + | + | + | + |
# | DiscoTK: Using Discourse Structure for Machine Translation Evaluation | DiscoTK: дискурсивная структура для оценки машинного перевода | + | + | + | + |
# | Language-Independent Sentiment Analysis Using Subjectivity and Positional Information | Языконезависимый анализ тональности через субъективность и позицию | + | + | + | + |
# | Findings of the 2016 WMT Shared Task on Cross-lingual Pronoun Prediction | Результаты WMT 2016: кросс-языковое предсказание местоимений | + | + | + | + |
# | Large-Scale Noun Compound Interpretation Using Bootstrapping and the Web as a Corpus | Крупномасштабная интерпретация noun compounds через бутстрап и веб | + | + | + | + |
# | SemEval-2015 Task 3: Answer Selection in Community Question Answering | SemEval-2015 Task 3: выбор ответа в community QA | + | + | + | + |
# | SemEval-2010 Task 8: Multi-Way Classification of Semantic Relations Between Pairs of Nominals | SemEval-2010 Task 8: многоклассовая классификация семантических отношений | + | + | + | + |
# | SemEval-2013 Task 4: Free Paraphrases of Noun Compounds | SemEval-2013 Task 4: свободные перефразы noun compounds | + | + | + | + |
# | Paraphrasing Verbs for Noun Compound Interpretation | Глаголы-перефразы для интерпретации noun compounds | + | + | + | + |
# | Global Thread-Level Inference for Comment Classification in Community Question Answering | Глобальный thread-level вывод для классификации комментариев в cQA | + | + | + | + |
# | SemanticZ at SemEval-2016 Task 3: Ranking Relevant Answers in cQA Using Semantic Similarity | SemanticZ at SemEval-2016 Task 3: ранжирование ответов в cQA | + | + | + | + |
# | In Search of Credible News | В поисках достоверных новостей | + | + | + | + |
# | Hunting for Troll Comments in News Community Forums | Охота на троллинг-комментарии в новостных форумах | + | + | + | + |
# | Experiments in Detecting Persuasion Techniques in the News | Эксперименты по детекции приёмов убеждения в новостях | + | + | + | + |
# | Findings of the NLP4IF-2019 Shared Task on Fine-Grained Propaganda Detection | Результаты NLP4IF-2019: тонкая детекция пропаганды | + | + | + | + |
# | Predicting the Leading Political Ideology of YouTube Channels Using Acoustic, Textual, and Metadata Information | Предсказание политической идеологии YouTube-каналов через аудио, текст и метаданные | + | + | + | + |
# | Contrastive Language Adaptation for Cross-Lingual Stance Detection | Контрастивная языковая адаптация для кросс-языковой детекции позиции | + | + | + | + |
# | Tanbih: Get To Know What You Are Reading | Tanbih: узнайте, что вы читаете | + | + | + | + |
# | Predicting the Role of Political Trolls in Social Media | Предсказание роли политических троллей в соцсетях | + | + | + | + |
# | Evaluating Pronominal Anaphora in Machine Translation: An Evaluation Measure and a Test Suite | Оценка местоименной анафоры в машинном переводе: метрика и тестовый набор | + | + | + | + |
# | Fact-Checking Meets Fauxtography: Verifying Claims About Images | Фактчекинг встречает фейкографию: проверка утверждений об изображениях | + | + | + | + |
# | Detecting Toxicity in News Articles: Application to Bulgarian | Детекция токсичности в новостях: применение к болгарскому | + | + | + | + |
# | It Takes Nine to Smell a Rat: Neural Multi-Task Learning for Check-Worthiness Prediction | Нужно девять, чтобы почуять крысу: мультизадачное обучение для check-worthiness | + | + | + | + |
# | Beyond English-Only Reading Comprehension: Experiments in Zero-Shot Multilingual Transfer for Bulgarian | За пределами англоязычного чтения с пониманием: zero-shot перенос для болгарского | + | + | + | + |
# | Automatic Fact-Checking Using Context and Discourse Information | Автоматический фактчекинг с использованием контекста и дискурса | + | + | + | + |
# | Predicting the Topical Stance of Media and Popular Twitter Users | Предсказание топикальной позиции СМИ и популярных пользователей Twitter | + | + | + | + |
# | Recursive Style Breach Detection with Multifaceted Ensemble Learning | Рекурсивная детекция нарушения стиля через многогранный ансамбль | + | + | + | + |
# | SemEval-2019 Task 8: Fact Checking in Community Question Answering Forums | SemEval-2019 Task 8: фактчекинг в форумах community QA | + | + | + | + |
# | Evaluating Variable-Length Multiple-Option Lists in Chatbots and Mobile Search | Оценка списков переменной длины в чатботах и мобильном поиске | + | + | + | + |
# | Team QCRI-MIT at SemEval-2019 Task 4: Propaganda Analysis Meets Hyperpartisan News Detection | Team QCRI-MIT at SemEval-2019 Task 4: анализ пропаганды и гиперпартийные новости | + | + | + | + |
# | Unsupervised User Stance Detection on Twitter | Неконтролируемая детекция позиции пользователей Twitter | + | + | + | + |
# | Multi-Task Ordinal Regression for Jointly Predicting Trustworthiness and Political Ideology of News Media | Мультизадачная ординальная регрессия для предсказания доверия и идеологии СМИ | + | + | + | + |
# | Predicting the Type and Target of Offensive Posts in Social Media | Предсказание типа и цели оскорбительных постов в соцсетях | + | + | + | + |
# | Machine Reading Comprehension for Answer Re-Ranking in Customer Support Chatbots | Машинное чтение с пониманием для реранкинга ответов в чатботах поддержки | + | + | + | + |
# | Predicting Factuality of Reporting and Bias of News Media Sources | Предсказание фактичности и bias новостных источников | + | + | + | + |
# | Joint Multitask Learning for Community Question Answering Using Task-Specific Embeddings | Совместное мультизадачное обучение для cQA через task-specific эмбеддинги | + | + | + | + |
# | Adversarial Domain Adaptation for Duplicate Question Detection | Состязательная доменная адаптация для обнаружения дубликатов вопросов | + | + | + | + |
# | Towards Automated Customer Support | К автоматизированной поддержке клиентов | + | + | + | + |
# | Overview of the CLEF-2018 CheckThat! Lab. Task 1: Check-Worthiness | Обзор CLEF-2018 CheckThat! Lab. Task 1: check-worthiness | + | + | + | + |
# | Integrating Stance Detection and Fact Checking in a Unified Corpus | Интеграция детекции позиции и фактчекинга в едином корпусе | + | + | + | + |
# | Automatic Stance Detection Using End-to-End Memory Networks | Автоматическая детекция позиции через end-to-end memory networks | + | + | + | + |
# | We Built a Fake News & Click-bait Filter: What Happened Next Will Blow Your Mind! | Мы построили фильтр фейк-ньюс и кликбейта: что случилось дальше | + | + | + | + |
# | Fact Checking in Community Forums | Фактчекинг в общественных форумах | + | + | + | + |
# | Finding People's Professions and Nationalities Using Distant Supervision | Определение профессий и национальностей через distant supervision | + | + | + | + |
# | Machine Translation Evaluation with Neural Networks | Оценка машинного перевода с нейросетями | + | + | + | + |
# | Discourse Structure in Machine Translation Evaluation | Дискурсивная структура в оценке машинного перевода | + | + | + | + |
# | Semantic Sentiment Analysis of Twitter Data | Семантический анализ тональности данных Twitter | + | + | + | + |
# | Cross-Language Question Re-Ranking | Кросс-языковой реранкинг вопросов | + | + | + | + |
# | Building Chatbots from Forum Data: Model Selection Using Question Answering Metrics | Построение чатботов из форумных данных: выбор модели через QA-метрики | + | + | + | + |
# | Robust Tuning Datasets for Statistical Machine Translation | Устойчивые tuning-датасеты для статистического машинного перевода | + | + | + | + |
# | Fully Automated Fact Checking Using External Sources | Полностью автоматический фактчекинг с внешними источниками | + | + | + | + |
# | Seminar Users in the Arabic Twitter Sphere | Seminar users в арабской Twitter-сфере | + | + | + | + |
# | Large-Scale Goodness Polarity Lexicons for Community Question Answering | Крупномасштабные лексиконы полярности для cQA | + | + | + | + |
# | The Case for Being Average: A Mediocrity Approach to Style Masking and Author Obfuscation | Аргумент за средность: подход посредственности к маскировке стиля | + | + | + | + |
# | Cross-language Learning with Adversarial Neural Networks: Application to Community Question Answering | Кросс-языковое обучение с состязательными нейросетями для cQA | + | + | + | + |
# | Bi-Text Alignment of Movie Subtitles for Spoken English-Arabic Statistical Machine Translation | Выравнивание двутекста киносубтитров для разговорного англо-арабского SMT | + | + | + | + |
# | Egyptian Arabic to English Statistical Machine Translation System for NIST OpenMT'2015 | Египетско-арабско-английская SMT-система для NIST OpenMT'2015 | + | + | + | + |
# | Understanding Breast Cancer Survival: Using Causality and Language Models on Multi-omics Data | Понимание выживаемости при раке груди: причинность и языковые модели на мультиомиксных данных | + | + | + | + |
# | Automated Mapping of CVE Vulnerability Records to MITRE CWE Weaknesses | Автоматическое сопоставление записей CVE с weaknesses MITRE CWE | + | + | + | + |
