# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/Python-2026/Practice/OOP_practice_scenarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Вариант 1. Библиотека
#
# **Задача 1 (создание класса, конструктор, метод).** В библиотеке ведётся учёт книг. Создайте класс `Book` с полями `title` (название), `author` (автор) и `year` (год издания). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о книге в формате: «Название» — Автор, год. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой книги в библиотеке есть инвентарный номер, который нельзя менять или читать напрямую. Создайте класс `BookCard`, в котором инвентарный номер хранится в приватном поле `__inventory_id`. Реализуйте метод `set_inventory_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_inventory_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В библиотеке хранятся разные типы изданий. Создайте базовый класс `Publication` с методом `get_type()`, возвращающим строку «Издание». Унаследуйте от него классы `Book` и `Magazine`, переопределив в каждом метод `get_type()` так, чтобы он возвращал «Книга» и «Журнал» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Библиотека выдаёт разные типы изданий, и для каждого нужно рассчитывать срок выдачи. Создайте классы `Book`, `Magazine` и `Newspaper`, у каждого из которых есть метод `loan_period()`, возвращающий количество дней: для книги — 30, для журнала — 14, для газеты — 3. Напишите функцию `show_loan_period(item)`, которая принимает любое издание и выводит срок его выдачи. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Librarian` (библиотекарь), в котором есть три поля: `name` — публичное, `_department` — защищённое (отдел), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Библиотеке нужна утилита для проверки ISBN-номеров. Создайте класс `LibraryUtils` со статическим методом `is_valid_isbn(isbn)`, который возвращает `True`, если длина строки равна 13, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `LibraryItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Book` и `Magazine`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание издания. Проверьте, что объект абстрактного класса `LibraryItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой книги в библиотеке есть обложка. Создайте класс `Cover` с методом `show()`, который выводит строку «Твёрдая обложка». Создайте класс `Book`, который содержит объект класса `Cover` внутри себя как поле. Метод `show_book()` у книги должен выводить название книги и вызывать метод `show()` у её обложки.
#
# **Задача 9 (переопределение методов).** В библиотеке есть базовый класс `LibraryItem` с методом `get_info()`, который возвращает строку «Издание библиотеки». Унаследуйте от него класс `Book` и переопределите метод `get_info()` так, чтобы он возвращал строку «Книга: <название>». Создайте объект класса `Book`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Библиотекарю нужен метод для регистрации выдачи книг. Создайте класс `LoanDesk` с методом `register(...)`, который принимает разное количество аргументов: при вызове `register(book)` регистрируется выдача одной книги, при `register(book, reader)` — выдача книги конкретному читателю, при `register(book, reader, days)` — выдача с указанием срока. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 2. Интернет-магазин
#
# **Задача 1 (создание класса, конструктор, метод).** В интернет-магазине ведётся учёт товаров. Создайте класс `Product` с полями `name` (название), `price` (цена) и `quantity` (количество на складе). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о товаре в формате: Название — цена, количество на складе. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого товара в магазине есть закупочная цена, которую нельзя показывать покупателям и менять напрямую. Создайте класс `ProductCard`, в котором закупочная цена хранится в приватном поле `__cost_price`. Реализуйте метод `set_cost_price(value)`, предназначенный только для установки значения при добавлении товара, и метод `get_cost_price()` для внутреннего чтения. Попытка изменить цену после установки должна игнорироваться.
#
# **Задача 3 (наследование).** В магазине продаются разные категории товаров. Создайте базовый класс `Goods` с методом `get_category()`, возвращающим строку «Товар». Унаследуйте от него классы `Electronics` и `Clothing`, переопределив в каждом метод `get_category()` так, чтобы он возвращал «Электроника» и «Одежда» соответственно. Создайте по одному объекту каждого класса и выведите их категорию.
#
# **Задача 4 (полиморфизм).** Магазин рассчитывает стоимость доставки для разных типов товаров. Создайте классы `Electronics`, `Clothing` и `Food`, у каждого из которых есть метод `delivery_cost()`, возвращающий стоимость доставки: для электроники — 500, для одежды — 300, для еды — 150. Напишите функцию `show_delivery(item)`, которая принимает любой товар и выводит стоимость его доставки. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Manager` (менеджер магазина), в котором есть три поля: `name` — публичное, `_department` — защищённое (отдел), `__bonus` — приватное (премия). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__bonus` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Магазину нужна утилита для проверки артикулов товаров. Создайте класс `ShopUtils` со статическим методом `is_valid_sku(sku)`, который возвращает `True`, если строка начинается с букв «SKU» и её длина равна 10, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `ShopItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Electronics` и `Clothing`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание товара. Проверьте, что объект абстрактного класса `ShopItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого товара в магазине есть упаковка. Создайте класс `Packaging` с методом `show()`, который выводит строку «Картонная коробка». Создайте класс `Product`, который содержит объект класса `Packaging` внутри себя как поле. Метод `show_product()` у товара должен выводить название товара и вызывать метод `show()` у его упаковки.
#
# **Задача 9 (переопределение методов).** В магазине есть базовый класс `ShopItem` с методом `get_info()`, который возвращает строку «Товар магазина». Унаследуйте от него класс `Electronics` и переопределите метод `get_info()` так, чтобы он возвращал строку «Электроника: <название>». Создайте объект класса `Electronics`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Менеджеру нужен метод для оформления заказов. Создайте класс `OrderDesk` с методом `create(...)`, который принимает разное количество аргументов: при вызове `create(product)` оформляется заказ на один товар, при `create(product, count)` — заказ на несколько единиц товара, при `create(product, count, customer)` — заказ с указанием покупателя. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.

# %% [markdown]
# # Вариант 3. Университет
#
# **Задача 1 (создание класса, конструктор, метод).** В университете ведётся учёт студентов. Создайте класс `Student` с полями `name` (имя), `group` (группа) и `gpa` (средний балл). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о студенте в формате: Имя — группа, средний балл. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого студента есть номер зачётной книжки, который нельзя менять или читать напрямую. Создайте класс `StudentRecord`, в котором номер зачётной книжки хранится в приватном поле `__record_id`. Реализуйте метод `set_record_id(value)`, предназначенный только для установки номера при зачислении, и метод `get_record_id()` для чтения значения. Повторная попытка изменить номер после зачисления должна игнорироваться.
#
# **Задача 3 (наследование).** В университете обучаются разные категории студентов. Создайте базовый класс `Person` с методом `get_role()`, возвращающим строку «Человек». Унаследуйте от него классы `Student` и `Teacher`, переопределив в каждом метод `get_role()` так, чтобы он возвращал «Студент» и «Преподаватель» соответственно. Создайте по одному объекту каждого класса и выведите их роль.
#
# **Задача 4 (полиморфизм).** Университет начисляет стипендию разным категориям студентов. Создайте классы `ExcellentStudent`, `GoodStudent` и `AverageStudent`, у каждого из которых есть метод `scholarship()`, возвращающий размер стипендии: для отличника — 5000, для хорошиста — 3000, для троечника — 0. Напишите функцию `show_scholarship(student)`, которая принимает любого студента и выводит размер его стипендии. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Dean` (декан), в котором есть три поля: `name` — публичное, `_faculty` — защищённое (факультет), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Университету нужна утилита для проверки студенческих билетов. Создайте класс `UniUtils` со статическим методом `is_valid_ticket(ticket)`, который возвращает `True`, если строка начинается с букв «ST» и её длина равна 8, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `UniversityMember` с абстрактным методом `describe()`. Унаследуйте от него классы `Student` и `Teacher`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание участника. Проверьте, что объект абстрактного класса `UniversityMember` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого студента есть студенческий билет. Создайте класс `StudentID` с методом `show()`, который выводит строку «Студенческий билет выдан». Создайте класс `Student`, который содержит объект класса `StudentID` внутри себя как поле. Метод `show_student()` у студента должен выводить имя студента и вызывать метод `show()` у его билета.
#
# **Задача 9 (переопределение методов).** В университете есть базовый класс `UniversityMember` с методом `get_info()`, который возвращает строку «Участник университета». Унаследуйте от него класс `Teacher` и переопределите метод `get_info()` так, чтобы он возвращал строку «Преподаватель: <имя>». Создайте объект класса `Teacher`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Секретарю деканата нужен метод для оформления заявок. Создайте класс `RequestDesk` с методом `submit(...)`, который принимает разное количество аргументов: при вызове `submit(student)` оформляется заявка от одного студента, при `submit(student, topic)` — заявка с указанием темы, при `submit(student, topic, teacher)` — заявка с указанием научного руководителя. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.

# %% [markdown]
# # Вариант 4. Больница
#
# **Задача 1 (создание класса, конструктор, метод).** В больнице ведётся учёт пациентов. Создайте класс `Patient` с полями `name` (имя), `age` (возраст) и `diagnosis` (диагноз). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о пациенте в формате: Имя — возраст, диагноз. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого пациента есть номер медицинской карты, который нельзя менять или читать напрямую. Создайте класс `MedicalCard`, в котором номер карты хранится в приватном поле `__card_id`. Реализуйте метод `set_card_id(value)`, предназначенный только для установки номера при поступлении, и метод `get_card_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В больнице работают разные категории сотрудников. Создайте базовый класс `HospitalWorker` с методом `get_position()`, возвращающим строку «Сотрудник». Унаследуйте от него классы `Doctor` и `Nurse`, переопределив в каждом метод `get_position()` так, чтобы он возвращал «Врач» и «Медсестра» соответственно. Создайте по одному объекту каждого класса и выведите их должность.
#
# **Задача 4 (полиморфизм).** Больница рассчитывает стоимость приёма для разных специалистов. Создайте классы `Therapist`, `Surgeon` и `Dentist`, у каждого из которых есть метод `appointment_cost()`, возвращающий стоимость приёма: у терапевта — 1000, у хирурга — 2500, у стоматолога — 1800. Напишите функцию `show_cost(doctor)`, которая принимает любого врача и выводит стоимость его приёма. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `HeadDoctor` (главный врач), в котором есть три поля: `name` — публичное, `_department` — защищённое (отделение), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Больнице нужна утилита для проверки номеров страховых полисов. Создайте класс `HospitalUtils` со статическим методом `is_valid_policy(policy)`, который возвращает `True`, если строка состоит только из цифр и её длина равна 16, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `HospitalMember` с абстрактным методом `describe()`. Унаследуйте от него классы `Doctor` и `Patient`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание участника. Проверьте, что объект абстрактного класса `HospitalMember` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого пациента есть палата. Создайте класс `Room` с методом `show()`, который выводит строку «Палата №» вместе с номером. Создайте класс `Patient`, который содержит объект класса `Room` внутри себя как поле. Метод `show_patient()` у пациента должен выводить имя пациента и вызывать метод `show()` у его палаты.
#
# **Задача 9 (переопределение методов).** В больнице есть базовый класс `HospitalMember` с методом `get_info()`, который возвращает строку «Участник больницы». Унаследуйте от него класс `Doctor` и переопределите метод `get_info()` так, чтобы он возвращал строку «Врач: <имя>». Создайте объект класса `Doctor`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Регистратору нужен метод для оформления записей на приём. Создайте класс `ReceptionDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(patient)` оформляется запись одного пациента, при `book(patient, doctor)` — запись к конкретному врачу, при `book(patient, doctor, time)` — запись с указанием времени приёма. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.

# %% [markdown]
# # Вариант 5. Автосалон
#
# **Задача 1 (создание класса, конструктор, метод).** В автосалоне ведётся учёт автомобилей. Создайте класс `Car` с полями `brand` (марка), `model` (модель) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об автомобиле в формате: Марка — модель, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого автомобиля есть VIN-номер, который нельзя менять или читать напрямую. Создайте класс `CarPassport`, в котором VIN-номер хранится в приватном поле `__vin`. Реализуйте метод `set_vin(value)`, предназначенный только для установки номера при постановке на учёт, и метод `get_vin()` для чтения значения. Повторная попытка изменить номер после постановки на учёт должна игнорироваться.
#
# **Задача 3 (наследование).** В автосалоне продаются разные типы транспорта. Создайте базовый класс `Vehicle` с методом `get_kind()`, возвращающим строку «Транспорт». Унаследуйте от него классы `Car` и `Motorcycle`, переопределив в каждом метод `get_kind()` так, чтобы он возвращал «Автомобиль» и «Мотоцикл» соответственно. Создайте по одному объекту каждого класса и выведите их вид.
#
# **Задача 4 (полиморфизм).** Автосалон рассчитывает налог для разных типов транспорта. Создайте классы `Sedan`, `SUV` и `SportCar`, у каждого из которых есть метод `tax()`, возвращающий размер налога: для седана — 5000, для внедорожника — 12000, для спорткара — 25000. Напишите функцию `show_tax(vehicle)`, которая принимает любой транспорт и выводит размер его налога. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `SalesManager` (менеджер по продажам), в котором есть три поля: `name` — публичное, `_department` — защищённое (отдел продаж), `__commission` — приватное (процент комиссии). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__commission` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Автосалону нужна утилита для проверки государственных номеров. Создайте класс `AutoUtils` со статическим методом `is_valid_plate(plate)`, который возвращает `True`, если строка начинается с букв «AB» и её длина равна 7, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `AutoItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Car` и `Motorcycle`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание транспорта. Проверьте, что объект абстрактного класса `AutoItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого автомобиля есть двигатель. Создайте класс `Engine` с методом `show()`, который выводит строку «Бензиновый двигатель». Создайте класс `Car`, который содержит объект класса `Engine` внутри себя как поле. Метод `show_car()` у автомобиля должен выводить модель автомобиля и вызывать метод `show()` у его двигателя.
#
# **Задача 9 (переопределение методов).** В автосалоне есть базовый класс `AutoItem` с методом `get_info()`, который возвращает строку «Транспорт автосалона». Унаследуйте от него класс `Car` и переопределите метод `get_info()` так, чтобы он возвращал строку «Автомобиль: <марка> <модель>». Создайте объект класса `Car`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Менеджеру автосалона нужен метод для оформления заказов. Создайте класс `OrderDesk` с методом `place(...)`, который принимает разное количество аргументов: при вызове `place(car)` оформляется заказ на один автомобиль, при `place(car, buyer)` — заказ с указанием покупателя, при `place(car, buyer, extras)` — заказ с указанием дополнительных опций. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.

# %% [markdown]
# # Вариант 6. Банк
#
# **Задача 1 (создание класса, конструктор, метод).** В банке ведётся учёт клиентов. Создайте класс `Client` с полями `name` (имя), `account_number` (номер счёта) и `balance` (баланс). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о клиенте в формате: Имя — счёт №..., баланс: ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого банковского счёта есть ПИН-код, который нельзя менять или читать напрямую. Создайте класс `BankCard`, в котором ПИН-код хранится в приватном поле `__pin`. Реализуйте метод `set_pin(value)`, предназначенный только для установки ПИН-кода при выпуске карты, и метод `check_pin(value)` для проверки введённого ПИН-кода. Повторная попытка изменить ПИН-код после выпуска должна игнорироваться.
#
# **Задача 3 (наследование).** В банке обслуживаются разные типы счетов. Создайте базовый класс `Account` с методом `get_account_type()`, возвращающим строку «Счёт». Унаследуйте от него классы `DepositAccount` и `CreditAccount`, переопределив в каждом метод `get_account_type()` так, чтобы он возвращал «Депозитный счёт» и «Кредитный счёт» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Банк начисляет процент по разным типам вкладов. Создайте классы `ShortDeposit`, `MediumDeposit` и `LongDeposit`, у каждого из которых есть метод `interest_rate()`, возвращающий процентную ставку: для краткосрочного — 5, для среднесрочного — 8, для долгосрочного — 12. Напишите функцию `show_rate(deposit)`, которая принимает любой вклад и выводит его ставку. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `BankManager` (управляющий банка), в котором есть три поля: `name` — публичное, `_branch` — защищённое (филиал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Банку нужна утилита для проверки номеров карт. Создайте класс `BankUtils` со статическим методом `is_valid_card(card)`, который возвращает `True`, если строка состоит только из цифр и её длина равна 16, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `BankProduct` с абстрактным методом `describe()`. Унаследуйте от него классы `DepositAccount` и `CreditAccount`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание продукта. Проверьте, что объект абстрактного класса `BankProduct` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого клиента банка есть паспорт. Создайте класс `Passport` с методом `show()`, который выводит строку «Паспорт предъявлен». Создайте класс `Client`, который содержит объект класса `Passport` внутри себя как поле. Метод `show_client()` у клиента должен выводить имя клиента и вызывать метод `show()` у его паспорта.
#
# **Задача 9 (переопределение методов).** В банке есть базовый класс `BankProduct` с методом `get_info()`, который возвращает строку «Банковский продукт». Унаследуйте от него класс `DepositAccount` и переопределите метод `get_info()` так, чтобы он возвращал строку «Депозит: <имя клиента>». Создайте объект класса `DepositAccount`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Операционисту нужен метод для оформления операций. Создайте класс `OperationDesk` с методом `process(...)`, который принимает разное количество аргументов: при вызове `process(client)` оформляется запрос клиента, при `process(client, amount)` — операция с указанием суммы, при `process(client, amount, operation)` — операция с указанием её типа (например, «снятие» или «пополнение»). Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 7. Аэропорт
#
# **Задача 1 (создание класса, конструктор, метод).** В аэропорту ведётся учёт пассажиров. Создайте класс `Passenger` с полями `name` (имя), `flight_number` (номер рейса) и `seat` (место). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о пассажире в формате: Имя — рейс №..., место ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого пассажира есть номер паспорта, который нельзя менять или читать напрямую. Создайте класс `Passport`, в котором номер паспорта хранится в приватном поле `__passport_id`. Реализуйте метод `set_passport_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_passport_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В аэропорту работают разные категории сотрудников. Создайте базовый класс `AirportWorker` с методом `get_position()`, возвращающим строку «Сотрудник». Унаследуйте от него классы `Pilot` и `Stewardess`, переопределив в каждом метод `get_position()` так, чтобы он возвращал «Пилот» и «Стюардесса» соответственно. Создайте по одному объекту каждого класса и выведите их должность.
#
# **Задача 4 (полиморфизм).** Аэропорт рассчитывает стоимость билета для разных классов обслуживания. Создайте классы `EconomyClass`, `BusinessClass` и `FirstClass`, у каждого из которых есть метод `ticket_price()`, возвращающий стоимость билета: для эконом-класса — 10000, для бизнес-класса — 35000, для первого класса — 70000. Напишите функцию `show_price(ticket)`, которая принимает любой класс обслуживания и выводит стоимость билета. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Dispatcher` (диспетчер), в котором есть три поля: `name` — публичное, `_shift` — защищённое (смена), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Аэропорту нужна утилита для проверки номеров рейсов. Создайте класс `AirportUtils` со статическим методом `is_valid_flight(flight)`, который возвращает `True`, если строка начинается с букв «SU» и её длина равна 6, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `AirportMember` с абстрактным методом `describe()`. Унаследуйте от него классы `Pilot` и `Passenger`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание участника. Проверьте, что объект абстрактного класса `AirportMember` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого пассажира есть багаж. Создайте класс `Luggage` с методом `show()`, который выводит строку «Багаж зарегистрирован». Создайте класс `Passenger`, который содержит объект класса `Luggage` внутри себя как поле. Метод `show_passenger()` у пассажира должен выводить имя пассажира и вызывать метод `show()` у его багажа.
#
# **Задача 9 (переопределение методов).** В аэропорту есть базовый класс `AirportMember` с методом `get_info()`, который возвращает строку «Участник аэропорта». Унаследуйте от него класс `Pilot` и переопределите метод `get_info()` так, чтобы он возвращал строку «Пилот: <имя>». Создайте объект класса `Pilot`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Сотруднику стойки регистрации нужен метод для оформления регистрации. Создайте класс `CheckInDesk` с методом `check_in(...)`, который принимает разное количество аргументов: при вызове `check_in(passenger)` регистрируется один пассажир, при `check_in(passenger, flight)` — регистрация с указанием рейса, при `check_in(passenger, flight, seat)` — регистрация с указанием места. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 8. Кинотеатр
#
# **Задача 1 (создание класса, конструктор, метод).** В кинотеатре ведётся учёт фильмов. Создайте класс `Movie` с полями `title` (название), `genre` (жанр) и `duration` (длительность в минутах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о фильме в формате: Название — жанр, длительность ... мин. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого билета в кинотеатр есть уникальный код, который нельзя менять или читать напрямую. Создайте класс `Ticket`, в котором код билета хранится в приватном поле `__ticket_code`. Реализуйте метод `set_ticket_code(value)`, предназначенный только для установки кода при продаже билета, и метод `get_ticket_code()` для чтения значения. Повторная попытка изменить код после продажи должна игнорироваться.
#
# **Задача 3 (наследование).** В кинотеатре есть разные типы сеансов. Создайте базовый класс `Session` с методом `get_session_type()`, возвращающим строку «Сеанс». Унаследуйте от него классы `MorningSession` и `EveningSession`, переопределив в каждом метод `get_session_type()` так, чтобы он возвращал «Утренний сеанс» и «Вечерний сеанс» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Кинотеатр рассчитывает стоимость билета для разных категорий зрителей. Создайте классы `AdultTicket`, `ChildTicket` и `StudentTicket`, у каждого из которых есть метод `price()`, возвращающий стоимость билета: для взрослого — 800, для детского — 400, для студенческого — 600. Напишите функцию `show_price(ticket)`, которая принимает любой билет и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Administrator` (администратор кинотеатра), в котором есть три поля: `name` — публичное, `_hall` — защищённое (зал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Кинотеатру нужна утилита для проверки кодов бронирования. Создайте класс `CinemaUtils` со статическим методом `is_valid_booking(code)`, который возвращает `True`, если строка начинается с букв «BK» и её длина равна 8, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `CinemaItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Movie` и `Session`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `CinemaItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого фильма есть возрастное ограничение. Создайте класс `AgeRating` с методом `show()`, который выводит строку «18+». Создайте класс `Movie`, который содержит объект класса `AgeRating` внутри себя как поле. Метод `show_movie()` у фильма должен выводить название фильма и вызывать метод `show()` у его возрастного ограничения.
#
# **Задача 9 (переопределение методов).** В кинотеатре есть базовый класс `CinemaItem` с методом `get_info()`, который возвращает строку «Объект кинотеатра». Унаследуйте от него класс `Movie` и переопределите метод `get_info()` так, чтобы он возвращал строку «Фильм: <название>». Создайте объект класса `Movie`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру нужен метод для продажи билетов. Создайте класс `CashDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(movie)` продаётся один билет, при `sell(movie, count)` — несколько билетов, при `sell(movie, count, session)` — билеты на конкретный сеанс. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 9. Ресторан
#
# **Задача 1 (создание класса, конструктор, метод).** В ресторане ведётся учёт блюд. Создайте класс `Dish` с полями `name` (название), `category` (категория: суп, горячее, десерт) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о блюде в формате: Название — категория, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого заказа в ресторане есть внутренний номер, который нельзя менять или читать напрямую. Создайте класс `Order`, в котором номер заказа хранится в приватном поле `__order_id`. Реализуйте метод `set_order_id(value)`, предназначенный только для установки номера при оформлении заказа, и метод `get_order_id()` для чтения значения. Повторная попытка изменить номер после оформления должна игнорироваться.
#
# **Задача 3 (наследование).** В ресторане работают разные категории сотрудников. Создайте базовый класс `Staff` с методом `get_position()`, возвращающим строку «Сотрудник». Унаследуйте от него классы `Chef` и `Waiter`, переопределив в каждом метод `get_position()` так, чтобы он возвращал «Повар» и «Официант» соответственно. Создайте по одному объекту каждого класса и выведите их должность.
#
# **Задача 4 (полиморфизм).** Ресторан рассчитывает стоимость приготовления для разных типов блюд. Создайте классы `Soup`, `MainCourse` и `Dessert`, у каждого из которых есть метод `cook_time()`, возвращающий время приготовления в минутах: для супа — 30, для горячего — 45, для десерта — 15. Напишите функцию `show_cook_time(dish)`, которая принимает любое блюдо и выводит время его приготовления. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `RestaurantManager` (управляющий ресторана), в котором есть три поля: `name` — публичное, `_hall` — защищённое (зал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Ресторану нужна утилита для проверки номеров столиков. Создайте класс `RestaurantUtils` со статическим методом `is_valid_table(number)`, который возвращает `True`, если число находится в диапазоне от 1 до 50, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `MenuItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Dish` и `Drink`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание позиции меню. Проверьте, что объект абстрактного класса `MenuItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого блюда есть тарелка для подачи. Создайте класс `Plate` с методом `show()`, который выводит строку «Круглая тарелка». Создайте класс `Dish`, который содержит объект класса `Plate` внутри себя как поле. Метод `show_dish()` у блюда должен выводить название блюда и вызывать метод `show()` у его тарелки.
#
# **Задача 9 (переопределение методов).** В ресторане есть базовый класс `MenuItem` с методом `get_info()`, который возвращает строку «Позиция меню». Унаследуйте от него класс `Dish` и переопределите метод `get_info()` так, чтобы он возвращал строку «Блюдо: <название>». Создайте объект класса `Dish`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Официанту нужен метод для оформления заказов. Создайте класс `OrderDesk` с методом `take(...)`, который принимает разное количество аргументов: при вызове `take(dish)` оформляется заказ на одно блюдо, при `take(dish, quantity)` — заказ на несколько порций, при `take(dish, quantity, table)` — заказ с указанием столика. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 10. Школа
#
# **Задача 1 (создание класса, конструктор, метод).** В школе ведётся учёт учеников. Создайте класс `Pupil` с полями `name` (имя), `grade` (класс) и `average_mark` (средняя оценка). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об ученике в формате: Имя — класс ..., средняя оценка ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого ученика есть номер личного дела, который нельзя менять или читать напрямую. Создайте класс `StudentFile`, в котором номер личного дела хранится в приватном поле `__file_id`. Реализуйте метод `set_file_id(value)`, предназначенный только для установки номера при зачислении, и метод `get_file_id()` для чтения значения. Повторная попытка изменить номер после зачисления должна игнорироваться.
#
# **Задача 3 (наследование).** В школе работают и учатся разные категории людей. Создайте базовый класс `SchoolMember` с методом `get_role()`, возвращающим строку «Участник школы». Унаследуйте от него классы `Pupil` и `Teacher`, переопределив в каждом метод `get_role()` так, чтобы он возвращал «Ученик» и «Учитель» соответственно. Создайте по одному объекту каждого класса и выведите их роль.
#
# **Задача 4 (полиморфизм).** Школа рассчитывает недельную нагрузку для разных предметов. Создайте классы `MathLesson`, `LiteratureLesson` и `PhysicsLesson`, у каждого из которых есть метод `hours_per_week()`, возвращающий количество часов в неделю: для математики — 6, для литературы — 4, для физики — 5. Напишите функцию `show_hours(lesson)`, которая принимает любой урок и выводит количество часов. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Principal` (директор школы), в котором есть три поля: `name` — публичное, `_office` — защищённое (кабинет), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Школе нужна утилита для проверки номеров дневников. Создайте класс `SchoolUtils` со статическим методом `is_valid_diary(number)`, который возвращает `True`, если число находится в диапазоне от 1 до 1000, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `SchoolItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Pupil` и `Teacher`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание участника. Проверьте, что объект абстрактного класса `SchoolItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого ученика есть портфель. Создайте класс `Backpack` с методом `show()`, который выводит строку «Портфель полон учебников». Создайте класс `Pupil`, который содержит объект класса `Backpack` внутри себя как поле. Метод `show_pupil()` у ученика должен выводить имя ученика и вызывать метод `show()` у его портфеля.
#
# **Задача 9 (переопределение методов).** В школе есть базовый класс `SchoolItem` с методом `get_info()`, который возвращает строку «Объект школы». Унаследуйте от него класс `Teacher` и переопределите метод `get_info()` так, чтобы он возвращал строку «Учитель: <имя>». Создайте объект класса `Teacher`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Секретарю школы нужен метод для оформления справок. Создайте класс `DocumentDesk` с методом `issue(...)`, который принимает разное количество аргументов: при вызове `issue(pupil)` оформляется справка одному ученику, при `issue(pupil, reason)` — справка с указанием причины, при `issue(pupil, reason, teacher)` — справка, заверенная учителем. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 11. Отель
#
# **Задача 1 (создание класса, конструктор, метод).** В отеле ведётся учёт гостей. Создайте класс `Guest` с полями `name` (имя), `room_number` (номер комнаты) и `nights` (количество ночей). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о госте в формате: Имя — комната №..., ночей: ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого гостя есть номер брони, который нельзя менять или читать напрямую. Создайте класс `Booking`, в котором номер брони хранится в приватном поле `__booking_id`. Реализуйте метод `set_booking_id(value)`, предназначенный только для установки номера при заселении, и метод `get_booking_id()` для чтения значения. Повторная попытка изменить номер после заселения должна игнорироваться.
#
# **Задача 3 (наследование).** В отеле есть разные типы номеров. Создайте базовый класс `Room` с методом `get_room_type()`, возвращающим строку «Номер». Унаследуйте от него классы `StandardRoom` и `LuxRoom`, переопределив в каждом метод `get_room_type()` так, чтобы он возвращал «Стандарт» и «Люкс» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Отель рассчитывает стоимость проживания для разных типов номеров. Создайте классы `EconomyRoom`, `StandardRoom` и `LuxRoom`, у каждого из которых есть метод `price_per_night()`, возвращающий стоимость за ночь: для эконом-номера — 2000, для стандарта — 4000, для люкса — 9000. Напишите функцию `show_price(room)`, которая принимает любой номер и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `HotelManager` (управляющий отеля), в котором есть три поля: `name` — публичное, `_floor` — защищённое (этаж), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Отелю нужна утилита для проверки номеров комнат. Создайте класс `HotelUtils` со статическим методом `is_valid_room(number)`, который возвращает `True`, если число находится в диапазоне от 100 до 999, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `HotelItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Room` и `Service`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `HotelItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого номера в отеле есть ключ-карта. Создайте класс `KeyCard` с методом `show()`, который выводит строку «Ключ-карта активирована». Создайте класс `Room`, который содержит объект класса `KeyCard` внутри себя как поле. Метод `show_room()` у номера должен выводить его тип и вызывать метод `show()` у ключ-карты.
#
# **Задача 9 (переопределение методов).** В отеле есть базовый класс `HotelItem` с методом `get_info()`, который возвращает строку «Объект отеля». Унаследуйте от него класс `LuxRoom` и переопределите метод `get_info()` так, чтобы он возвращал строку «Люкс: комната <номер>». Создайте объект класса `LuxRoom`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Портье нужен метод для оформления услуг. Создайте класс `ServiceDesk` с методом `order(...)`, который принимает разное количество аргументов: при вызове `order(guest)` оформляется запрос гостя, при `order(guest, service)` — заказ конкретной услуги, при `order(guest, service, time)` — заказ услуги с указанием времени. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 12. Зоопарк
#
# **Задача 1 (создание класса, конструктор, метод).** В зоопарке ведётся учёт животных. Создайте класс `Animal` с полями `name` (кличка), `species` (вид) и `age` (возраст). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о животном в формате: Кличка — вид, возраст ... лет. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого животного есть номер чипа, который нельзя менять или читать напрямую. Создайте класс `Chip`, в котором номер чипа хранится в приватном поле `__chip_id`. Реализуйте метод `set_chip_id(value)`, предназначенный только для установки номера при регистрации животного, и метод `get_chip_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В зоопарке живут разные классы животных. Создайте базовый класс `Creature` с методом `get_class()`, возвращающим строку «Существо». Унаследуйте от него классы `Mammal` и `Bird`, переопределив в каждом метод `get_class()` так, чтобы он возвращал «Млекопитающее» и «Птица» соответственно. Создайте по одному объекту каждого класса и выведите их класс.
#
# **Задача 4 (полиморфизм).** Зоопарк рассчитывает суточный рацион для разных животных. Создайте классы `Lion`, `Elephant` и `Monkey`, у каждого из которых есть метод `daily_food()`, возвращающий количество килограммов еды в день: для льва — 8, для слона — 150, для обезьяны — 3. Напишите функцию `show_food(animal)`, которая принимает любое животное и выводит его рацион. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `ZooDirector` (директор зоопарка), в котором есть три поля: `name` — публичное, `_sector` — защищённое (сектор), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Зоопарку нужна утилита для проверки номеров вольеров. Создайте класс `ZooUtils` со статическим методом `is_valid_enclosure(number)`, который возвращает `True`, если число находится в диапазоне от 1 до 200, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `ZooItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Animal` и `Enclosure`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `ZooItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого животного есть вольер. Создайте класс `Enclosure` с методом `show()`, который выводит строку «Просторный вольер». Создайте класс `Animal`, который содержит объект класса `Enclosure` внутри себя как поле. Метод `show_animal()` у животного должен выводить кличку и вызывать метод `show()` у его вольера.
#
# **Задача 9 (переопределение методов).** В зоопарке есть базовый класс `ZooItem` с методом `get_info()`, который возвращает строку «Объект зоопарка». Унаследуйте от него класс `Animal` и переопределите метод `get_info()` так, чтобы он возвращал строку «Животное: <кличка>». Создайте объект класса `Animal`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Смотрителю зоопарка нужен метод для регистрации кормлений. Создайте класс `FeedDesk` с методом `feed(...)`, который принимает разное количество аргументов: при вызове `feed(animal)` регистрируется кормление одного животного, при `feed(animal, food)` — кормление с указанием корма, при `feed(animal, food, time)` — кормление с указанием времени. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 13. Фитнес-клуб
#
# **Задача 1 (создание класса, конструктор, метод).** В фитнес-клубе ведётся учёт клиентов. Создайте класс `Member` с полями `name` (имя), `membership_type` (тип абонемента) и `months` (срок в месяцах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о клиенте в формате: Имя — абонемент ..., на ... мес. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента есть номер клубной карты, который нельзя менять или читать напрямую. Создайте класс `ClubCard`, в котором номер карты хранится в приватном поле `__card_id`. Реализуйте метод `set_card_id(value)`, предназначенный только для установки номера при оформлении, и метод `get_card_id()` для чтения значения. Повторная попытка изменить номер после оформления должна игнорироваться.
#
# **Задача 3 (наследование).** В фитнес-клубе есть разные типы тренировок. Создайте базовый класс `Workout` с методом `get_workout_type()`, возвращающим строку «Тренировка». Унаследуйте от него классы `Yoga` и `Boxing`, переопределив в каждом метод `get_workout_type()` так, чтобы он возвращал «Йога» и «Бокс» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Фитнес-клуб рассчитывает стоимость занятия для разных типов тренировок. Создайте классы `Yoga`, `Boxing` и `CrossFit`, у каждого из которых есть метод `session_price()`, возвращающий стоимость занятия: для йоги — 500, для бокса — 800, для кроссфита — 1000. Напишите функцию `show_price(workout)`, которая принимает любую тренировку и выводит её стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Trainer` (тренер), в котором есть три поля: `name` — публичное, `_specialization` — защищённое (специализация), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Фитнес-клубу нужна утилита для проверки номеров шкафчиков. Создайте класс `FitnessUtils` со статическим методом `is_valid_locker(number)`, который возвращает `True`, если число находится в диапазоне от 1 до 300, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `FitnessItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Workout` и `Trainer`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `FitnessItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого клиента есть абонемент. Создайте класс `Subscription` с методом `show()`, который выводит строку «Абонемент активен». Создайте класс `Member`, который содержит объект класса `Subscription` внутри себя как поле. Метод `show_member()` у клиента должен выводить имя клиента и вызывать метод `show()` у его абонемента.
#
# **Задача 9 (переопределение методов).** В фитнес-клубе есть базовый класс `FitnessItem` с методом `get_info()`, который возвращает строку «Объект клуба». Унаследуйте от него класс `Trainer` и переопределите метод `get_info()` так, чтобы он возвращал строку «Тренер: <имя>». Создайте объект класса `Trainer`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору фитнес-клуба нужен метод для записи на тренировки. Создайте класс `BookingDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(member)` оформляется запись клиента, при `book(member, workout)` — запись на конкретную тренировку, при `book(member, workout, trainer)` — запись к конкретному тренеру. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 14. Аптека
#
# **Задача 1 (создание класса, конструктор, метод).** В аптеке ведётся учёт лекарств. Создайте класс `Medicine` с полями `name` (название), `form` (форма выпуска: таблетки, сироп, мазь) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о лекарстве в формате: Название — форма, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого лекарства есть номер партии, который нельзя менять или читать напрямую. Создайте класс `Batch`, в котором номер партии хранится в приватном поле `__batch_id`. Реализуйте метод `set_batch_id(value)`, предназначенный только для установки номера при поставке, и метод `get_batch_id()` для чтения значения. Повторная попытка изменить номер после поставки должна игнорироваться.
#
# **Задача 3 (наследование).** В аптеке есть разные категории товаров. Создайте базовый класс `PharmacyItem` с методом `get_category()`, возвращающим строку «Товар аптеки». Унаследуйте от него классы `Medicine` и `Vitamin`, переопределив в каждом метод `get_category()` так, чтобы он возвращал «Лекарство» и «Витамин» соответственно. Создайте по одному объекту каждого класса и выведите их категорию.
#
# **Задача 4 (полиморфизм).** Аптека рассчитывает размер скидки для разных категорий товаров. Создайте классы `Medicine`, `Vitamin` и `Cosmetic`, у каждого из которых есть метод `discount()`, возвращающий процент скидки: для лекарства — 5, для витамина — 10, для косметики — 15. Напишите функцию `show_discount(item)`, которая принимает любой товар и выводит его скидку. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Pharmacist` (фармацевт), в котором есть три поля: `name` — публичное, `_department` — защищённое (отдел), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Аптеке нужна утилита для проверки штрих-кодов. Создайте класс `PharmacyUtils` со статическим методом `is_valid_barcode(code)`, который возвращает `True`, если строка состоит только из цифр и её длина равна 13, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `PharmacyProduct` с абстрактным методом `describe()`. Унаследуйте от него классы `Medicine` и `Vitamin`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `PharmacyProduct` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой упаковки лекарства есть инструкция. Создайте класс `Instruction` с методом `show()`, который выводит строку «Инструкция прилагается». Создайте класс `Medicine`, который содержит объект класса `Instruction` внутри себя как поле. Метод `show_medicine()` у лекарства должен выводить название и вызывать метод `show()` у его инструкции.
#
# **Задача 9 (переопределение методов).** В аптеке есть базовый класс `PharmacyProduct` с методом `get_info()`, который возвращает строку «Товар аптеки». Унаследуйте от него класс `Medicine` и переопределите метод `get_info()` так, чтобы он возвращал строку «Лекарство: <название>». Создайте объект класса `Medicine`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Провизору нужен метод для оформления заказов. Создайте класс `OrderDesk` с методом `order(...)`, который принимает разное количество аргументов: при вызове `order(medicine)` оформляется заказ одного лекарства, при `order(medicine, quantity)` — заказ с указанием количества, при `order(medicine, quantity, customer)` — заказ с указанием покупателя. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 15. IT-компания
#
# **Задача 1 (создание класса, конструктор, метод).** В IT-компании ведётся учёт сотрудников. Создайте класс `Employee` с полями `name` (имя), `position` (должность) и `experience` (стаж в годах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о сотруднике в формате: Имя — должность, стаж ... лет. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого сотрудника есть размер зарплаты, который нельзя менять или читать напрямую. Создайте класс `Contract`, в котором зарплата хранится в приватном поле `__salary`. Реализуйте метод `set_salary(value)`, предназначенный только для установки зарплаты при приёме на работу, и метод `get_salary()` для чтения значения. Повторная попытка изменить зарплату после подписания контракта должна игнорироваться.
#
# **Задача 3 (наследование).** В IT-компании работают разные категории сотрудников. Создайте базовый класс `Staff` с методом `get_role()`, возвращающим строку «Сотрудник». Унаследуйте от него классы `Developer` и `Manager`, переопределив в каждом метод `get_role()` так, чтобы он возвращал «Разработчик» и «Менеджер» соответственно. Создайте по одному объекту каждого класса и выведите их роль.
#
# **Задача 4 (полиморфизм).** IT-компания рассчитывает месячную стоимость сотрудника для разных ролей. Создайте классы `Junior`, `Middle` и `Senior`, у каждого из которых есть метод `monthly_cost()`, возвращающий стоимость: для джуна — 100000, для мидла — 200000, для сеньора — 350000. Напишите функцию `show_cost(dev)`, которая принимает любого разработчика и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `TeamLead` (тимлид), в котором есть три поля: `name` — публичное, `_project` — защищённое (проект), `__bonus` — приватное (бонус). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__bonus` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** IT-компании нужна утилита для проверки email-адресов сотрудников. Создайте класс `CompanyUtils` со статическим методом `is_valid_email(email)`, который возвращает `True`, если строка содержит символ `@` и заканчивается на `.com`, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `CompanyMember` с абстрактным методом `describe()`. Унаследуйте от него классы `Developer` и `Manager`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `CompanyMember` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого сотрудника есть ноутбук. Создайте класс `Laptop` с методом `show()`, который выводит строку «Рабочий ноутбук выдан». Создайте класс `Employee`, который содержит объект класса `Laptop` внутри себя как поле. Метод `show_employee()` у сотрудника должен выводить имя и вызывать метод `show()` у его ноутбука.
#
# **Задача 9 (переопределение методов).** В IT-компании есть базовый класс `CompanyMember` с методом `get_info()`, который возвращает строку «Участник компании». Унаследуйте от него класс `Developer` и переопределите метод `get_info()` так, чтобы он возвращал строку «Разработчик: <имя>». Создайте объект класса `Developer`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** HR-менеджеру нужен метод для оформления заявок. Создайте класс `HRDesk` с методом `submit(...)`, который принимает разное количество аргументов: при вызове `submit(employee)` оформляется заявка сотрудника, при `submit(employee, type)` — заявка с указанием типа (отпуск, больничный), при `submit(employee, type, days)` — заявка с указанием количества дней. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 16. Почта
#
# **Задача 1 (создание класса, конструктор, метод).** На почте ведётся учёт отправлений. Создайте класс `Parcel` с полями `sender` (отправитель), `recipient` (получатель) и `weight` (вес в граммах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об отправлении в формате: От: ... Кому: ..., вес ... г. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого отправления есть трек-номер, который нельзя менять или читать напрямую. Создайте класс `Tracking`, в котором трек-номер хранится в приватном поле `__track_id`. Реализуйте метод `set_track_id(value)`, предназначенный только для установки номера при приёме отправления, и метод `get_track_id()` для чтения значения. Повторная попытка изменить номер после приёма должна игнорироваться.
#
# **Задача 3 (наследование).** На почте есть разные типы отправлений. Создайте базовый класс `MailItem` с методом `get_mail_type()`, возвращающим строку «Отправление». Унаследуйте от него классы `Letter` и `Parcel`, переопределив в каждом метод `get_mail_type()` так, чтобы он возвращал «Письмо» и «Посылка» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Почта рассчитывает стоимость доставки для разных типов отправлений. Создайте классы `Letter`, `Parcel` и `ExpressMail`, у каждого из которых есть метод `delivery_cost()`, возвращающий стоимость: для письма — 50, для посылки — 300, для экспресс-почты — 800. Напишите функцию `show_cost(item)`, которая принимает любое отправление и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Postmaster` (начальник почты), в котором есть три поля: `name` — публичное, `_branch` — защищённое (отделение), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Почте нужна утилита для проверки почтовых индексов. Создайте класс `PostUtils` со статическим методом `is_valid_index(index)`, который возвращает `True`, если строка состоит только из цифр и её длина равна 6, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `PostItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Letter` и `Parcel`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `PostItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой посылки есть упаковочная коробка. Создайте класс `Box` с методом `show()`, который выводит строку «Картонная коробка». Создайте класс `Parcel`, который содержит объект класса `Box` внутри себя как поле. Метод `show_parcel()` у посылки должен выводить имя получателя и вызывать метод `show()` у её коробки.
#
# **Задача 9 (переопределение методов).** На почте есть базовый класс `PostItem` с методом `get_info()`, который возвращает строку «Почтовое отправление». Унаследуйте от него класс `Parcel` и переопределите метод `get_info()` так, чтобы он возвращал строку «Посылка для: <получатель>». Создайте объект класса `Parcel`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Оператору почты нужен метод для оформления отправлений. Создайте класс `PostDesk` с методом `send(...)`, который принимает разное количество аргументов: при вызове `send(parcel)` оформляется отправка одной посылки, при `send(parcel, address)` — отправка с указанием адреса, при `send(parcel, address, express)` — отправка с указанием срочности. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 17. Полиция
#
# **Задача 1 (создание класса, конструктор, метод).** В полицейском участке ведётся учёт сотрудников. Создайте класс `Officer` с полями `name` (имя), `rank` (звание) и `years_of_service` (выслуга лет). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о сотруднике в формате: Имя — звание, выслуга ... лет. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого сотрудника есть номер служебного удостоверения, который нельзя менять или читать напрямую. Создайте класс `Badge`, в котором номер удостоверения хранится в приватном поле `__badge_id`. Реализуйте метод `set_badge_id(value)`, предназначенный только для установки номера при приёме на службу, и метод `get_badge_id()` для чтения значения. Повторная попытка изменить номер после выдачи должна игнорироваться.
#
# **Задача 3 (наследование).** В полиции есть разные подразделения. Создайте базовый класс `PoliceUnit` с методом `get_unit()`, возвращающим строку «Подразделение». Унаследуйте от него классы `Patrol` и `Investigation`, переопределив в каждом метод `get_unit()` так, чтобы он возвращал «Патрульная служба» и «Следственный отдел» соответственно. Создайте по одному объекту каждого класса и выведите их подразделение.
#
# **Задача 4 (полиморфизм).** Полиция рассчитывает уровень опасности для разных вызовов. Создайте классы `TheftCall`, `AccidentCall` и `EmergencyCall`, у каждого из которых есть метод `danger_level()`, возвращающий уровень опасности по шкале от 1 до 10: для кражи — 3, для ДТП — 6, для ЧП — 10. Напишите функцию `show_danger(call)`, которая принимает любой вызов и выводит его уровень опасности. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Chief` (начальник отдела), в котором есть три поля: `name` — публичное, `_department` — защищённое (отдел), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Полиции нужна утилита для проверки номеров протоколов. Создайте класс `PoliceUtils` со статическим методом `is_valid_protocol(number)`, который возвращает `True`, если строка начинается с букв «PR» и её длина равна 7, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `PoliceItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Officer` и `Case`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `PoliceItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого сотрудника есть пистолет. Создайте класс `Weapon` с методом `show()`, который выводит строку «Служебный пистолет выдан». Создайте класс `Officer`, который содержит объект класса `Weapon` внутри себя как поле. Метод `show_officer()` у сотрудника должен выводить имя и вызывать метод `show()` у его оружия.
#
# **Задача 9 (переопределение методов).** В полиции есть базовый класс `PoliceItem` с методом `get_info()`, который возвращает строку «Объект полиции». Унаследуйте от него класс `Officer` и переопределите метод `get_info()` так, чтобы он возвращал строку «Сотрудник: <имя>». Создайте объект класса `Officer`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Дежурному нужен метод для регистрации вызовов. Создайте класс `DutyDesk` с методом `register(...)`, который принимает разное количество аргументов: при вызове `register(call)` регистрируется вызов, при `register(call, address)` — вызов с адресом, при `register(call, address, officer)` — вызов с назначением сотрудника. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 18. Пекарня
#
# **Задача 1 (создание класса, конструктор, метод).** В пекарне ведётся учёт выпечки. Создайте класс `BakeryItem` с полями `name` (название), `type` (тип: хлеб, булочка, пирог) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о выпечке в формате: Название — тип, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого рецепта есть секретный код, который нельзя менять или читать напрямую. Создайте класс `Recipe`, в котором код рецепта хранится в приватном поле `__recipe_code`. Реализуйте метод `set_recipe_code(value)`, предназначенный только для установки кода при разработке рецепта, и метод `get_recipe_code()` для чтения значения. Повторная попытка изменить код после утверждения должна игнорироваться.
#
# **Задача 3 (наследование).** В пекарне есть разные виды изделий. Создайте базовый класс `Baked` с методом `get_kind()`, возвращающим строку «Выпечка». Унаследуйте от него классы `Bread` и `Cake`, переопределив в каждом метод `get_kind()` так, чтобы он возвращал «Хлеб» и «Торт» соответственно. Создайте по одному объекту каждого класса и выведите их вид.
#
# **Задача 4 (полиморфизм).** Пекарня рассчитывает время выпекания для разных изделий. Создайте классы `Bread`, `Bun` и `Pie`, у каждого из которых есть метод `bake_time()`, возвращающий время в минутах: для хлеба — 45, для булочки — 20, для пирога — 60. Напишите функцию `show_bake_time(item)`, которая принимает любое изделие и выводит время его выпекания. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Baker` (пекарь), в котором есть три поля: `name` — публичное, `_shift` — защищённое (смена), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Пекарне нужна утилита для проверки количества муки. Создайте класс `BakeryUtils` со статическим методом `is_enough_flour(kg)`, который возвращает `True`, если количество муки больше 10 кг, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `BakeryProduct` с абстрактным методом `describe()`. Унаследуйте от него классы `Bread` и `Cake`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `BakeryProduct` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого торта есть коробка. Создайте класс `CakeBox` с методом `show()`, который выводит строку «Праздничная коробка». Создайте класс `Cake`, который содержит объект класса `CakeBox` внутри себя как поле. Метод `show_cake()` у торта должен выводить название и вызывать метод `show()` у его коробки.
#
# **Задача 9 (переопределение методов).** В пекарне есть базовый класс `BakeryProduct` с методом `get_info()`, который возвращает строку «Изделие пекарни». Унаследуйте от него класс `Cake` и переопределите метод `get_info()` так, чтобы он возвращал строку «Торт: <название>». Создайте объект класса `Cake`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Продавцу нужен метод для оформления заказов. Создайте класс `OrderDesk` с методом `take(...)`, который принимает разное количество аргументов: при вызове `take(item)` оформляется заказ одного изделия, при `take(item, quantity)` — заказ на несколько штук, при `take(item, quantity, customer)` — заказ с указанием покупателя. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 19. Салон красоты
#
# **Задача 1 (создание класса, конструктор, метод).** В салоне красоты ведётся учёт услуг. Создайте класс `Service` с полями `name` (название), `category` (категория: стрижка, маникюр, массаж) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об услуге в формате: Название — категория, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента есть номер карты лояльности, который нельзя менять или читать напрямую. Создайте класс `LoyaltyCard`, в котором номер карты хранится в приватном поле `__card_id`. Реализуйте метод `set_card_id(value)`, предназначенный только для установки номера при регистрации клиента, и метод `get_card_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В салоне красоты работают разные специалисты. Создайте базовый класс `BeautyMaster` с методом `get_specialty()`, возвращающим строку «Специалист». Унаследуйте от него классы `Hairdresser` и `Manicurist`, переопределив в каждом метод `get_specialty()` так, чтобы он возвращал «Парикмахер» и «Мастер маникюра» соответственно. Создайте по одному объекту каждого класса и выведите их специальность.
#
# **Задача 4 (полиморфизм).** Салон красоты рассчитывает длительность для разных услуг. Создайте классы `Haircut`, `Manicure` и `Massage`, у каждого из которых есть метод `duration()`, возвращающий длительность в минутах: для стрижки — 60, для маникюра — 90, для массажа — 120. Напишите функцию `show_duration(service)`, которая принимает любую услугу и выводит её длительность. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `SalonManager` (управляющий салона), в котором есть три поля: `name` — публичное, `_cabinet` — защищённое (кабинет), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Салону нужна утилита для проверки времени записи. Создайте класс `SalonUtils` со статическим методом `is_working_hours(hour)`, который возвращает `True`, если час находится в диапазоне от 9 до 21, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `SalonItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Service` и `Master`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `SalonItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого мастера есть рабочее место. Создайте класс `Workplace` с методом `show()`, который выводит строку «Косметическое кресло готово». Создайте класс `Master`, который содержит объект класса `Workplace` внутри себя как поле. Метод `show_master()` у мастера должен выводить имя и вызывать метод `show()` у его рабочего места.
#
# **Задача 9 (переопределение методов).** В салоне есть базовый класс `SalonItem` с методом `get_info()`, который возвращает строку «Объект салона». Унаследуйте от него класс `Master` и переопределите метод `get_info()` так, чтобы он возвращал строку «Мастер: <имя>». Создайте объект класса `Master`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору салона нужен метод для записи клиентов. Создайте класс `ReceptionDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(client)` оформляется запись клиента, при `book(client, service)` — запись на услугу, при `book(client, service, master)` — запись к конкретному мастеру. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 20. Турагентство
#
# **Задача 1 (создание класса, конструктор, метод).** В турагентстве ведётся учёт туров. Создайте класс `Tour` с полями `country` (страна), `days` (количество дней) и `price` (цена). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о туре в формате: Страна — ... дней, цена. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента есть номер паспорта, который нельзя менять или читать напрямую. Создайте класс `ClientPassport`, в котором номер паспорта хранится в приватном поле `__passport_id`. Реализуйте метод `set_passport_id(value)`, предназначенный только для установки номера при оформлении тура, и метод `get_passport_id()` для чтения значения. Повторная попытка изменить номер после оформления должна игнорироваться.
#
# **Задача 3 (наследование).** В турагентстве есть разные типы туров. Создайте базовый класс `TravelPackage` с методом `get_package_type()`, возвращающим строку «Тур». Унаследуйте от него классы `BeachTour` и `ExcursionTour`, переопределив в каждом метод `get_package_type()` так, чтобы он возвращал «Пляжный тур» и «Экскурсионный тур» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Турагентство рассчитывает стоимость тура для разных направлений. Создайте классы `TourToTurkey`, `TourToEgypt` и `TourToItaly`, у каждого из которых есть метод `tour_price()`, возвращающий стоимость: в Турцию — 80000, в Египет — 70000, в Италию — 120000. Напишите функцию `show_price(tour)`, которая принимает любой тур и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `AgencyDirector` (директор агентства), в котором есть три поля: `name` — публичное, `_office` — защищённое (офис), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Турагентству нужна утилита для проверки номеров путёвок. Создайте класс `TravelUtils` со статическим методом `is_valid_voucher(code)`, который возвращает `True`, если строка начинается с букв «TV» и её длина равна 8, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `TravelItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Tour` и `Client`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `TravelItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого тура есть страховка. Создайте класс `Insurance` с методом `show()`, который выводит строку «Страховка оформлена». Создайте класс `Tour`, который содержит объект класса `Insurance` внутри себя как поле. Метод `show_tour()` у тура должен выводить страну и вызывать метод `show()` у его страховки.
#
# **Задача 9 (переопределение методов).** В турагентстве есть базовый класс `TravelItem` с методом `get_info()`, который возвращает строку «Объект турагентства». Унаследуйте от него класс `Tour` и переопределите метод `get_info()` так, чтобы он возвращал строку «Тур в <страна>». Создайте объект класса `Tour`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Менеджеру турагентства нужен метод для оформления заявок. Создайте класс `BookingDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(tour)` оформляется заявка на тур, при `book(tour, client)` — заявка с указанием клиента, при `book(tour, client, date)` — заявка с указанием даты выезда. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 21. Автомойка
#
# **Задача 1 (создание класса, конструктор, метод).** На автомойке ведётся учёт автомобилей. Создайте класс `Car` с полями `brand` (марка), `plate` (номер) и `type` (тип кузова: седан, внедорожник, микроавтобус). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об автомобиле в формате: Марка — номер ..., тип ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой мойки есть внутренний код заказа, который нельзя менять или читать напрямую. Создайте класс `WashOrder`, в котором код заказа хранится в приватном поле `__order_code`. Реализуйте метод `set_order_code(value)`, предназначенный только для установки кода при оформлении заказа, и метод `get_order_code()` для чтения значения. Повторная попытка изменить код после оформления должна игнорироваться.
#
# **Задача 3 (наследование).** На автомойке есть разные типы обслуживания. Создайте базовый класс `WashService` с методом `get_service_type()`, возвращающим строку «Услуга». Унаследуйте от него классы `ExpressWash` и `DeepWash`, переопределив в каждом метод `get_service_type()` так, чтобы он возвращал «Экспресс-мойка» и «Глубокая мойка» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Автомойка рассчитывает стоимость для разных типов кузова. Создайте классы `Sedan`, `SUV` и `Minivan`, у каждого из которых есть метод `wash_price()`, возвращающий стоимость: для седана — 500, для внедорожника — 800, для микроавтобуса — 1000. Напишите функцию `show_price(car)`, которая принимает любой автомобиль и выводит стоимость мойки. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `WashManager` (управляющий автомойки), в котором есть три поля: `name` — публичное, `_shift` — защищённое (смена), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Автомойке нужна утилита для проверки длины очереди. Создайте класс `WashUtils` со статическим методом `is_queue_free(count)`, который возвращает `True`, если количество машин в очереди меньше 3, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `WashItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Car` и `WashService`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `WashItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой услуги мойки есть набор моющих средств. Создайте класс `Detergent` с методом `show()`, который выводит строку «Автошампунь premium». Создайте класс `WashService`, который содержит объект класса `Detergent` внутри себя как поле. Метод `show_service()` у услуги должен выводить её тип и вызывать метод `show()` у моющего средства.
#
# **Задача 9 (переопределение методов).** На автомойке есть базовый класс `WashItem` с методом `get_info()`, который возвращает строку «Объект автомойки». Унаследуйте от него класс `Car` и переопределите метод `get_info()` так, чтобы он возвращал строку «Автомобиль: <марка> <номер>». Создайте объект класса `Car`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Оператору автомойки нужен метод для оформления заказов. Создайте класс `WashDesk` с методом `accept(...)`, который принимает разное количество аргументов: при вызове `accept(car)` принимается автомобиль, при `accept(car, service)` — с указанием типа мойки, при `accept(car, service, time)` — с указанием времени. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 22. Химчистка
#
# **Задача 1 (создание класса, конструктор, метод).** В химчистке ведётся учёт вещей. Создайте класс `ClothingItem` с полями `name` (название вещи), `material` (материал) и `price` (стоимость чистки). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о вещи в формате: Название — материал, стоимость ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой вещи есть номер квитанции, который нельзя менять или читать напрямую. Создайте класс `Receipt`, в котором номер квитанции хранится в приватном поле `__receipt_id`. Реализуйте метод `set_receipt_id(value)`, предназначенный только для установки номера при приёме вещи, и метод `get_receipt_id()` для чтения значения. Повторная попытка изменить номер после приёма должна игнорироваться.
#
# **Задача 3 (наследование).** В химчистке обрабатываются разные типы вещей. Создайте базовый класс `LaundryItem` с методом `get_item_type()`, возвращающим строку «Вещь». Унаследуйте от него классы `Coat` и `Dress`, переопределив в каждом метод `get_item_type()` так, чтобы он возвращал «Пальто» и «Платье» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Химчистка рассчитывает время обработки для разных типов вещей. Создайте классы `Coat`, `Dress` и `Curtains`, у каждого из которых есть метод `processing_time()`, возвращающий время в часах: для пальто — 24, для платья — 12, для штор — 48. Напишите функцию `show_time(item)`, которая принимает любую вещь и выводит время её обработки. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Cleaner` (сотрудник химчистки), в котором есть три поля: `name` — публичное, `_workshop` — защищённое (цех), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Химчистке нужна утилита для проверки допустимого веса вещи. Создайте класс `LaundryUtils` со статическим методом `is_valid_weight(kg)`, который возвращает `True`, если вес не превышает 10 кг, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `LaundryProduct` с абстрактным методом `describe()`. Унаследуйте от него классы `ClothingItem` и `Service`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `LaundryProduct` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой вещи есть защитный чехол. Создайте класс `Cover` с методом `show()`, который выводит строку «Защитный чехол надет». Создайте класс `ClothingItem`, который содержит объект класса `Cover` внутри себя как поле. Метод `show_item()` у вещи должен выводить её название и вызывать метод `show()` у её чехла.
#
# **Задача 9 (переопределение методов).** В химчистке есть базовый класс `LaundryProduct` с методом `get_info()`, который возвращает строку «Продукт химчистки». Унаследуйте от него класс `ClothingItem` и переопределите метод `get_info()` так, чтобы он возвращал строку «Вещь: <название>». Создайте объект класса `ClothingItem`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Приёмщику химчистки нужен метод для оформления заказов. Создайте класс `ReceptionDesk` с методом `accept(...)`, который принимает разное количество аргументов: при вызове `accept(item)` принимается одна вещь, при `accept(item, count)` — несколько вещей, при `accept(item, count, client)` — заказ с указанием клиента. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 23. Прокат автомобилей
#
# **Задача 1 (создание класса, конструктор, метод).** В прокате автомобилей ведётся учёт машин. Создайте класс `RentalCar` с полями `brand` (марка), `model` (модель) и `price_per_day` (цена за сутки). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об автомобиле в формате: Марка — модель, цена за сутки ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента проката есть номер водительского удостоверения, который нельзя менять или читать напрямую. Создайте класс `DriverLicense`, в котором номер удостоверения хранится в приватном поле `__license_id`. Реализуйте метод `set_license_id(value)`, предназначенный только для установки номера при оформлении аренды, и метод `get_license_id()` для чтения значения. Повторная попытка изменить номер после оформления должна игнорироваться.
#
# **Задача 3 (наследование).** В прокате есть разные классы автомобилей. Создайте базовый класс `RentalVehicle` с методом `get_class()`, возвращающим строку «Автомобиль». Унаследуйте от него классы `EconomyCar` и `PremiumCar`, переопределив в каждом метод `get_class()` так, чтобы он возвращал «Эконом-класс» и «Премиум-класс» соответственно. Создайте по одному объекту каждого класса и выведите их класс.
#
# **Задача 4 (полиморфизм).** Прокат рассчитывает стоимость аренды для разных классов автомобилей. Создайте классы `EconomyCar`, `ComfortCar` и `PremiumCar`, у каждого из которых есть метод `rental_price()`, возвращающий цену за сутки: для эконома — 2000, для комфорта — 4000, для премиума — 9000. Напишите функцию `show_price(car)`, которая принимает любой автомобиль и выводит цену аренды. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `RentalManager` (менеджер проката), в котором есть три поля: `name` — публичное, `_branch` — защищённое (филиал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Прокату нужна утилита для проверки возраста клиента. Создайте класс `RentalUtils` со статическим методом `is_valid_age(age)`, который возвращает `True`, если клиенту не меньше 21 года, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `RentalItem` с абстрактным методом `describe()`. Унаследуйте от него классы `RentalCar` и `Client`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `RentalItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого автомобиля в прокате есть GPS-навигатор. Создайте класс `GPS` с методом `show()`, который выводит строку «GPS-навигатор включён». Создайте класс `RentalCar`, который содержит объект класса `GPS` внутри себя как поле. Метод `show_car()` у автомобиля должен выводить модель и вызывать метод `show()` у его навигатора.
#
# **Задача 9 (переопределение методов).** В прокате есть базовый класс `RentalItem` с методом `get_info()`, который возвращает строку «Объект проката». Унаследуйте от него класс `RentalCar` и переопределите метод `get_info()` так, чтобы он возвращал строку «Автомобиль: <марка> <модель>». Создайте объект класса `RentalCar`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Менеджеру проката нужен метод для оформления аренды. Создайте класс `RentalDesk` с методом `rent(...)`, который принимает разное количество аргументов: при вызове `rent(car)` оформляется аренда автомобиля, при `rent(car, client)` — аренда с указанием клиента, при `rent(car, client, days)` — аренда с указанием срока. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 24. Музей
#
# **Задача 1 (создание класса, конструктор, метод).** В музее ведётся учёт экспонатов. Создайте класс `Exhibit` с полями `title` (название), `era` (эпоха) и `value` (оценочная стоимость). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об экспонате в формате: Название — эпоха, стоимость ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого экспоната есть инвентарный номер, который нельзя менять или читать напрямую. Создайте класс `ExhibitCard`, в котором инвентарный номер хранится в приватном поле `__inventory_id`. Реализуйте метод `set_inventory_id(value)`, предназначенный только для установки номера при постановке на учёт, и метод `get_inventory_id()` для чтения значения. Повторная попытка изменить номер после постановки на учёт должна игнорироваться.
#
# **Задача 3 (наследование).** В музее хранятся разные типы экспонатов. Создайте базовый класс `MuseumItem` с методом `get_item_type()`, возвращающим строку «Экспонат». Унаследуйте от него классы `Painting` и `Sculpture`, переопределив в каждом метод `get_item_type()` так, чтобы он возвращал «Картина» и «Скульптура» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Музей рассчитывает стоимость реставрации для разных типов экспонатов. Создайте классы `Painting`, `Sculpture` и `Manuscript`, у каждого из которых есть метод `restoration_cost()`, возвращающий стоимость: для картины — 50000, для скульптуры — 80000, для рукописи — 30000. Напишите функцию `show_cost(item)`, которая принимает любой экспонат и выводит стоимость реставрации. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `Curator` (куратор музея), в котором есть три поля: `name` — публичное, `_hall` — защищённое (зал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Музею нужна утилита для проверки возраста посетителя. Создайте класс `MuseumUtils` со статическим методом `is_child_ticket(age)`, который возвращает `True`, если посетителю меньше 14 лет, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `MuseumObject` с абстрактным методом `describe()`. Унаследуйте от него классы `Exhibit` и `Hall`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `MuseumObject` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого экспоната есть витрина. Создайте класс `Showcase` с методом `show()`, который выводит строку «Стеклянная витрина с подсветкой». Создайте класс `Exhibit`, который содержит объект класса `Showcase` внутри себя как поле. Метод `show_exhibit()` у экспоната должен выводить название и вызывать метод `show()` у его витрины.
#
# **Задача 9 (переопределение методов).** В музее есть базовый класс `MuseumObject` с методом `get_info()`, который возвращает строку «Объект музея». Унаследуйте от него класс `Painting` и переопределите метод `get_info()` так, чтобы он возвращал строку «Картина: <название>». Создайте объект класса `Painting`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Экскурсоводу нужен метод для оформления экскурсий. Создайте класс `TourDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(visitor)` оформляется одиночное посещение, при `book(visitor, group)` — групповое посещение, при `book(visitor, group, guide)` — экскурсия с гидом. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 25. Картинная галерея
#
# **Задача 1 (создание класса, конструктор, метод).** В картинной галерее ведётся учёт работ. Создайте класс `Artwork` с полями `title` (название), `artist` (художник) и `year` (год создания). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о работе в формате: Название — художник, год. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой картины есть каталожный номер, который нельзя менять или читать напрямую. Создайте класс `Catalog`, в котором каталожный номер хранится в приватном поле `__catalog_id`. Реализуйте метод `set_catalog_id(value)`, предназначенный только для установки номера при добавлении картины в каталог, и метод `get_catalog_id()` для чтения значения. Повторная попытка изменить номер после добавления в каталог должна игнорироваться.
#
# **Задача 3 (наследование).** В галерее представлены разные направления искусства. Создайте базовый класс `ArtStyle` с методом `get_style()`, возвращающим строку «Стиль». Унаследуйте от него классы `Impressionism` и `Realism`, переопределив в каждом метод `get_style()` так, чтобы он возвращал «Импрессионизм» и «Реализм» соответственно. Создайте по одному объекту каждого класса и выведите их стиль.
#
# **Задача 4 (полиморфизм).** Галерея рассчитывает страховую стоимость для разных типов работ. Создайте классы `Painting`, `Sculpture` и `Graphic`, у каждого из которых есть метод `insurance_value()`, возвращающий стоимость страховки: для живописи — 100000, для скульптуры — 150000, для графики — 60000. Напишите функцию `show_value(art)`, которая принимает любую работу и выводит стоимость страховки. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `GalleryDirector` (директор галереи), в котором есть три поля: `name` — публичное, `_exposition` — защищённое (экспозиция), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Галерее нужна утилита для проверки времени работы. Создайте класс `GalleryUtils` со статическим методом `is_open(day)`, который возвращает `True`, если день недели не понедельник, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `GalleryItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Artwork` и `Artist`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `GalleryItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой картины есть рама. Создайте класс `Frame` с методом `show()`, который выводит строку «Золочёная рама». Создайте класс `Artwork`, который содержит объект класса `Frame` внутри себя как поле. Метод `show_artwork()` у картины должен выводить название и вызывать метод `show()` у её рамы.
#
# **Задача 9 (переопределение методов).** В галерее есть базовый класс `GalleryItem` с методом `get_info()`, который возвращает строку «Объект галереи». Унаследуйте от него класс `Artwork` и переопределите метод `get_info()` так, чтобы он возвращал строку «Работа: <название> — <художник>». Создайте объект класса `Artwork`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору галереи нужен метод для оформления экскурсий. Создайте класс `GuideDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(visitor)` оформляется одиночный визит, при `book(visitor, group)` — групповой визит, при `book(visitor, group, guide)` — экскурсия с гидом. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 26. Аквапарк
#
# **Задача 1 (создание класса, конструктор, метод).** В аквапарке ведётся учёт посетителей. Создайте класс `Visitor` с полями `name` (имя), `age` (возраст) и `ticket_type` (тип билета: взрослый, детский). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о посетителе в формате: Имя — возраст ..., билет: ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого посетителя есть номер браслета, который нельзя менять или читать напрямую. Создайте класс `Bracelet`, в котором номер браслета хранится в приватном поле `__bracelet_id`. Реализуйте метод `set_bracelet_id(value)`, предназначенный только для установки номера при входе, и метод `get_bracelet_id()` для чтения значения. Повторная попытка изменить номер после входа должна игнорироваться.
#
# **Задача 3 (наследование).** В аквапарке есть разные типы горок. Создайте базовый класс `WaterSlide` с методом `get_slide_type()`, возвращающим строку «Горка». Унаследуйте от него классы `OpenSlide` и `TubeSlide`, переопределив в каждом метод `get_slide_type()` так, чтобы он возвращал «Открытая горка» и «Закрытая труба» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Аквапарк рассчитывает пропускную способность для разных бассейнов. Создайте классы `KidsPool`, `WavePool` и `DeepPool`, у каждого из которых есть метод `capacity()`, возвращающий максимальное число людей: для детского — 50, для волнового — 200, для глубокого — 100. Напишите функцию `show_capacity(pool)`, которая принимает любой бассейн и выводит его вместимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `ParkManager` (управляющий аквапарка), в котором есть три поля: `name` — публичное, `_zone` — защищённое (зона), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Аквапарку нужна утилита для проверки температуры воды. Создайте класс `AquaUtils` со статическим методом `is_comfortable(temp)`, который возвращает `True`, если температура от 24 до 28 градусов, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `AquaItem` с абстрактным методом `describe()`. Унаследуйте от него классы `WaterSlide` и `Pool`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `AquaItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой горки есть спасательный круг. Создайте класс `LifeRing` с методом `show()`, который выводит строку «Спасательный круг на месте». Создайте класс `WaterSlide`, который содержит объект класса `LifeRing` внутри себя как поле. Метод `show_slide()` у горки должен выводить её тип и вызывать метод `show()` у спасательного круга.
#
# **Задача 9 (переопределение методов).** В аквапарке есть базовый класс `AquaItem` с методом `get_info()`, который возвращает строку «Объект аквапарка». Унаследуйте от него класс `WaterSlide` и переопределите метод `get_info()` так, чтобы он возвращал строку «Горка: <тип>». Создайте объект класса `WaterSlide`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру аквапарка нужен метод для продажи билетов. Создайте класс `TicketDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(visitor)` продаётся один билет, при `sell(visitor, count)` — несколько билетов, при `sell(visitor, count, zone)` — билеты в конкретную зону. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 27. Боулинг
#
# **Задача 1 (создание класса, конструктор, метод).** В боулинг-клубе ведётся учёт дорожек. Создайте класс `Lane` с полями `number` (номер дорожки), `type` (тип: стандарт, VIP) и `price_per_hour` (цена за час). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о дорожке в формате: Дорожка №... — тип ..., цена за час ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой игры есть номер брони, который нельзя менять или читать напрямую. Создайте класс `GameBooking`, в котором номер брони хранится в приватном поле `__booking_id`. Реализуйте метод `set_booking_id(value)`, предназначенный только для установки номера при бронировании, и метод `get_booking_id()` для чтения значения. Повторная попытка изменить номер после бронирования должна игнорироваться.
#
# **Задача 3 (наследование).** В боулинг-клубе есть разные типы шаров. Создайте базовый класс `BowlingBall` с методом `get_ball_type()`, возвращающим строку «Шар». Унаследуйте от него классы `LightBall` и `HeavyBall`, переопределив в каждом метод `get_ball_type()` так, чтобы он возвращал «Лёгкий шар» и «Тяжёлый шар» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Боулинг-клуб рассчитывает стоимость часа для разных типов дорожек. Создайте классы `StandardLane`, `VIPLane` и `PremiumLane`, у каждого из которых есть метод `price_per_hour()`, возвращающий стоимость: для стандарта — 1000, для VIP — 2000, для премиум — 3500. Напишите функцию `show_price(lane)`, которая принимает любую дорожку и выводит цену. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `ClubManager` (управляющий клуба), в котором есть три поля: `name` — публичное, `_hall` — защищённое (зал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Боулинг-клубу нужна утилита для проверки номера дорожки. Создайте класс `BowlingUtils` со статическим методом `is_valid_lane(number)`, который возвращает `True`, если число находится в диапазоне от 1 до 20, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `BowlingItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Lane` и `Ball`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `BowlingItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой дорожки есть механизм подачи шаров. Создайте класс `BallReturn` с методом `show()`, который выводит строку «Механизм возврата готов». Создайте класс `Lane`, который содержит объект класса `BallReturn` внутри себя как поле. Метод `show_lane()` у дорожки должен выводить её номер и вызывать метод `show()` у механизма возврата.
#
# **Задача 9 (переопределение методов).** В боулинг-клубе есть базовый класс `BowlingItem` с методом `get_info()`, который возвращает строку «Объект клуба». Унаследуйте от него класс `VIPLane` и переопределите метод `get_info()` так, чтобы он возвращал строку «VIP-дорожка №...». Создайте объект класса `VIPLane`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору боулинга нужен метод для оформления игр. Создайте класс `GameDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(lane)` бронируется дорожка, при `book(lane, hours)` — бронирование на несколько часов, при `book(lane, hours, players)` — бронирование с указанием числа игроков. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 28. Тир
#
# **Задача 1 (создание класса, конструктор, метод).** В тире ведётся учёт оружия. Создайте класс `Weapon` с полями `model` (модель), `caliber` (калибр) и `price_per_shot` (цена за выстрел). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об оружии в формате: Модель — калибр ..., цена за выстрел ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента тира есть номер карты посетителя, который нельзя менять или читать напрямую. Создайте класс `ShooterCard`, в котором номер карты хранится в приватном поле `__card_id`. Реализуйте метод `set_card_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_card_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В тире есть разные виды оружия. Создайте базовый класс `Firearm` с методом `get_weapon_kind()`, возвращающим строку «Оружие». Унаследуйте от него классы `Pistol` и `Rifle`, переопределив в каждом метод `get_weapon_kind()` так, чтобы он возвращал «Пистолет» и «Винтовка» соответственно. Создайте по одному объекту каждого класса и выведите их вид.
#
# **Задача 4 (полиморфизм).** Тир рассчитывает стоимость выстрела для разных типов оружия. Создайте классы `Pistol`, `Rifle` и `Shotgun`, у каждого из которых есть метод `shot_price()`, возвращающий стоимость: для пистолета — 50, для винтовки — 100, для дробовика — 150. Напишите функцию `show_price(weapon)`, которая принимает любое оружие и выводит цену выстрела. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `RangeManager` (управляющий тира), в котором есть три поля: `name` — публичное, `_hall` — защищённое (зал), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Тиру нужна утилита для проверки возраста клиента. Создайте класс `RangeUtils` со статическим методом `is_adult(age)`, который возвращает `True`, если клиенту не меньше 18 лет, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `RangeItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Weapon` и `Target`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `RangeItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого оружия есть магазин с патронами. Создайте класс `Magazine` с методом `show()`, который выводит строку «Магазин заряжен». Создайте класс `Weapon`, который содержит объект класса `Magazine` внутри себя как поле. Метод `show_weapon()` у оружия должен выводить модель и вызывать метод `show()` у его магазина.
#
# **Задача 9 (переопределение методов).** В тире есть базовый класс `RangeItem` с методом `get_info()`, который возвращает строку «Объект тира». Унаследуйте от него класс `Rifle` и переопределите метод `get_info()` так, чтобы он возвращал строку «Винтовка: <модель>». Создайте объект класса `Rifle`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Инструктору тира нужен метод для оформления сеансов. Создайте класс `SessionDesk` с методом `start(...)`, который принимает разное количество аргументов: при вызове `start(weapon)` начинается сеанс с одним оружием, при `start(weapon, shots)` — сеанс с указанием числа выстрелов, при `start(weapon, shots, shooter)` — сеанс с указанием стрелка. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 29. Квест-комната
#
# **Задача 1 (создание класса, конструктор, метод).** В квест-комнате ведётся учёт сценариев. Создайте класс `Quest` с полями `title` (название), `difficulty` (сложность: лёгкий, средний, сложный) и `duration` (длительность в минутах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о квесте в формате: Название — сложность ..., длительность ... мин. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждой игры есть код брони, который нельзя менять или читать напрямую. Создайте класс `QuestBooking`, в котором код брони хранится в приватном поле `__booking_code`. Реализуйте метод `set_booking_code(value)`, предназначенный только для установки кода при бронировании, и метод `get_booking_code()` для чтения значения. Повторная попытка изменить код после бронирования должна игнорироваться.
#
# **Задача 3 (наследование).** В квест-комнате есть разные типы квестов. Создайте базовый класс `QuestType` с методом `get_quest_type()`, возвращающим строку «Квест». Унаследуйте от него классы `HorrorQuest` и `DetectiveQuest`, переопределив в каждом метод `get_quest_type()` так, чтобы он возвращал «Хоррор-квест» и «Детективный квест» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Квест-комната рассчитывает стоимость игры для разных сценариев. Создайте классы `EasyQuest`, `MediumQuest` и `HardQuest`, у каждого из которых есть метод `price()`, возвращающий стоимость: для лёгкого — 3000, для среднего — 5000, для сложного — 8000. Напишите функцию `show_price(quest)`, которая принимает любой квест и выводит стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `QuestManager` (управляющий квестами), в котором есть три поля: `name` — публичное, `_room` — защищённое (комната), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Квест-комнате нужна утилита для проверки размера команды. Создайте класс `QuestUtils` со статическим методом `is_valid_team(size)`, который возвращает `True`, если число игроков от 2 до 6, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `QuestItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Quest` и `Room`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `QuestItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждой квест-комнаты есть набор реквизита. Создайте класс `Props` с методом `show()`, который выводит строку «Реквизит подготовлен». Создайте класс `Room`, который содержит объект класса `Props` внутри себя как поле. Метод `show_room()` у комнаты должен выводить название квеста и вызывать метод `show()` у реквизита.
#
# **Задача 9 (переопределение методов).** В квест-комнате есть базовый класс `QuestItem` с методом `get_info()`, который возвращает строку «Объект квеста». Унаследуйте от него класс `HorrorQuest` и переопределите метод `get_info()` так, чтобы он возвращал строку «Хоррор-квест: <название>». Создайте объект класса `HorrorQuest`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору квест-комнаты нужен метод для оформления игр. Создайте класс `BookingDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(quest)` бронируется квест, при `book(quest, team)` — бронирование с указанием команды, при `book(quest, team, time)` — бронирование с указанием времени. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 30. Планетарий
#
# **Задача 1 (создание класса, конструктор, метод).** В планетарии ведётся учёт шоу. Создайте класс `Show` с полями `title` (название), `topic` (тема: космос, звёзды, планеты) и `duration` (длительность в минутах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о шоу в формате: Название — тема ..., длительность ... мин. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого билета в планетарий есть уникальный код, который нельзя менять или читать напрямую. Создайте класс `PlanetariumTicket`, в котором код билета хранится в приватном поле `__ticket_code`. Реализуйте метод `set_ticket_code(value)`, предназначенный только для установки кода при продаже, и метод `get_ticket_code()` для чтения значения. Повторная попытка изменить код после продажи должна игнорироваться.
#
# **Задача 3 (наследование).** В планетарии есть разные типы шоу. Создайте базовый класс `SpaceShow` с методом `get_show_type()`, возвращающим строку «Шоу». Унаследуйте от него классы `StarShow` и `PlanetShow`, переопределив в каждом метод `get_show_type()` так, чтобы он возвращал «Шоу о звёздах» и «Шоу о планетах» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Планетарий рассчитывает стоимость билета для разных категорий посетителей. Создайте классы `AdultTicket`, `ChildTicket` и `StudentTicket`, у каждого из которых есть метод `price()`, возвращающий стоимость: для взрослого — 700, для детского — 350, для студенческого — 500. Напишите функцию `show_price(ticket)`, которая принимает любой билет и выводит его стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `PlanetariumDirector` (директор планетария), в котором есть три поля: `name` — публичное, `_dome` — защищённое (купол), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Планетарию нужна утилита для проверки времени сеанса. Создайте класс `PlanetariumUtils` со статическим методом `is_valid_time(hour)`, который возвращает `True`, если час находится в диапазоне от 10 до 22, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `PlanetariumItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Show` и `Telescope`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `PlanetariumItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого шоу есть проектор. Создайте класс `Projector` с методом `show()`, который выводит строку «Проектор включён». Создайте класс `Show`, который содержит объект класса `Projector` внутри себя как поле. Метод `show_show()` у шоу должен выводить название и вызывать метод `show()` у его проектора.
#
# **Задача 9 (переопределение методов).** В планетарии есть базовый класс `PlanetariumItem` с методом `get_info()`, который возвращает строку «Объект планетария». Унаследуйте от него класс `StarShow` и переопределите метод `get_info()` так, чтобы он возвращал строку «Шоу о звёздах: <название>». Создайте объект класса `StarShow`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру планетария нужен метод для продажи билетов. Создайте класс `CashDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(show)` продаётся один билет, при `sell(show, count)` — несколько билетов, при `sell(show, count, category)` — билеты определённой категории. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 31. Цирк
#
# **Задача 1 (создание класса, конструктор, метод).** В цирке ведётся учёт артистов. Создайте класс `Artist` с полями `name` (имя), `genre` (жанр: акробат, клоун, гимнаст) и `experience` (стаж в годах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об артисте в формате: Имя — жанр ..., стаж ... лет. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого артиста есть номер контракта, который нельзя менять или читать напрямую. Создайте класс `Contract`, в котором номер контракта хранится в приватном поле `__contract_id`. Реализуйте метод `set_contract_id(value)`, предназначенный только для установки номера при подписании контракта, и метод `get_contract_id()` для чтения значения. Повторная попытка изменить номер после подписания должна игнорироваться.
#
# **Задача 3 (наследование).** В цирке выступают разные категории артистов. Создайте базовый класс `Performer` с методом `get_role()`, возвращающим строку «Артист». Унаследуйте от него классы `Acrobat` и `Clown`, переопределив в каждом метод `get_role()` так, чтобы он возвращал «Акробат» и «Клоун» соответственно. Создайте по одному объекту каждого класса и выведите их роль.
#
# **Задача 4 (полиморфизм).** Цирк рассчитывает длительность номера для разных жанров. Создайте классы `Acrobat`, `Clown` и `Magician`, у каждого из которых есть метод `act_duration()`, возвращающий длительность в минутах: для акробата — 15, для клоуна — 10, для фокусника — 20. Напишите функцию `show_duration(artist)`, которая принимает любого артиста и выводит длительность номера. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `CircusDirector` (директор цирка), в котором есть три поля: `name` — публичное, `_arena` — защищённое (арена), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Цирку нужна утилита для проверки возраста зрителя. Создайте класс `CircusUtils` со статическим методом `is_child(age)`, который возвращает `True`, если зрителю меньше 12 лет, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `CircusItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Artist` и `Act`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `CircusItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого артиста есть костюм. Создайте класс `Costume` с методом `show()`, который выводит строку «Яркий цирковой костюм». Создайте класс `Artist`, который содержит объект класса `Costume` внутри себя как поле. Метод `show_artist()` у артиста должен выводить имя и вызывать метод `show()` у его костюма.
#
# **Задача 9 (переопределение методов).** В цирке есть базовый класс `CircusItem` с методом `get_info()`, который возвращает строку «Объект цирка». Унаследуйте от него класс `Clown` и переопределите метод `get_info()` так, чтобы он возвращал строку «Клоун: <имя>». Создайте объект класса `Clown`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору цирка нужен метод для продажи билетов. Создайте класс `TicketDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(show)` продаётся один билет, при `sell(show, count)` — несколько билетов, при `sell(show, count, row)` — билеты на конкретный ряд. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 32. Океанариум
#
# **Задача 1 (создание класса, конструктор, метод).** В океанариуме ведётся учёт обитателей. Создайте класс `SeaCreature` с полями `name` (название), `species` (вид) и `depth` (глубина обитания в метрах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об обитателе в формате: Название — вид ..., глубина ... м. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого обитателя есть номер чипа, который нельзя менять или читать напрямую. Создайте класс `SeaChip`, в котором номер чипа хранится в приватном поле `__chip_id`. Реализуйте метод `set_chip_id(value)`, предназначенный только для установки номера при регистрации обитателя, и метод `get_chip_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В океанариуме живут разные классы существ. Создайте базовый класс `SeaBeing` с методом `get_class()`, возвращающим строку «Существо». Унаследуйте от него классы `Fish` и `Mammal`, переопределив в каждом метод `get_class()` так, чтобы он возвращал «Рыба» и «Млекопитающее» соответственно. Создайте по одному объекту каждого класса и выведите их класс.
#
# **Задача 4 (полиморфизм).** Океанариум рассчитывает суточный рацион для разных обитателей. Создайте классы `Shark`, `Dolphin` и `Turtle`, у каждого из которых есть метод `daily_food()`, возвращающий количество килограммов еды в день: для акулы — 5, для дельфина — 8, для черепахи — 2. Напишите функцию `show_food(creature)`, которая принимает любого обитателя и выводит его рацион. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `OceanariumDirector` (директор океанариума), в котором есть три поля: `name` — публичное, `_tank` — защищённое (аквариум), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Океанариуму нужна утилита для проверки температуры воды. Создайте класс `OceanariumUtils` со статическим методом `is_comfortable(temp)`, который возвращает `True`, если температура от 20 до 26 градусов, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `OceanariumItem` с абстрактным методом `describe()`. Унаследуйте от него классы `SeaCreature` и `Tank`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `OceanariumItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого обитателя есть аквариум. Создайте класс `Tank` с методом `show()`, который выводит строку «Просторный аквариум с морской водой». Создайте класс `SeaCreature`, который содержит объект класса `Tank` внутри себя как поле. Метод `show_creature()` у обитателя должен выводить название и вызывать метод `show()` у его аквариума.
#
# **Задача 9 (переопределение методов).** В океанариуме есть базовый класс `OceanariumItem` с методом `get_info()`, который возвращает строку «Объект океанариума». Унаследуйте от него класс `Shark` и переопределите метод `get_info()` так, чтобы он возвращал строку «Акула: <название>». Создайте объект класса `Shark`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру океанариума нужен метод для продажи билетов. Создайте класс `TicketDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(visitor)` продаётся один билет, при `sell(visitor, count)` — несколько билетов, при `sell(visitor, count, show)` — билеты на конкретное шоу. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 33. Дельфинарий
#
# **Задача 1 (создание класса, конструктор, метод).** В дельфинарии ведётся учёт дельфинов. Создайте класс `Dolphin` с полями `name` (кличка), `age` (возраст) и `trick_count` (число трюков). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о дельфине в формате: Кличка — возраст ... лет, трюков: ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого дельфина есть номер чипа, который нельзя менять или читать напрямую. Создайте класс `DolphinChip`, в котором номер чипа хранится в приватном поле `__chip_id`. Реализуйте метод `set_chip_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_chip_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В дельфинарии выступают разные морские животные. Создайте базовый класс `SeaArtist` с методом `get_species()`, возвращающим строку «Животное». Унаследуйте от него классы `Dolphin` и `Seal`, переопределив в каждом метод `get_species()` так, чтобы он возвращал «Дельфин» и «Тюлень» соответственно. Создайте по одному объекту каждого класса и выведите их вид.
#
# **Задача 4 (полиморфизм).** Дельфинарий рассчитывает длительность выступления для разных животных. Создайте классы `Dolphin`, `Seal` и `Walrus`, у каждого из которых есть метод `show_duration()`, возвращающий длительность в минутах: для дельфина — 20, для тюленя — 15, для моржа — 10. Напишите функцию `show_duration(artist)`, которая принимает любое животное и выводит длительность выступления. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `DolphinariumManager` (управляющий дельфинариума), в котором есть три поля: `name` — публичное, `_pool` — защищённое (бассейн), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Дельфинариуму нужна утилита для проверки температуры воды. Создайте класс `DolphinariumUtils` со статическим методом `is_comfortable(temp)`, который возвращает `True`, если температура от 22 до 26 градусов, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `DolphinariumItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Dolphin` и `Trainer`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `DolphinariumItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого дельфина есть мяч для тренировки. Создайте класс `Ball` с методом `show()`, который выводит строку «Яркий тренировочный мяч». Создайте класс `Dolphin`, который содержит объект класса `Ball` внутри себя как поле. Метод `show_dolphin()` у дельфина должен выводить кличку и вызывать метод `show()` у его мяча.
#
# **Задача 9 (переопределение методов).** В дельфинарии есть базовый класс `DolphinariumItem` с методом `get_info()`, который возвращает строку «Объект дельфинариума». Унаследуйте от него класс `Dolphin` и переопределите метод `get_info()` так, чтобы он возвращал строку «Дельфин: <кличка>». Создайте объект класса `Dolphin`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру дельфинариума нужен метод для продажи билетов. Создайте класс `TicketDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(show)` продаётся один билет, при `sell(show, count)` — несколько билетов, при `sell(show, count, row)` — билеты на конкретный ряд. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 34. Ледовый дворец
#
# **Задача 1 (создание класса, конструктор, метод).** В ледовом дворце ведётся учёт фигуристов. Создайте класс `FigureSkater` с полями `name` (имя), `category` (разряд: юношеский, взрослый) и `program` (программа: короткая, произвольная). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о фигуристе в формате: Имя — разряд ..., программа ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого фигуриста есть номер лицензии, который нельзя менять или читать напрямую. Создайте класс `License`, в котором номер лицензии хранится в приватном поле `__license_id`. Реализуйте метод `set_license_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_license_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В ледовом дворце занимаются разные спортсмены. Создайте базовый класс `IceAthlete` с методом `get_sport()`, возвращающим строку «Спортсмен». Унаследуйте от него классы `FigureSkater` и `HockeyPlayer`, переопределив в каждом метод `get_sport()` так, чтобы он возвращал «Фигурное катание» и «Хоккей» соответственно. Создайте по одному объекту каждого класса и выведите их вид спорта.
#
# **Задача 4 (полиморфизм).** Ледовый дворец рассчитывает стоимость аренды льда для разных секций. Создайте классы `FigureSkating`, `Hockey` и `Curling`, у каждого из которых есть метод `ice_price()`, возвращающий стоимость часа: для фигурного катания — 5000, для хоккея — 8000, для кёрлинга — 6000. Напишите функцию `show_price(section)`, которая принимает любую секцию и выводит стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `IcePalaceDirector` (директор дворца), в котором есть три поля: `name` — публичное, `_rink` — защищённое (каток), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Ледовому дворцу нужна утилита для проверки температуры льда. Создайте класс `IceUtils` со статическим методом `is_good_ice(temp)`, который возвращает `True`, если температура от -5 до -3 градусов, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `IceItem` с абстрактным методом `describe()`. Унаследуйте от него классы `FigureSkater` и `Section`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `IceItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого фигуриста есть коньки. Создайте класс `Skates` с методом `show()`, который выводит строку «Профессиональные коньки». Создайте класс `FigureSkater`, который содержит объект класса `Skates` внутри себя как поле. Метод `show_skater()` у фигуриста должен выводить имя и вызывать метод `show()` у его коньков.
#
# **Задача 9 (переопределение методов).** В ледовом дворце есть базовый класс `IceItem` с методом `get_info()`, который возвращает строку «Объект дворца». Унаследуйте от него класс `HockeyPlayer` и переопределите метод `get_info()` так, чтобы он возвращал строку «Хоккеист: <имя>». Создайте объект класса `HockeyPlayer`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору ледового дворца нужен метод для записи на тренировки. Создайте класс `BookingDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(athlete)` оформляется запись спортсмена, при `book(athlete, section)` — запись в секцию, при `book(athlete, section, time)` — запись на конкретное время. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 35. Роллердром
#
# **Задача 1 (создание класса, конструктор, метод).** На роллердроме ведётся учёт роликов. Создайте класс `RollerSkate` с полями `brand` (марка), `size` (размер) и `price_per_hour` (цена за час). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о роликах в формате: Марка — размер ..., цена за час ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента роллердрома есть номер карты, который нельзя менять или читать напрямую. Создайте класс `ClientCard`, в котором номер карты хранится в приватном поле `__card_id`. Реализуйте метод `set_card_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_card_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** На роллердроме есть разные типы роликов. Создайте базовый класс `Skate` с методом `get_skate_type()`, возвращающим строку «Ролики». Унаследуйте от него классы `QuadSkate` и `InlineSkate`, переопределив в каждом метод `get_skate_type()` так, чтобы он возвращал «Квады» и «Инлайн» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Роллердром рассчитывает стоимость часа для разных категорий посетителей. Создайте классы `ChildSkater`, `AdultSkater` и `ProSkater`, у каждого из которых есть метод `hour_price()`, возвращающий стоимость: для ребёнка — 300, для взрослого — 500, для профессионала — 700. Напишите функцию `show_price(skater)`, которая принимает любого посетителя и выводит стоимость часа. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `RinkManager` (управляющий роллердрома), в котором есть три поля: `name` — публичное, `_zone` — защищённое (зона), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Роллердрому нужна утилита для проверки размера роликов. Создайте класс `RollerUtils` со статическим методом `is_valid_size(size)`, который возвращает `True`, если размер от 30 до 47, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `RollerItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Skate` и `Skater`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `RollerItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого клиента есть защитный шлем. Создайте класс `Helmet` с методом `show()`, который выводит строку «Защитный шлем надет». Создайте класс `Skater`, который содержит объект класса `Helmet` внутри себя как поле. Метод `show_skater()` у клиента должен выводить имя и вызывать метод `show()` у его шлема.
#
# **Задача 9 (переопределение методов).** На роллердроме есть базовый класс `RollerItem` с методом `get_info()`, который возвращает строку «Объект роллердрома». Унаследуйте от него класс `ProSkater` и переопределите метод `get_info()` так, чтобы он возвращал строку «Профессионал: <имя>». Создайте объект класса `ProSkater`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору роллердрома нужен метод для оформления проката. Создайте класс `RentalDesk` с методом `rent(...)`, который принимает разное количество аргументов: при вызове `rent(skate)` выдаются ролики, при `rent(skate, hours)` — прокат на несколько часов, при `rent(skate, hours, skater)` — прокат с указанием клиента. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---

# %% [markdown]
# # Вариант 36. Парк аттракционов
#
# **Задача 1 (создание класса, конструктор, метод).** В парке аттракционов ведётся учёт аттракционов. Создайте класс `Attraction` с полями `name` (название), `type` (тип: карусель, горка, колесо обозрения) и `min_height` (минимальный рост посетителя в см). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию об аттракционе в формате: Название — тип ..., минимальный рост ... см. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого билета на аттракцион есть уникальный код, который нельзя менять или читать напрямую. Создайте класс `RideTicket`, в котором код билета хранится в приватном поле `__ticket_code`. Реализуйте метод `set_ticket_code(value)`, предназначенный только для установки кода при продаже, и метод `get_ticket_code()` для чтения значения. Повторная попытка изменить код после продажи должна игнорироваться.
#
# **Задача 3 (наследование).** В парке есть разные типы аттракционов. Создайте базовый класс `Ride` с методом `get_ride_type()`, возвращающим строку «Аттракцион». Унаследуйте от него классы `Carousel` и `RollerCoaster`, переопределив в каждом метод `get_ride_type()` так, чтобы он возвращал «Карусель» и «Американские горки» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Парк рассчитывает длительность сеанса для разных аттракционов. Создайте классы `Carousel`, `FerrisWheel` и `RollerCoaster`, у каждого из которых есть метод `ride_duration()`, возвращающий длительность в минутах: для карусели — 5, для колеса обозрения — 15, для горок — 3. Напишите функцию `show_duration(ride)`, которая принимает любой аттракцион и выводит длительность. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `ParkManager` (управляющий парка), в котором есть три поля: `name` — публичное, `_zone` — защищённое (зона), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Парку нужна утилита для проверки роста посетителя. Создайте класс `ParkUtils` со статическим методом `is_tall_enough(height, min_height)`, который возвращает `True`, если рост посетителя не меньше минимального, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `ParkItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Attraction` и `Visitor`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `ParkItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого аттракциона есть система безопасности. Создайте класс `SafetySystem` с методом `show()`, который выводит строку «Система безопасности активна». Создайте класс `Attraction`, который содержит объект класса `SafetySystem` внутри себя как поле. Метод `show_attraction()` у аттракциона должен выводить название и вызывать метод `show()` у системы безопасности.
#
# **Задача 9 (переопределение методов).** В парке есть базовый класс `ParkItem` с методом `get_info()`, который возвращает строку «Объект парка». Унаследуйте от него класс `RollerCoaster` и переопределите метод `get_info()` так, чтобы он возвращал строку «Американские горки: <название>». Создайте объект класса `RollerCoaster`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Кассиру парка нужен метод для продажи билетов. Создайте класс `TicketDesk` с методом `sell(...)`, который принимает разное количество аргументов: при вызове `sell(ride)` продаётся один билет, при `sell(ride, count)` — несколько билетов, при `sell(ride, count, visitor)` — билеты для конкретного посетителя. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 37. Батутный центр
#
# **Задача 1 (создание класса, конструктор, метод).** В батутном центре ведётся учёт батутов. Создайте класс `Trampoline` с полями `size` (размер: малый, средний, большой), `zone` (зона: детская, взрослая) и `price_per_hour` (цена за час). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о батуте в формате: Размер — зона ..., цена за час ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого посетителя центра есть номер браслета, который нельзя менять или читать напрямую. Создайте класс `JumpBracelet`, в котором номер браслета хранится в приватном поле `__bracelet_id`. Реализуйте метод `set_bracelet_id(value)`, предназначенный только для установки номера при входе, и метод `get_bracelet_id()` для чтения значения. Повторная попытка изменить номер после входа должна игнорироваться.
#
# **Задача 3 (наследование).** В батутном центре есть разные типы прыжков. Создайте базовый класс `Jump` с методом `get_jump_type()`, возвращающим строку «Прыжок». Унаследуйте от него классы `FreeJump` и `TrickJump`, переопределив в каждом метод `get_jump_type()` так, чтобы он возвращал «Свободный прыжок» и «Трюковой прыжок» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Батутный центр рассчитывает стоимость часа для разных зон. Создайте классы `KidsZone`, `TeenZone` и `AdultZone`, у каждого из которых есть метод `hour_price()`, возвращающий стоимость: для детской — 400, для подростковой — 600, для взрослой — 800. Напишите функцию `show_price(zone)`, которая принимает любую зону и выводит стоимость часа. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `CenterManager` (управляющий центра), в котором есть три поля: `name` — публичное, `_zone` — защищённое (зона), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Батутному центру нужна утилита для проверки веса посетителя. Создайте класс `TrampolineUtils` со статическим методом `is_valid_weight(kg)`, который возвращает `True`, если вес не превышает 120 кг, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `TrampolineItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Trampoline` и `Instructor`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `TrampolineItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого батута есть защитная сетка. Создайте класс `SafetyNet` с методом `show()`, который выводит строку «Защитная сетка натянута». Создайте класс `Trampoline`, который содержит объект класса `SafetyNet` внутри себя как поле. Метод `show_trampoline()` у батута должен выводить его размер и вызывать метод `show()` у защитной сетки.
#
# **Задача 9 (переопределение методов).** В батутном центре есть базовый класс `TrampolineItem` с методом `get_info()`, который возвращает строку «Объект центра». Унаследуйте от него класс `Trampoline` и переопределите метод `get_info()` так, чтобы он возвращал строку «Батут: <размер>». Создайте объект класса `Trampoline`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору центра нужен метод для оформления прыжков. Создайте класс `JumpDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(visitor)` оформляется один прыжок, при `book(visitor, count)` — несколько прыжков, при `book(visitor, count, zone)` — прыжки в конкретной зоне. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 38. Картинг
#
# **Задача 1 (создание класса, конструктор, метод).** В картинг-центре ведётся учёт картов. Создайте класс `Kart` с полями `model` (модель), `engine` (объём двигателя) и `price_per_race` (цена за заезд). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о карте в формате: Модель — двигатель ..., цена за заезд ... Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого заезда есть номер, который нельзя менять или читать напрямую. Создайте класс `Race`, в котором номер заезда хранится в приватном поле `__race_id`. Реализуйте метод `set_race_id(value)`, предназначенный только для установки номера при регистрации заезда, и метод `get_race_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В картинг-центре есть разные типы картов. Создайте базовый класс `KartType` с методом `get_kart_type()`, возвращающим строку «Карт». Унаследуйте от него классы `KidsKart` и `SportKart`, переопределив в каждом метод `get_kart_type()` так, чтобы он возвращал «Детский карт» и «Спортивный карт» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Картинг-центр рассчитывает стоимость заезда для разных трасс. Создайте классы `ShortTrack`, `MediumTrack` и `LongTrack`, у каждого из которых есть метод `race_price()`, возвращающий стоимость: для короткой — 1000, для средней — 1500, для длинной — 2000. Напишите функцию `show_price(track)`, которая принимает любую трассу и выводит стоимость. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `TrackManager` (управляющий трассы), в котором есть три поля: `name` — публичное, `_track` — защищённое (трасса), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Картинг-центру нужна утилита для проверки возраста пилота. Создайте класс `KartUtils` со статическим методом `is_valid_age(age)`, который возвращает `True`, если пилоту не меньше 14 лет, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `KartItem` с абстрактным методом `describe()`. Унаследуйте от него классы `Kart` и `Track`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `KartItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого карта есть шлем. Создайте класс `Helmet` с методом `show()`, который выводит строку «Шлем выдан». Создайте класс `Kart`, который содержит объект класса `Helmet` внутри себя как поле. Метод `show_kart()` у карта должен выводить модель и вызывать метод `show()` у шлема.
#
# **Задача 9 (переопределение методов).** В картинг-центре есть базовый класс `KartItem` с методом `get_info()`, который возвращает строку «Объект картинга». Унаследуйте от него класс `SportKart` и переопределите метод `get_info()` так, чтобы он возвращал строку «Спортивный карт: <модель>». Создайте объект класса `SportKart`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору картинга нужен метод для оформления заездов. Создайте класс `RaceDesk` с методом `register(...)`, который принимает разное количество аргументов: при вызове `register(kart)` регистрируется карт, при `register(kart, pilot)` — карт с пилотом, при `register(kart, pilot, track)` — заезд на конкретной трассе. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 39. Скалодром
#
# **Задача 1 (создание класса, конструктор, метод).** На скалодроме ведётся учёт трасс. Создайте класс `ClimbingRoute` с полями `name` (название), `difficulty` (сложность: лёгкая, средняя, сложная) и `height` (высота в метрах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о трассе в формате: Название — сложность ..., высота ... м. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого клиента скалодрома есть номер страховки, который нельзя менять или читать напрямую. Создайте класс `Insurance`, в котором номер страховки хранится в приватном поле `__insurance_id`. Реализуйте метод `set_insurance_id(value)`, предназначенный только для установки номера при регистрации, и метод `get_insurance_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** На скалодроме есть разные типы трасс. Создайте базовый класс `ClimbingWall` с методом `get_wall_type()`, возвращающим строку «Стена». Унаследуйте от него классы `BoulderWall` и `SpeedWall`, переопределив в каждом метод `get_wall_type()` так, чтобы он возвращал «Боулдеринг» и «Скоростная стена» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Скалодром рассчитывает время прохождения для разных трасс. Создайте классы `EasyRoute`, `MediumRoute` и `HardRoute`, у каждого из которых есть метод `climb_time()`, возвращающий время в минутах: для лёгкой — 5, для средней — 10, для сложной — 20. Напишите функцию `show_time(route)`, которая принимает любую трассу и выводит время прохождения. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `ClimbingManager` (управляющий скалодрома), в котором есть три поля: `name` — публичное, `_sector` — защищённое (сектор), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Скалодрому нужна утилита для проверки возраста клиента. Создайте класс `ClimbingUtils` со статическим методом `is_adult(age)`, который возвращает `True`, если клиенту не меньше 16 лет, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `ClimbingItem` с абстрактным методом `describe()`. Унаследуйте от него классы `ClimbingRoute` и `Instructor`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `ClimbingItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого клиента есть страховочная система. Создайте класс `Harness` с методом `show()`, который выводит строку «Страховочная система застёгнута». Создайте класс `Climber`, который содержит объект класса `Harness` внутри себя как поле. Метод `show_climber()` у клиента должен выводить имя и вызывать метод `show()` у страховочной системы.
#
# **Задача 9 (переопределение методов).** На скалодроме есть базовый класс `ClimbingItem` с методом `get_info()`, который возвращает строку «Объект скалодрома». Унаследуйте от него класс `HardRoute` и переопределите метод `get_info()` так, чтобы он возвращал строку «Сложная трасса: <название>». Создайте объект класса `HardRoute`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Администратору скалодрома нужен метод для оформления восхождений. Создайте класс `ClimbDesk` с методом `book(...)`, который принимает разное количество аргументов: при вызове `book(climber)` оформляется восхождение, при `book(climber, route)` — восхождение по конкретной трассе, при `book(climber, route, instructor)` — восхождение с инструктором. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
#
# # Вариант 40. Верёвочный парк
#
# **Задача 1 (создание класса, конструктор, метод).** В верёвочном парке ведётся учёт маршрутов. Создайте класс `RopeRoute` с полями `name` (название), `level` (уровень: детский, средний, экстрим) и `length` (длина в метрах). Реализуйте конструктор, который принимает эти три значения и сохраняет их в объекте. Добавьте метод `info()`, который выводит информацию о маршруте в формате: Название — уровень ..., длина ... м. Создайте один экземпляр класса и вызовите метод.
#
# **Задача 2 (инкапсуляция).** У каждого участника парка есть номер страховочного троса, который нельзя менять или читать напрямую. Создайте класс `SafetyRope`, в котором номер троса хранится в приватном поле `__rope_id`. Реализуйте метод `set_rope_id(value)`, предназначенный только для установки номера при регистрации участника, и метод `get_rope_id()` для чтения значения. Повторная попытка изменить номер после регистрации должна игнорироваться.
#
# **Задача 3 (наследование).** В верёвочном парке есть разные типы препятствий. Создайте базовый класс `Obstacle` с методом `get_obstacle_type()`, возвращающим строку «Препятствие». Унаследуйте от него классы `RopeBridge` и `ZipLine`, переопределив в каждом метод `get_obstacle_type()` так, чтобы он возвращал «Верёвочный мост» и «Зип-лайн» соответственно. Создайте по одному объекту каждого класса и выведите их тип.
#
# **Задача 4 (полиморфизм).** Верёвочный парк рассчитывает время прохождения для разных маршрутов. Создайте классы `KidsRoute`, `MiddleRoute` и `ExtremeRoute`, у каждого из которых есть метод `passing_time()`, возвращающий время в минутах: для детского — 20, для среднего — 40, для экстрима — 60. Напишите функцию `show_time(route)`, которая принимает любой маршрут и выводит время прохождения. Убедитесь, что функция одинаково работает со всеми тремя типами объектов.
#
# **Задача 5 (модификаторы доступа).** Создайте класс `RopeParkManager` (управляющий парка), в котором есть три поля: `name` — публичное, `_zone` — защищённое (зона), `__salary` — приватное (зарплата). Продемонстрируйте обращение к каждому из полей извне класса. Объясните в комментариях, почему к полю `__salary` нельзя обратиться напрямую и как это защищает данные сотрудника.
#
# **Задача 6 (статические методы).** Верёвочному парку нужна утилита для проверки веса участника. Создайте класс `RopeParkUtils` со статическим методом `is_valid_weight(kg)`, который возвращает `True`, если вес не превышает 100 кг, и `False` — в противном случае. Вызовите метод, не создавая объекта класса. Поясните, чем статический метод отличается от обычного.
#
# **Задача 7 (абстрактные методы).** Создайте абстрактный класс `RopeParkItem` с абстрактным методом `describe()`. Унаследуйте от него классы `RopeRoute` и `Instructor`, каждый из которых обязан реализовать метод `describe()`, возвращающий краткое описание. Проверьте, что объект абстрактного класса `RopeParkItem` создать нельзя, а объекты наследников — можно.
#
# **Задача 8 (композиция).** У каждого участника есть карабин. Создайте класс `Carabiner` с методом `show()`, который выводит строку «Карабин застёгнут». Создайте класс `Participant`, который содержит объект класса `Carabiner` внутри себя как поле. Метод `show_participant()` у участника должен выводить имя и вызывать метод `show()` у карабина.
#
# **Задача 9 (переопределение методов).** В верёвочном парке есть базовый класс `RopeParkItem` с методом `get_info()`, который возвращает строку «Объект парка». Унаследуйте от него класс `ExtremeRoute` и переопределите метод `get_info()` так, чтобы он возвращал строку «Экстрим-маршрут: <название>». Создайте объект класса `ExtremeRoute`, вызовите метод `get_info()` и убедитесь, что используется версия из дочернего класса, а не из родительского.
#
# **Задача 10 (перегрузка).** Инструктору парка нужен метод для регистрации участников. Создайте класс `CheckInDesk` с методом `register(...)`, который принимает разное количество аргументов: при вызове `register(participant)` регистрируется участник, при `register(participant, route)` — участник на конкретный маршрут, при `register(participant, route, instructor)` — участник с инструктором. Метод должен выводить соответствующее сообщение в зависимости от количества переданных аргументов.
#
# ---
