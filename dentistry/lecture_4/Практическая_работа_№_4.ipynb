# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/dentistry/lecture_4/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%96_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Практическая работа № 4: Визуализация данных в клинических исследованиях (стоматология и смежные области)**
#
# ## Введение
#
# В лекции №4 мы изучили, как визуализация помогает врачу увидеть закономерности, проверить допущения статистических тестов, сравнить группы и донести результаты до аудитории. График — это не просто «картинка», а инструмент мышления, позволяющий мгновенно оценить распределение, выбросы, связи и динамику клинических параметров.
#
# Цель данной работы — закрепить практические навыки:
#
# - выбора правильного типа графика в зависимости от исследовательской задачи и типа данных,
# - построения и оформления графиков в соответствии с требованиями научных медицинских публикаций,
# - критической оценки графиков на предмет манипуляций и искажений,
# - работы с библиотеками `matplotlib`, `seaborn` и `pandas` в Python.
#
# Вы будете выполнять задания как с генерацией случайных данных, так и с анализом реальных (или приближенных к реальным) клинических данных. Все графики необходимо оформлять так, как принято в научных журналах (по аналогии со стандартами APA, адаптированными для медицины).
#
# ---
#
# ## Подготовка рабочей среды
#
# Перед началом работы установите необходимые библиотеки (в терминале или командной строке):
#
# ```python
# !pip install pandas numpy matplotlib seaborn scipy
# ```
#
# Если вы используете Jupyter Notebook или Google Colab, достаточно выполнить ячейку с импортами:
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# from scipy import stats
# ```
#
# Для корректного отображения русских шрифтов в графиках (если необходимо) можно добавить:
#
# ```python
# plt.rcParams['font.family'] = 'DejaVu Sans'  # или другой шрифт с поддержкой кириллицы
# ```
#
# ## Часть 1. Теоретические вопросы (для самопроверки)
#
# Перед выполнением практических заданий письменно ответьте на следующие вопросы (кратко, но содержательно). Это поможет убедиться, что вы понимаете ключевые концепции визуализации.
#
# 1. Назовите четыре основные функции визуализации в клинических исследованиях. Приведите пример для каждой из стоматологической практики.
#
# 2. Какой тип графика вы выберете для отображения распределения одной количественной переменной (например, глубины пародонтального кармана)? Почему?
#
# 3. В чём отличие гистограммы от столбчатой диаграммы? Приведите примеры использования каждой в стоматологии.
#
# 4. Что показывает ящик с усами (boxplot)? Какие пять статистик на нём отображены?
#
# 5. Для какой задачи используется точечный график (scatter plot)? Какую информацию он даёт о связи двух переменных (например, возраст и глубина кармана)?
#
# 6. Что такое тепловая карта (heatmap) и когда она применяется в медицинских исследованиях? Приведите два примера (один стоматологический, другой — из смежной области, например, для микробиолога или неонатолога).
#
# 7. Назовите обязательные элементы оформления графика для научной публикации (по стандартам, принятым в медицинских журналах).
#
# 8. Какие ошибки при построении графиков могут ввести читателя в заблуждение? Приведите хотя бы три примера.
#
# 9. Почему важно проверять распределение данных перед выбором статистического теста? Какой график для этого подходит лучше всего?
#
# 10. **Этический вопрос:** Представьте, что вы видите в статье график, где ось Y начинается не с нуля, а с 3 мм, чтобы подчеркнуть разницу между группами лечения. Что вы заподозрите и как проверите честность такого графика?
#
# ---
#
# ## Часть 2. Практические задания на Python
#
# Все задания выполняйте в одной Jupyter Notebook (или .py-скрипте). Код должен быть прокомментирован на русском языке, а каждый график сопровождаться текстовым анализом (что вы видите и какой вывод можно сделать). В конце каждого задания приводите краткий вывод.
#
# ---
#
# ### Задание 1. Гистограмма: анализ распределения глубины пародонтальных карманов
#
# **Описание.** Предположим, вы исследовали глубину пародонтальных карманов (PPD) у 200 пациентов с хроническим генерализованным пародонтитом. Значения могут варьироваться от 2 до 8 мм. Вы получили следующие данные (сгенерируем их для примера).
#
# **Требуется:**
#
# 1. Сгенерируйте массив из 200 случайных значений, имеющих нормальное распределение со средним 4.5 мм и стандартным отклонением 1.2 мм, но обрежьте значения до диапазона 2–8 мм (используйте `np.clip`). Это будет имитация реальных данных.
#
# 2. Постройте гистограмму с 12 интервалами. Добавьте вертикальные линии для среднего и медианы, подпишите их на графике.
#
# 3. Оформите график по правилам научных публикаций:
#    - заголовок с номером (например, *Рисунок 1. Распределение глубины пародонтальных карманов (N=200)*),
#    - подписи осей (с единицами измерения — мм),
#    - легенду.
#
# 4. Напишите краткий анализ: симметрично ли распределение? Есть ли выбросы? Какое значение (среднее или медиана) лучше описывает центральную тенденцию?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 2. Ящик с усами: сравнение трёх методов лечения пародонтита
#
# **Описание.** Вы проводите исследование эффективности трёх методов лечения хронического пародонтита: скейлинг (SRP), лоскутная операция (OFD) и лазерная терапия (LT). У вас есть три группы по 40 пациентов каждая. Глубина карманов (PPD) измеряется в мм через 3 месяца после лечения.
#
# Сгенерируйте данные так, чтобы:
# - в группе скейлинга средний PPD был около 3.5 мм, разброс 0.8;
# - в группе лоскутной операции — около 2.8 мм, разброс 0.7;
# - в группе лазерной терапии — около 3.2 мм, разброс 0.9.
#
# **Требуется:**
#
# 1. Создайте DataFrame с колонками `['PPD', 'Метод']`.
#
# 2. Постройте ящик с усами (boxplot) с помощью `seaborn.boxplot`. Сравните медианы, разброс и выбросы в группах.
#
# 3. Оформите график по правилам: номер, название, подписи осей, легенда (если нужна). Добавьте под графиком примечание со средними и стандартными отклонениями для каждой группы (используйте `plt.figtext` или текстовую ячейку).
#
# 4. Напишите интерпретацию: какие группы статистически различаются (визуально)? Есть ли группы с большим разбросом? Что это может означать для выбора метода лечения в практике?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 3. Точечный график: связь между возрастом и глубиной пародонтальных карманов
#
# **Описание.** Вы хотите проверить гипотезу о том, что возраст пациента положительно связан с глубиной пародонтальных карманов (PPD). Для этого вы собрали данные 100 пациентов с пародонтитом: возраст (годы) и средняя глубина кармана (мм).
#
# Сгенерируйте данные так, чтобы корреляция была примерно +0.5 (т.е. чем старше пациент, тем глубже карманы).
#
# **Требуется:**
#
# 1. Постройте scatter plot: по оси X — возраст, по оси Y — PPD.
#
# 2. Добавьте линию регрессии (используйте `scipy.stats.linregress`). Нанесите на график коэффициент корреляции (r).
#
# 3. Оформите график по правилам. Добавьте примечание с уравнением регрессии (опционально).
#
# 4. Напишите анализ: что вы видите? Есть ли нелинейность? Есть ли явные выбросы, которые могут искажать связь?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 4. Тепловая карта корреляционной матрицы клинических параметров
#
# **Описание.** Вы измерили у 120 пациентов с пародонтитом пять клинических параметров:
# - глубина пародонтального кармана (PPD),
# - уровень клинического прикрепления (CAL),
# - индекс гигиены (OHI-S),
# - кровоточивость при зондировании (SBI),
# - возраст пациента.
#
# Вы хотите увидеть, какие параметры сильно коррелируют между собой, а какие — независимы.
#
# Сгенерируйте коррелированные данные (можно использовать многомерное нормальное распределение или создать переменные с известными корреляциями).
#
# **Требуется:**
#
# 1. Рассчитайте матрицу корреляций Пирсона для всех пяти переменных.
#
# 2. Постройте тепловую карту (heatmap) с аннотациями (коэффициенты корреляции). Используйте цветовую палитру `coolwarm` или `RdBu`.
#
# 3. Оформите график: номер, название, подписи осей (названия параметров), цветовая шкала с подписью.
#
# 4. Проанализируйте: какие кластеры сильно коррелирующих параметров вы видите? Есть ли параметры, которые почти не коррелируют с другими? Что это говорит о патогенезе пародонтита?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 5. Линейный график: динамика боли после удаления зуба мудрости
#
# **Описание.** Вы отслеживаете изменения уровня боли по визуально-аналоговой шкале (VAS, 0–10) у одного пациента после удаления ретинированного третьего моляра на протяжении 7 дней. Данные по баллам VAS на каждый день:
#
# `[7.0, 5.5, 4.0, 3.5, 2.5, 1.5, 0.8]`
#
# **Требуется:**
#
# 1. Постройте линейный график, соединяющий точки. Используйте маркеры (например, кружки).
#
# 2. Подпишите оси: «День после операции» и «Балл по VAS».
#
# 3. Оформите: заголовок, подписи, легенда (если несколько линий).
#
# 4. Добавьте горизонтальную пунктирную линию, обозначающую уровень боли, требующий назначения анальгетиков (например, VAS ≥ 4). Прокомментируйте, в какие дни пациенту требовалось обезболивание.
#
# 5. Напишите анализ: какова динамика? Есть ли периоды застоя или усиления боли? Какой темп снижения?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 6. Сравнение нескольких групп с помощью столбчатой диаграммы (бонус)
#
# **Описание.** У вас есть данные о частоте встречаемости различных диагнозов в стоматологической клинике за месяц (например, 150 первичных пациентов). Распределение: кариес — 45, пульпит — 38, периодонтит — 28, гингивит — 15, стоматит — 24.
#
# **Требуется:**
#
# 1. Постройте столбчатую диаграмму (bar chart) с частотами для каждого диагноза.
#
# 2. Оформите по правилам.
#
# 3. Сделайте вывод о наиболее распространённом диагнозе в выборке.
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ## Часть 3. Анализ готовых графиков и этика визуализации
#
# **Задание 7. Критический анализ графиков (эссе).**
#
# Найдите в интернете или научных публикациях **два графика** (можно скриншоты):
# - один, по вашему мнению, **хороший и честный**;
# - другой, который **вводит в заблуждение** (манипуляции с масштабом, обрезанные оси, неподходящий тип графика и т.п.).
#
# Вставьте их в свой отчёт (или опишите словами, если нет возможности вставить) и напишите **эссе** (объёмом 1–2 страницы), в котором:
#
# 1. Опишите, что показывает каждый график и какова его цель.
#
# 2. Для хорошего графика: почему он удачен? Какие элементы оформления делают его понятным и честным? Соответствует ли он правилам оформления?
#
# 3. Для плохого графика: какая именно манипуляция использована? Как она искажает восприятие данных? Что бы вы изменили, чтобы график стал честным?
#
# 4. Сделайте вывод о важности критического взгляда на визуализацию в медицинских исследованиях. Почему врач должен уметь распознавать недобросовестные графики?
#
# ```text
# # Ваш текст эссе:
# ```
#
# ## Часть 4. Комплексное задание (повышенной сложности) — по желанию
#
# **Задание 8. Построение инфографики «Как выбрать правильный график».**
#
# Создайте одностраничную памятку для коллег-стоматологов (или врачей смежных специальностей). Можно использовать любой инструмент (Word, PowerPoint, Canva, даже код с `matplotlib` для создания схемы). Памятка должна содержать:
#
# - алгоритм выбора графика в виде блок-схемы (можно взять за основу схему из лекции);
# - краткое описание не менее 5 типов графиков (гистограмма, boxplot, scatter plot, heatmap, line plot) с указанием, когда какой использовать;
# - примеры клинических задач для каждого (из стоматологии, а также можно добавить пример для неонатологии или микробиологии);
# - чек-лист оформления графика (заголовок, оси, легенда, примечание).
#
# Файл приложите к работе (в формате .png, .pdf или .pptx).
#
# ```text
# # Файл приложен отдельно
# ```
#
# ---
#
# ## Часть 5. Домашнее задание (на 2 недели)
#
# **Задание 9. Работа с реальными (или приближенными) клиническими данными.**
#
# Возьмите любой набор данных, который у вас есть (можно использовать данные из лекции №2 — 30 пациентов с глубиной пародонтальных карманов и индексом гигиены, либо найти открытый датасет по стоматологии, например, из репозиториев Kaggle). Если данных нет, создайте свои, имитируя обследование 50 пациентов по 3–4 параметрам (например, PPD, OHI-S, возраст, кровоточивость).
#
# Выполните следующие пункты:
#
# 1. **Очистите данные** (если есть пропуски, удалите или заполните) и опишите их (средние, медианы, стандартные отклонения).
#
# 2. **Постройте гистограмму** для одной количественной переменной (например, глубина карманов). Оформите по правилам.
#
# 3. **Постройте boxplot** для сравнения двух групп (например, курящие и некурящие, или мужчины и женщины, или группа с хорошей и плохой гигиеной, если есть данные). Сделайте выводы.
#
# 4. **Постройте scatter plot** для двух переменных, которые, по вашему предположению, могут быть связаны (например, возраст и PPD, или OHI-S и PPD). Добавьте линию регрессии и коэффициент корреляции.
#
# 5. **Постройте тепловую карту** корреляционной матрицы для всех количественных переменных. Проанализируйте сильные связи.
#
# Все графики должны быть оформлены по правилам: номера, названия, подписи осей, легенды, примечания со статистиками.
#
# В конце напишите **общее резюме** (1 страница): какие закономерности вы обнаружили в своих данных? Подтвердились ли ваши гипотезы? Какой график оказался наиболее информативным?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ## Критерии оценки
#
# | Компонент | Процент | Описание |
# |-----------|---------|----------|
# | Теоретические вопросы (Часть 1) | 15% | Полнота и правильность ответов |
# | Задания 1–5 (построение графиков) | 40% | Корректность кода, соответствие оформлению, качество интерпретации |
# | Задания 6–7 (анализ и этика) | 20% | Глубина анализа, аргументированность, умение выявить манипуляции |
# | Задание 8 (инфографика) | 10% | Наглядность, полнота, практическая полезность |
# | Домашнее задание (Часть 5) | 15% | Полнота выполнения всех пунктов, качество оформления, выводы |
#
# ---
#
# ## Требования к сдаче
#
# - Пришлите **один файл** (Jupyter Notebook `.ipynb` или Python `.py`) со всеми заданиями, кодом и текстовыми комментариями.
# - Эссе по этике (Задание 7) и инфографика (Задание 8) могут быть приложены отдельными файлами (`.pdf`, `.png`, `.pptx`) или вставлены в Notebook как Markdown-ячейки.
# - Убедитесь, что код выполняется без ошибок. Укажите версии библиотек, если требуется.
# - Все графики должны быть сохранены в высоком разрешении (при необходимости используйте `plt.savefig`).
#
# ---
#
# ## Заключение
#
# Данная практическая работа позволит вам не только освоить технические приёмы построения графиков на Python, но и научиться выбирать правильный инструмент для каждой клинической задачи, а главное — критически оценивать визуализацию с точки зрения честности и информативности. Грамотная визуализация — это путь к более глубокому пониманию данных и прозрачной коммуникации результатов в медицинской практике. Успехов!
#
# ---
#
# **Срок выполнения: 2 недели.**
