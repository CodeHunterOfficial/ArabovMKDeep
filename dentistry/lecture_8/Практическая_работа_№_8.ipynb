# %% [markdown]
# <a href="https://colab.research.google.com/github/CodeHunterOfficial/ArabovMKDeep/blob/main/dentistry/lecture_8/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%96_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа № 8: Локальные LLM и приватность данных в стоматологии и медицине
#
# ## Введение
#
# В лекции №8 мы познакомились с тем, как использовать локальные большие языковые модели (LLM) для работы с медицинскими данными, сохраняя полный контроль над конфиденциальностью. Мы разобрали:
#
# - почему локальный запуск LLM критически важен для врачей с точки зрения 152-ФЗ и врачебной тайны,
# - как установить и настроить **Ollama** — платформу для запуска локальных моделей,
# - какие модели доступны (Qwen, DeepSeek, Llama, Mistral) и как их сравнивать,
# - как подключать локальные модели к **VS Code**,
# - как настраивать **системные промпты** для медицинских задач (анализ жалоб, суммаризация эпикризов, перевод терминов),
# - как использовать **Ollama API** в Python-коде,
# - какие этические правила нужно соблюдать при работе с локальными LLM в медицине.
#
# Теперь вам предстоит применить эти знания на практике.
#
# **Цель работы** — закрепить навыки:
# - установки и настройки Ollama,
# - работы с локальными моделями через терминал и API,
# - создания и использования системных промптов для стоматологических и общемедицинских задач,
# - разработки простого чат-приложения для поддержки пациентов стоматологической клиники,
# - анализа производительности и качества локальных моделей,
# - этической оценки использования локальных LLM в клинической практике.
#
# ---
#
# ## Подготовка рабочей среды
#
# Перед началом работы убедитесь, что ваш компьютер соответствует минимальным требованиям:
#
# | Требование | Минимальные | Рекомендуемые |
# |------------|-------------|---------------|
# | **Оперативная память (RAM)** | 8 GB | 16+ GB |
# | **Свободное место на диске** | 10 GB | 20+ GB |
# | **Операционная система** | Windows 10+, macOS 11+, Linux | Windows 11, macOS 13+, Ubuntu 22+ |
#
# Установите необходимые библиотеки Python:
#
# ```python
# !pip install requests
# !pip install ollama
#
# # Установка зависимостей (pciutils + zstd)
# !sudo apt-get update
# !sudo apt-get install -y pciutils zstd
#
# # Установка Ollama через официальный скрипт
# !curl -fsSL https://ollama.ai/install.sh | sh
#
# # Проверка установки
# !ollama --version
#
# # Запуск сервера в фоне
# import subprocess
# import threading
# import time
#
# def start_server():
#     subprocess.Popen(["ollama", "serve"])
#
# server_thread = threading.Thread(target=start_server, daemon=True)
# server_thread.start()
#
# time.sleep(5)  # Ждем запуска сервера
#
# # Скачиваем модель (выберите подходящую по ресурсам)
# !ollama pull qwen2.5:7b   # или qwen2.5:0.5b для слабых ПК
#
# # Проверяем список доступных моделей
# !ollama list
#
# print("✅ Ollama установлен и готов к работе!")
# ```
#
# Установите **Ollama** с официального сайта: [ollama.com/download](https://ollama.com/download)
#
# После установки проверьте, что всё работает:
#
# ```python
# !ollama --version
# ```
#
# ## Часть 1. Теоретические вопросы (для самопроверки)
#
# Перед выполнением практических заданий письменно ответьте на следующие вопросы. Это поможет убедиться, что вы понимаете ключевые концепции.
#
# 1. Почему локальный запуск LLM важен для врача-стоматолога (и врача любой специальности)? Какие преимущества он даёт по сравнению с облачными сервисами?
#
# 2. Что такое Ollama и для чего он нужен? Как он связан с 152-ФЗ и врачебной тайной?
#
# 3. Какие системные требования необходимы для запуска моделей 7B–8B?
#
# 4. Как установить Ollama на Windows/macOS/Linux? Опишите пошагово.
#
# 5. Какие модели доступны в Ollama? Какую модель вы бы рекомендовали для работы с русскоязычными медицинскими текстами и почему?
#
# 6. В чём разница между Qwen2.5:7B, DeepSeek-R1:7B и Llama3.2:8B? Какая модель лучше для работы с русским языком?
#
# 7. Что такое системный промпт (system prompt)? Приведите пример для стоматологической консультации.
#
# 8. Как использовать Ollama API в Python? Напишите базовый код для отправки запроса.
#
# 9. Какие этические требования нужно соблюдать при использовании локальных LLM в медицине?
#
# 10. **Рефлексивный вопрос:** готовы ли вы использовать локальную LLM в своей будущей практике? Какие риски вы видите и как их минимизировать?
#
# ---
#
# ## Часть 2. Практические задания
#
# Все задания выполняйте в Jupyter Notebook или отдельных Python-файлах. Код должен быть снабжён комментариями на русском языке.
#
# ---
#
# ### Задание 1. Установка и настройка Ollama
#
# **Описание.** В этом задании вы установите Ollama и скачаете первую модель для работы.
#
# **Требуется:**
#
# 1. Установите Ollama на свой компьютер (следуя инструкции из лекции).
#
# 2. Скачайте модель **Qwen2.5:7B** (или **Qwen2.5:0.5B**, если у вас мало ресурсов):
#
# ```bash
# !ollama pull qwen2.5:7b
# ```
#
# 3. Проверьте, что модель скачалась:
#
# ```bash
# !ollama list
# ```
#
# 4. Запустите модель в интерактивном режиме:
#
# ```bash
# !ollama run qwen2.5:7b
# ```
#
# 5. Задайте модели два вопроса:
#    - "Привет! Как ты можешь помочь врачу-стоматологу?"
#    - "Что такое острый пульпит и каковы его симптомы?"
#
# 6. Выйдите из интерактивного режима (`/bye`).
#
# **Что сдать:** скриншоты выполнения всех шагов (терминал с командами) и краткое описание (1 страница).
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 2. Работа с Ollama API (базовый запрос)
#
# **Описание.** В этом задании вы напишете Python-код для отправки запросов к локальной модели через Ollama API.
#
# **Требуется:**
#
# 1. Напишите функцию `chat_with_ollama(user_text, system_prompt)`, которая отправляет запрос к Ollama API и возвращает ответ модели.
#
# 2. Используйте следующие параметры:
#    - API endpoint: `http://localhost:11434/api/chat`
#    - Модель: `qwen2.5:7b` (или другую)
#    - Температура: `0.7`
#    - Максимальное количество токенов: `300`
#
# 3. Отправьте запрос с системным промптом:
#
# ```
# Ты — помощник врача-стоматолога. Твоя задача — помогать в анализе жалоб пациентов,
# но НЕ ставить диагнозы и НЕ давать медицинские рекомендации.
#
# Будь профессиональным и точным. Напоминай о необходимости консультации врача.
# ```
#
# 4. Задайте вопрос от имени пациента: *«У меня болит зуб при накусывании, десна опухла, температура 37.5. Что мне делать?»*
#
# 5. Выведите ответ модели.
#
# 6. Обработайте возможные ошибки (Ollama не запущен, превышение времени ожидания).
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 3. Сравнение системных промптов
#
# **Описание.** В этом задании вы протестируете разные системные промпты и сравните, как меняется стиль ответов модели при работе с тревожным пациентом.
#
# **Требуется:**
#
# 1. Создайте три разных системных промпта для одной и той же задачи (помощь пациенту с дентофобией):
#
#    - **Промпт А (базовый)**: ассистент стоматолога, профессиональный, чёткий.
#
#    - **Промпт Б (КПТ-подход)**: помогает справиться со страхом, называет когнитивные искажения (катастрофизация, сверхобобщение), задаёт вопросы о доказательствах.
#
#    - **Промпт В (эмпатический)**: сострадательный, фокус на чувствах, поддержка.
#
# 2. Для каждого промпта отправьте один и тот же запрос пациента:
#
#    *«Я ужасно боюсь идти к стоматологу, у меня паника, сердце колотится. А ещё зуб болит, наверное, будет очень больно лечить. Я не могу решиться.»*
#
# 3. Запишите все три ответа модели.
#
# 4. Напишите сравнительный анализ (1–2 страницы):
#    - Как изменился стиль ответа?
#    - Какой промпт дал наиболее поддерживающий ответ?
#    - Какой промпт лучше подходит для работы с дентофобией?
#    - Какой промпт вы бы использовали в своей практике и почему?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 4. Создание интерактивного чат-бота для стоматологической клиники
#
# **Описание.** В этом задании вы создадите полноценный интерактивный чат-бот для поддержки пациентов стоматологической клиники, работающий локально через Ollama API.
#
# **Требуется:**
#
# 1. Создайте файл `dental_chat.py`.
#
# 2. Реализуйте интерактивный чат с:
#    - Приветственным сообщением с дисклеймером.
#    - Возможностью выбирать системный промпт из списка (ассистент, суммаризация, перевод терминов, поддержка при дентофобии).
#    - Историей диалога (сохраняйте сообщения в список).
#    - Командами: `/exit` — выход, `/clear` — очистка истории, `/change` — смена промпта.
#
# 3. Убедитесь, что:
#    - Данные не сохраняются на диск (только в памяти сессии).
#    - Есть дисклеймер о том, что модель не заменяет врача и не ставит диагнозы.
#
# 4. Запустите чат-бота и проведите короткий диалог (3–4 сообщения) от имени пациента с жалобой.
#
# **Что сдать:** полный код файла `dental_chat.py`, скриншот работы чат-бота, краткое описание (1 страница).
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 5. Анализ производительности моделей
#
# **Описание.** В этом задании вы сравните производительность двух разных моделей (по времени ответа и качеству) на медицинском вопросе.
#
# **Требуется:**
#
# 1. Скачайте **две модели** разных размеров, например:
#    - `qwen2.5:0.5b` (лёгкая)
#    - `qwen2.5:7b` (средняя)
#
# 2. Напишите функцию, которая измеряет время ответа модели.
#
# 3. Отправьте один и тот же запрос к обеим моделям (с одинаковым системным промптом):
#
#    *«Опиши три характерных симптома острого пульпита»*
#
# 4. Запишите:
#    - Время ответа для каждой модели (в секундах).
#    - Качество ответа (количество слов, релевантность, медицинская точность).
#
# 5. Напишите отчёт (1–2 страницы):
#    - Какая модель быстрее?
#    - Какая модель дала более качественный ответ?
#    - Какую модель вы бы рекомендовали для использования в стоматологической практике и почему?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 6. Создание системного промпта для конкретной стоматологической задачи
#
# **Описание.** В этом задании вы разработаете собственный системный промпт для конкретной клинической задачи.
#
# **Требуется:**
#
# 1. Выберите одну из задач:
#    - Помощь в анализе жалоб пациента (предварительная сортировка по срочности).
#    - Суммаризация выписного эпикриза.
#    - Перевод медицинских терминов на понятный для пациента язык.
#    - Поддержка тревожного пациента перед лечением (снижение дентофобии).
#    - Генерация рекомендаций по послеоперационному уходу.
#
# 2. Разработайте системный промпт, который:
#    - Чётко определяет роль модели.
#    - Устанавливает правила поведения.
#    - Определяет стиль общения.
#    - Содержит дисклеймер и напоминание о необходимости консультации врача.
#
# 3. Протестируйте промпт на 3–4 разных запросах (реалистичные вопросы пациента или описания клинических ситуаций).
#
# 4. Напишите рефлексию (1 страница):
#    - Почему вы выбрали именно эту структуру промпта?
#    - Что работает хорошо? Что можно улучшить?
#    - Как этот промпт может быть использован в реальной клинической практике?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 7. Этический анализ (обязательное)
#
# **Описание.** Представьте, что вы — руководитель стоматологической клиники (или медицинского центра). Вы хотите внедрить локальную LLM для поддержки работы врачей: анализ жалоб, помощь в документации, предварительные рекомендации пациентам.
#
# **Напишите этический протокол** (2–3 страницы), в котором осветите:
#
# 1. **Информированное согласие** — что пациент должен знать об использовании ИИ? Какие пункты обязательно включить в форму согласия?
#
# 2. **Конфиденциальность и безопасность** — как хранятся данные? Кто имеет доступ? Как обеспечивается анонимизация? (учесть 152-ФЗ, врачебную тайну)
#
# 3. **Человеческий контроль** — как организовать проверку результатов модели врачом? Кто отвечает за финальные решения?
#
# 4. **Обработка ошибок и неотложных состояний** — что делать, если модель пропустит признаки острого воспаления (периостит, абсцесс)? Что делать, если модель даст неверную рекомендацию?
#
# 5. **Прозрачность** — как объяснить пациенту, почему модель выдала тот или иной результат?
#
# 6. **Обучение персонала** — кто и как будет обучаться работе с системой?
#
# **Что сдать:** этический протокол в формате Word/PDF (или текстовой ячейкой в Notebook).
#
# ```text
# # Ваш анализ:
# ```
#
# ---
#
# ### Задание 8. Демонстрационное приложение (повышенной сложности — по желанию)
#
# **Описание.** Создайте простое веб-приложение на Streamlit для работы с локальной LLM в стоматологической клинике.
#
# **Требуется:**
#
# 1. Установите Streamlit: `pip install streamlit`
#
# 2. Создайте файл `app.py` с:
#    - Полем ввода для текста жалобы или вопроса пациента.
#    - Выбором системного промпта (из списка: ассистент, суммаризация, перевод терминов).
#    - Кнопкой "Отправить".
#    - Отображением ответа модели.
#    - Чётким дисклеймером: "Не является медицинской консультацией".
#
# 3. Запустите приложение: `streamlit run app.py`
#
# 4. Проведите демонстрацию работы (скриншоты).
#
# **Что сдать:** код `app.py`, скриншоты работы приложения.
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ---
#
# ### Задание 9. Сравнение локальной и облачной модели (исследовательское)
#
# **Описание.** Если у вас есть доступ к облачному API (например, Hugging Face Inference API или OpenAI), сравните ответы локальной и облачной модели на одни и те же медицинские запросы.
#
# **Требуется:**
#
# 1. Выберите один и тот же системный промпт (например, ассистент стоматолога).
#
# 2. Отправьте один и тот же запрос к локальной модели (через Ollama) и к облачной модели.
#
# 3. Сравните:
#    - Качество ответа (точность, релевантность, эмпатичность).
#    - Время ответа.
#    - Конфиденциальность (данные покидают компьютер?).
#
# 4. Напишите рефлексию (1–2 страницы):
#    - Какая модель дала более качественный ответ?
#    - Готовы ли вы пожертвовать качеством ради приватности?
#    - Какой подход вы выберете для своей практики?
#
# ```python
# # Ваш код решения задачи:
# ```
#
# ## Критерии оценки
#
# | Компонент | Процент | Описание |
# |-----------|---------|----------|
# | Теоретические вопросы (Часть 1) | 15% | Полнота и правильность ответов |
# | Задание 1 (установка Ollama) | 10% | Корректность установки, скриншоты |
# | Задание 2 (Ollama API) | 10% | Корректность кода, обработка ошибок |
# | Задание 3 (сравнение промптов) | 10% | Глубина сравнительного анализа |
# | Задание 4 (интерактивный чат-бот) | 15% | Полнота функционала, качество кода |
# | Задание 5 (анализ производительности) | 10% | Качество эксперимента, выводы |
# | Задание 6 (создание промпта) | 10% | Качество промпта, рефлексия |
# | Задание 7 (этический протокол) | 20% | Полнота, аргументированность |
# | Задание 8 (Streamlit, бонус) | +5% | Работающее приложение |
# | Задание 9 (сравнение с облаком, бонус) | +5% | Качество сравнения, выводы |
#
# ---
#
# ## Требования к сдаче
#
# - Пришлите **один файл** (Jupyter Notebook `.ipynb`) со всеми заданиями, кодом и текстовыми комментариями.
# - Для заданий, требующих отдельных файлов (Задание 4, Задание 8), приложите файлы `.py` в архиве или ссылкой на репозиторий.
# - Этический протокол (Задание 7) приложите отдельным файлом (`.pdf` или `.docx`).
# - Скриншоты вставьте в Notebook или приложите отдельными файлами.
# - Убедитесь, что код выполняется без ошибок. Укажите версии библиотек.
#
# ---
#
# ## Заключение
#
# Данная практическая работа проведёт вас через все этапы работы с локальными LLM — от установки и настройки до создания полноценного приложения для поддержки пациентов стоматологической клиники. Вы не только освоите технические навыки, но и научитесь **критически оценивать** этические аспекты использования ИИ в клинической практике.
#
# **Главный вывод:** локальные LLM позволяют использовать мощь современных моделей, сохраняя полный контроль над данными пациентов. Это не компромисс — это стандарт для ответственной работы с чувствительной информацией.
#
# ---
#
# **Срок выполнения: 2 недели.**
